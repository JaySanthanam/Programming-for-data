# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Table_Oct23.csv"
new_df = get_data(url_new)
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Table_Jul23.csv"
old_df = get_data(url_old)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
#new_df['Indicator'] = new_df['Indicator'].map("{:.4f}".format)
#new_df['Numerator'] = new_df['Numerator'].map('{:.4f}'.format)
#new_df['Denominator'] = new_df['Denominator'].map('{:.4f}'.format)

# %%
#old_df['Indicator'] = old_df['Indicator'].map('{:.4f}'.format)
#old_df['Numerator'] = old_df['Numerator'].map('{:.4f}'.format)
#old_df['Denominator'] = old_df['Denominator'].map('{:.4f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year  Indicator  Numerator  Denominator
# 0  C&L01  Aberdeen City  2010-11     0.4067   785.0188    1922292.0
# 1  C&L01  Aberdeen City  2011-12     0.9227  1886.6034    2045051.0
# 2  C&L01  Aberdeen City  2012-13     4.3317  9381.0432    2163756.0
# 3  C&L01  Aberdeen City  2013-14     4.0486  8988.3238    2222588.0
# 4  C&L01  Aberdeen City  2014-15     3.4734  8645.5731    2487138.0

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year  Indicator  Numerator  Denominator
# 0  C&L01  Aberdeen City  2010-11       0.33      637.0    1922292.0
# 1  C&L01  Aberdeen City  2011-12       0.76     1554.0    2045051.0
# 2  C&L01  Aberdeen City  2012-13       3.64     7883.0    2163756.0
# 3  C&L01  Aberdeen City  2013-14       3.48     7726.0    2222588.0
# 4  C&L01  Aberdeen City  2014-15       3.02     7517.0    2487138.0

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#         Code LocalAuthority     Year  Indicator  Numerator  Denominator
# 0      C&L01  Aberdeen City  2010-11     0.3300      637.0    1922292.0
# 1      C&L01  Aberdeen City  2011-12     0.7600     1554.0    2045051.0
# 2      C&L01  Aberdeen City  2012-13     3.6400     7883.0    2163756.0
# 3      C&L01  Aberdeen City  2013-14     3.4800     7726.0    2222588.0
# 4      C&L01  Aberdeen City  2014-15     3.0200     7517.0    2487138.0
# ...      ...            ...      ...        ...        ...          ...
# 32548   SW06       Scotland  2018-19   103.4162   109915.0    1062841.0
# 32549   SW06       Scotland  2019-20   104.8891   112873.0    1076118.0
# 32550   SW06       Scotland  2020-21   120.2000    91887.0     764451.0
# 32551   SW06       Scotland  2021-22   106.7436    98102.0     919043.0
# 32552   SW06       Scotland  2022-23   101.6758    94572.0     930133.0
#
# [26776 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                     old                              new  \
#                               Indicator  Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    0.4067   785.0188   1922292.0    0.3300
#                       2011-12    0.9227  1886.6034   2045051.0    0.7600
#                       2012-13    4.3317  9381.0432   2163756.0    3.6400
#                       2013-14    4.0486  8988.3238   2222588.0    3.4800
#                       2014-15    3.4734  8645.5731   2487138.0    3.0200
# ...                                 ...        ...         ...       ...
# HSN02  Scotland       2022-23       NaN        NaN         NaN    0.0171
# HSN03  Scotland       2022-23       NaN        NaN         NaN    0.7091
# HSN04b Scotland       2022-23       NaN        NaN         NaN    9.6802
# SW03a  Scotland       2022-23       NaN        NaN         NaN    0.6152
# SW06   Scotland       2022-23       NaN        NaN         NaN  101.6758
#
#
#                                 Numerator   Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11       637.0  1.922292e+06
#                       2011-12      1554.0  2.045051e+06
#                       2012-13      7883.0  2.163756e+06
#                       2013-14      7726.0  2.222588e+06
#                       2014-15      7517.0  2.487138e+06
# ...                                   ...           ...
# HSN02  Scotland       2022-23  22152924.0  1.300000e+09
# HSN03  Scotland       2022-23    228853.0  3.227210e+05
# HSN04b Scotland       2022-23   5701127.0  5.889490e+05
# SW03a  Scotland       2022-23         NaN           NaN
# SW06   Scotland       2022-23     94572.0  9.301330e+05
#
# [32566 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                     old                              new  \
#                               Indicator  Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    0.4067   785.0188   1922292.0    0.3300
#                       2011-12    0.9227  1886.6034   2045051.0    0.7600
#                       2012-13    4.3317  9381.0432   2163756.0    3.6400
#                       2013-14    4.0486  8988.3238   2222588.0    3.4800
#                       2014-15    3.4734  8645.5731   2487138.0    3.0200
# ...                                 ...        ...         ...       ...
# HSN02  Scotland       2022-23       NaN        NaN         NaN    0.0171
# HSN03  Scotland       2022-23       NaN        NaN         NaN    0.7091
# HSN04b Scotland       2022-23       NaN        NaN         NaN    9.6802
# SW03a  Scotland       2022-23       NaN        NaN         NaN    0.6152
# SW06   Scotland       2022-23       NaN        NaN         NaN  101.6758
#
#
#                                 Numerator   Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11       637.0  1.922292e+06
#                       2011-12      1554.0  2.045051e+06
#                       2012-13      7883.0  2.163756e+06
#                       2013-14      7726.0  2.222588e+06
#                       2014-15      7517.0  2.487138e+06
# ...                                   ...           ...
# HSN02  Scotland       2022-23  22152924.0  1.300000e+09
# HSN03  Scotland       2022-23    228853.0  3.227210e+05
# HSN04b Scotland       2022-23   5701127.0  5.889490e+05
# SW03a  Scotland       2022-23         NaN           NaN
# SW06   Scotland       2022-23     94572.0  9.301330e+05
#
# [20760 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()

# %%
out
# Out:
#                                     old                              new  \
#                               Indicator  Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    0.4067   785.0188   1922292.0    0.3300
#                       2011-12    0.9227  1886.6034   2045051.0    0.7600
#                       2012-13    4.3317  9381.0432   2163756.0    3.6400
#                       2013-14    4.0486  8988.3238   2222588.0    3.4800
#                       2014-15    3.4734  8645.5731   2487138.0    3.0200
# ...                                 ...        ...         ...       ...
# HSN02  Scotland       2022-23       NaN        NaN         NaN    0.0171
# HSN03  Scotland       2022-23       NaN        NaN         NaN    0.7091
# HSN04b Scotland       2022-23       NaN        NaN         NaN    9.6802
# SW03a  Scotland       2022-23       NaN        NaN         NaN    0.6152
# SW06   Scotland       2022-23       NaN        NaN         NaN  101.6758
#
#
#                                 Numerator   Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11       637.0  1.922292e+06
#                       2011-12      1554.0  2.045051e+06
#                       2012-13      7883.0  2.163756e+06
#                       2013-14      7726.0  2.222588e+06
#                       2014-15      7517.0  2.487138e+06
# ...                                   ...           ...
# HSN02  Scotland       2022-23  22152924.0  1.300000e+09
# HSN03  Scotland       2022-23    228853.0  3.227210e+05
# HSN04b Scotland       2022-23   5701127.0  5.889490e+05
# SW03a  Scotland       2022-23         NaN           NaN
# SW06   Scotland       2022-23     94572.0  9.301330e+05
#
# [32566 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                               Indicator_old  Numerator_old  Denominator_old  \
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11         0.4067       785.0188        1922292.0
#                      2011-12         0.9227      1886.6034        2045051.0
#                      2012-13         4.3317      9381.0432        2163756.0
#                      2013-14         4.0486      8988.3238        2222588.0
#                      2014-15         3.4734      8645.5731        2487138.0
# ...                                     ...            ...              ...
# SW07  Scotland       2018-19         0.8217            NaN              NaN
#                      2019-20         0.8180            NaN              NaN
#                      2020-21         0.8250            NaN              NaN
#                      2021-22         0.7580            NaN              NaN
#                      2022-23         0.7500            NaN              NaN
#
#                               Indicator_new  Numerator_new  Denominator_new  \
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11         0.3300          637.0        1922292.0
#                      2011-12         0.7600         1554.0        2045051.0
#                      2012-13         3.6400         7883.0        2163756.0
#                      2013-14         3.4800         7726.0        2222588.0
#                      2014-15         3.0200         7517.0        2487138.0
# ...                                     ...            ...              ...
# SW07  Scotland       2018-19         0.8217            NaN              NaN
#                      2019-20         0.8180            NaN              NaN
#                      2020-21         0.8250            NaN              NaN
#                      2021-22         0.7580            NaN              NaN
#                      2022-23         0.7500            NaN              NaN
#
#                               Indicator_diff  Numerator_diff  \
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11            True            True
#                      2011-12            True            True
#                      2012-13            True            True
#                      2013-14            True            True
#                      2014-15            True            True
# ...                                      ...             ...
# SW07  Scotland       2018-19           False            True
#                      2019-20           False            True
#                      2020-21           False            True
#                      2021-22           False            True
#                      2022-23           False            True
#
#                               Denominator_diff  Record_Changed  \
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11             False            True
#                      2011-12             False            True
#                      2012-13             False            True
#                      2013-14             False            True
#                      2014-15             False            True
# ...                                        ...             ...
# SW07  Scotland       2018-19              True            True
#                      2019-20              True            True
#                      2020-21              True            True
#                      2021-22              True            True
#                      2022-23              True            True
#
#                                         Cols_Changed
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11    Indicator, Numerator
#                      2011-12    Indicator, Numerator
#                      2012-13    Indicator, Numerator
#                      2013-14    Indicator, Numerator
#                      2014-15    Indicator, Numerator
# ...                                              ...
# SW07  Scotland       2018-19  Numerator, Denominator
#                      2019-20  Numerator, Denominator
#                      2020-21  Numerator, Denominator
#                      2021-22  Numerator, Denominator
#                      2022-23  Numerator, Denominator
#
# [31402 rows x 11 columns]

# %%
from google.colab import files
diff_out. to_excel('diff_out.xlsx')
files.download('diff_out.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# Empty DataFrame
# Columns: [ExpenditureCash_old, ExpenditureCash_new, ExpenditureCash_diff, Record_Changed, Cols_Changed]
# Index: []

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 228    Aberdeen City        CHN12a  2019-20          849.3100
# 229    Aberdeen City        CHN12a  2020-21          866.1900
# 230    Aberdeen City        CHN12a  2021-22          957.2600
# 239    Aberdeen City        CHN12b  2019-20          511.0000
# 240    Aberdeen City        CHN12b  2020-21          578.0000
# ...              ...           ...      ...               ...
# 35761       Scotland          SW02  2019-20            0.0769
# 35762       Scotland          SW02  2022-23            0.0863
# 35763       Scotland         SW03a  2022-23            0.6154
# 35764       Scotland          SW05  2021-22          659.1519
# 35765       Scotland          SW05  2022-23          677.1817
#
#        NumeratorCash_LA  DenominatorCash_LA      _merge
# 228                 NaN                 NaN   left_only
# 229                 NaN                 NaN   left_only
# 230                 NaN                 NaN   left_only
# 239                 NaN                 NaN   left_only
# 240                 NaN                 NaN   left_only
# ...                 ...                 ...         ...
# 35761       265984.0000         3458888.245  right_only
# 35762       371997.7443         4308343.000  right_only
# 35763               NaN                 NaN  right_only
# 35764       957925.6043           27947.500  right_only
# 35765       994692.0000           28247.500  right_only
#
# [4555 rows x 7 columns]

# %%
old_df
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 0      Aberdeen City         C&L01  2010-11             0.330
# 1      Aberdeen City         C&L01  2011-12             0.760
# 2      Aberdeen City         C&L01  2012-13             3.640
# 3      Aberdeen City         C&L01  2013-14             3.480
# 4      Aberdeen City         C&L01  2014-15             3.020
# ...              ...           ...      ...               ...
# 32561       Scotland          SW07  2019-20             0.818
# 32562       Scotland          SW07  2020-21             0.825
# 32563       Scotland          SW07  2021-22             0.758
# 32564       Scotland          SW07  2022-23             0.750
# 32565       Scotland        CHN20a  2020-21            11.870
#
#        NumeratorCash_LA  DenominatorCash_LA
# 0                 637.0           1922292.0
# 1                1554.0           2045051.0
# 2                7883.0           2163756.0
# 3                7726.0           2222588.0
# 4                7517.0           2487138.0
# ...                 ...                 ...
# 32561               NaN                 NaN
# 32562               NaN                 NaN
# 32563               NaN                 NaN
# 32564               NaN                 NaN
# 32565               NaN                 NaN
#
# [32566 rows x 6 columns]

# %%
new_df
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 0      Aberdeen City         C&L01  2010-11             0.330
# 1      Aberdeen City         C&L01  2011-12             0.760
# 2      Aberdeen City         C&L01  2012-13             3.640
# 3      Aberdeen City         C&L01  2013-14             3.480
# 4      Aberdeen City         C&L01  2014-15             3.020
# ...              ...           ...      ...               ...
# 34406       Scotland          SW07  2019-20             0.818
# 34407       Scotland          SW07  2020-21             0.825
# 34408       Scotland          SW07  2021-22             0.758
# 34409       Scotland          SW07  2022-23             0.750
# 34410       Scotland        CHN20a  2020-21            11.870
#
#        NumeratorCash_LA  DenominatorCash_LA
# 0                 637.0           1922292.0
# 1                1554.0           2045051.0
# 2                7883.0           2163756.0
# 3                7726.0           2222588.0
# 4                7517.0           2487138.0
# ...                 ...                 ...
# 34406               NaN                 NaN
# 34407               NaN                 NaN
# 34408               NaN                 NaN
# 34409               NaN                 NaN
# 34410               NaN                 NaN
#
# [34411 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','IndicatorCode','Year_new'], right_on=['LocalAuthority','IndicatorCode','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([   12,    25,    38, ..., 34325, 34338, 34384])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["IndicatorCode", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#             LocalAuthority     Code     Year  Indicator  Numerator  \
# 456          Aberdeen City  CORP06a  2022-23     5.5605    9842.00
# 469          Aberdeen City  CORP06b  2022-23    13.8537   68479.00
# 4489      Clackmannanshire  CORP03b  2022-23     0.5982      67.00
# 4497      Clackmannanshire  CORP03c  2022-23     0.0208      16.86
# 10656    East Renfrewshire  CORP06a  2022-23     4.1353    5947.00
# 10669    East Renfrewshire  CORP06b  2022-23    12.3578   32241.00
# 27763       South Ayrshire   CORP04  2022-23     6.6542  374325.00
# 27815       South Ayrshire   CORP08  2022-23     0.9538   83694.00
# 374          Aberdeen City    CHN24  2021-22     0.2049        NaN
# 1403         Aberdeenshire    CHN24  2021-22     0.1602        NaN
# 2439                 Angus    CHN24  2021-22     0.2419        NaN
# 3475         Argyll & Bute    CHN24  2021-22     0.2171        NaN
# 4443      Clackmannanshire    CHN24  2021-22     0.2826        NaN
# 5474   Dumfries & Galloway    CHN24  2021-22     0.2604        NaN
# 6454           Dundee City    CHN24  2021-22     0.2712        NaN
# 7490         East Ayrshire    CHN24  2021-22     0.2719        NaN
# 8526   East Dunbartonshire    CHN24  2021-22     0.1494        NaN
# 9559          East Lothian    CHN24  2021-22     0.2113        NaN
# 10580    East Renfrewshire    CHN24  2021-22     0.1444        NaN
# 11612       Edinburgh City    CHN24  2021-22     0.1954        NaN
# 12591          Eilean Siar    CHN24  2021-22     0.1980        NaN
# 13561              Falkirk    CHN24  2021-22     0.2534        NaN
# 14597                 Fife    CHN24  2021-22     0.2613        NaN
# 15633         Glasgow City    CHN24  2021-22     0.3202        NaN
# 16613             Highland    CHN24  2021-22     0.2279        NaN
# 17642           Inverclyde    CHN24  2021-22     0.2437        NaN
# 18609           Midlothian    CHN24  2021-22     0.2274        NaN
# 19628                Moray    CHN24  2021-22     0.2407        NaN
# 20654       North Ayrshire    CHN24  2021-22     0.2896        NaN
# 21688    North Lanarkshire    CHN24  2021-22     0.2662        NaN
# 22680       Orkney Islands    CHN24  2021-22     0.2009        NaN
# 23705      Perth & Kinross    CHN24  2021-22     0.2190        NaN
# 24738         Renfrewshire    CHN24  2021-22     0.2334        NaN
# 25771     Scottish Borders    CHN24  2021-22     0.2338        NaN
# 26700     Shetland Islands    CHN24  2021-22     0.1544        NaN
# 27715       South Ayrshire    CHN24  2021-22     0.2442        NaN
# 28746    South Lanarkshire    CHN24  2021-22     0.2284        NaN
# 29782             Stirling    CHN24  2021-22     0.2079        NaN
# 30816  West Dunbartonshire    CHN24  2021-22     0.2764        NaN
# 31851         West Lothian    CHN24  2021-22     0.2391        NaN
# 32512                  NaN      NaN      NaN        NaN        NaN
#
#        Denominator
# 456        1770.00
# 469        4943.00
# 4489        112.00
# 4497         16.51
# 10656      1438.00
# 10669      2609.00
# 27763     56254.00
# 27815     87746.00
# 374            NaN
# 1403           NaN
# 2439           NaN
# 3475           NaN
# 4443           NaN
# 5474           NaN
# 6454           NaN
# 7490           NaN
# 8526           NaN
# 9559           NaN
# 10580          NaN
# 11612          NaN
# 12591          NaN
# 13561          NaN
# 14597          NaN
# 15633          NaN
# 16613          NaN
# 17642          NaN
# 18609          NaN
# 19628          NaN
# 20654          NaN
# 21688          NaN
# 22680          NaN
# 23705          NaN
# 24738          NaN
# 25771          NaN
# 26700          NaN
# 27715          NaN
# 28746          NaN
# 29782          NaN
# 30816          NaN
# 31851          NaN
# 32512          NaN

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 12     Aberdeen City         C&L01  2022-23            4.2400
# 25     Aberdeen City         C&L02  2022-23            2.4400
# 38     Aberdeen City         C&L03  2022-23            3.1300
# 51     Aberdeen City         C&L04  2022-23        28391.1500
# 100    Aberdeen City         CHN01  2022-23         6393.6000
# ...              ...           ...      ...               ...
# 34255       Scotland      FINSUS04  2022-23            0.2097
# 34265       Scotland      FINSUS05  2022-23            0.9871
# 34325       Scotland          SW01  2022-23           36.8600
# 34338       Scotland          SW02  2022-23            0.0863
# 34384       Scotland          SW05  2022-23          677.1817
#
#        NumeratorCash_LA  DenominatorCash_LA
# 12         7.352000e+03           1734240.0
# 25         4.025000e+03           1648447.0
# 38         4.190000e+03           1339942.0
# 51         6.457000e+03            227430.0
# 100        9.317400e+04             14573.0
# ...                 ...                 ...
# 34255               NaN                 NaN
# 34265      1.330451e+07          13478604.0
# 34325      7.523644e+05          20410000.0
# 34338      3.719977e+05           4308343.0
# 34384      9.946920e+05             28247.5
#
# [1845 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 0      Aberdeen City         C&L01  2010-11             0.330
# 1      Aberdeen City         C&L01  2011-12             0.760
# 2      Aberdeen City         C&L01  2012-13             3.640
# 3      Aberdeen City         C&L01  2013-14             3.480
# 4      Aberdeen City         C&L01  2014-15             3.020
# ...              ...           ...      ...               ...
# 32561       Scotland          SW07  2019-20             0.818
# 32562       Scotland          SW07  2020-21             0.825
# 32563       Scotland          SW07  2021-22             0.758
# 32564       Scotland          SW07  2022-23             0.750
# 32565       Scotland        CHN20a  2020-21            11.870
#
#        NumeratorCash_LA  DenominatorCash_LA
# 0                 637.0           1922292.0
# 1                1554.0           2045051.0
# 2                7883.0           2163756.0
# 3                7726.0           2222588.0
# 4                7517.0           2487138.0
# ...                 ...                 ...
# 32561               NaN                 NaN
# 32562               NaN                 NaN
# 32563               NaN                 NaN
# 32564               NaN                 NaN
# 32565               NaN                 NaN
#
# [32566 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True, False, False],
#        [ True,  True,  True,  True, False, False],
#        [ True,  True,  True,  True, False, False]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([   48,    48,    49, ..., 32564, 32565, 32565])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Indicator'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-4fdcc668f1cd> in <cell line: 4>()
#       2 change_df = old_df.loc[rows]
#       3 AddNew_df = new_update.loc[rows]
# ----> 4 change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
#       5 change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
#       6 change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3805             if self.columns.nlevels > 1:
#    3806                 return self._getitem_multilevel(key)
# -> 3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#    3809                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Indicator'

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#        index    Code       LocalAuthority     Year   Indicator New_Indicator  \
# 110      407   C&L02        Aberdeen City  2021-22      2.4476        2.1544
# 506      803   C&L03        Aberdeen City  2021-22      3.1229       47.2555
# 865     1162   C&L04        Aberdeen City  2021-22  14269.6162    21752.0543
# 2317    2614   CHN01        Aberdeen City  2021-22   5902.8563     5711.4908
# 2713    3010   CHN02        Aberdeen City  2021-22   7107.2086     7866.6148
# ...      ...     ...                  ...      ...         ...           ...
# 23235  23532  ENV04e       South Ayrshire  2007-11      0.4461     4372.3525
# 23247  23544  ENV04e    South Lanarkshire  2007-11      0.3873    10411.2838
# 23259  23556  ENV04e             Stirling  2007-11      0.4834     3608.1957
# 23271  23568  ENV04e  West Dunbartonshire  2007-11      0.3585     11269.645
# 23283  23580  ENV04e         West Lothian  2007-11      0.2853    15435.0184
#
#         Numerator New_Numerator  Denominator New_Denominator
# 110     3297.3084     3192.3941    1347180.0       1481816.0
# 506     3718.9642      415.6607    1190854.0          8796.0
# 865     3245.0000        1875.0     227430.0         86220.0
# 2317   83136.1361       52134.0      14084.0          9128.0
# 2713   71363.7459       59298.0      10041.0          7538.0
# ...           ...           ...          ...             ...
# 23235         NaN       1374.49          NaN        314360.0
# 23247         NaN      953.4628          NaN         91580.0
# 23259         NaN      324.2318          NaN         89860.0
# 23271         NaN     2052.6478          NaN        182140.0
# 23283         NaN      3535.563          NaN        229060.0
#
# [31061 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Jul2024.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_data_Aug2024.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#            Code    LocalAuthority     Year Indicator Numerator Denominator
# 13        C&L01     Aberdeen City  2023-24       nan       nan         nan
# 27        C&L01     Aberdeenshire  2023-24       nan       nan  1846056.00
# 41        C&L01             Angus  2023-24       nan       nan   783913.00
# 55        C&L01     Argyll & Bute  2023-24       nan       nan   582515.00
# 69        C&L01  Clackmannanshire  2023-24       nan       nan         nan
# ...         ...               ...      ...       ...       ...         ...
# 37327  FINSUS03          Scotland  2023-24       nan       nan         nan
# 37341  FINSUS04          Scotland  2023-24       nan       nan         nan
# 37412      SW01          Scotland  2023-24       nan       nan         nan
# 37426      SW02          Scotland  2023-24       nan       nan         nan
# 37477      SW05          Scotland  2023-24       nan       nan         nan
#
# [1122 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                       old                             new  \
#                                 Indicator Numerator Denominator Indicator
# Code     LocalAuthority Year
# C&L01    Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                         2011-12      0.76   1554.00  2045051.00      0.76
#                         2012-13      3.64   7883.00  2163756.00      3.64
#                         2013-14      3.48   7726.00  2222588.00      3.48
#                         2014-15      3.02   7517.00  2487138.00      3.02
# ...                                   ...       ...         ...       ...
# FINSUS03 Scotland       2023-24       NaN       NaN         NaN       nan
# FINSUS04 Scotland       2023-24       NaN       NaN         NaN       nan
# SW01     Scotland       2023-24       NaN       NaN         NaN       nan
# SW02     Scotland       2023-24       NaN       NaN         NaN       nan
# SW05     Scotland       2023-24       NaN       NaN         NaN       nan
#
#
#                                 Numerator Denominator
# Code     LocalAuthority Year
# C&L01    Aberdeen City  2010-11    637.00  1922292.00
#                         2011-12   1554.00  2045051.00
#                         2012-13   7883.00  2163756.00
#                         2013-14   7726.00  2222588.00
#                         2014-15   7517.00  2487138.00
# ...                                   ...         ...
# FINSUS03 Scotland       2023-24       nan         nan
# FINSUS04 Scotland       2023-24       nan         nan
# SW01     Scotland       2023-24       nan         nan
# SW02     Scotland       2023-24       nan         nan
# SW05     Scotland       2023-24       nan         nan
#
# [37505 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                           old                             new  \
#                                     Indicator Numerator Denominator Indicator
# Code         LocalAuthority Year
# C&L01        Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                             2011-12      0.76   1554.00  2045051.00      0.76
#                             2012-13      3.64   7883.00  2163756.00      3.64
#                             2013-14      3.48   7726.00  2222588.00      3.48
#                             2014-15      3.02   7517.00  2487138.00      3.02
# ...                                       ...       ...         ...       ...
# CORP06b      Scotland       2023-24       NaN       NaN         NaN     14.16
# CORP08       Scotland       2023-24       NaN       NaN         NaN      0.95
# CORP11       Scotland       2023-24       NaN       NaN         NaN      1.29
# CORP12       Scotland       2023-24       NaN       NaN         NaN      1.01
# CORP-ASSET01 Scotland       2023-24       NaN       NaN         NaN      0.84
#
#
#                                        Numerator  Denominator
# Code         LocalAuthority Year
# C&L01        Aberdeen City  2010-11       637.00   1922292.00
#                             2011-12      1554.00   2045051.00
#                             2012-13      7883.00   2163756.00
#                             2013-14      7726.00   2222588.00
#                             2014-15      7517.00   2487138.00
# ...                                          ...          ...
# CORP06b      Scotland       2023-24   1160233.00     81914.00
# CORP08       Scotland       2023-24          nan   2400592.00
# CORP11       Scotland       2023-24  49947258.00  38734050.00
# CORP12       Scotland       2023-24  84874290.00  83729000.00
# CORP-ASSET01 Scotland       2023-24      4395.00          nan
#
# [18652 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3758         if is_single_key:
#    3759             if self.columns.nlevels > 1:
# -> 3760                 return self._getitem_multilevel(key)
#    3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3813     def _getitem_multilevel(self, key):
#    3814         # self.columns is a MultiIndex
# -> 3815         loc = self.columns.get_loc(key)
#    3816         if isinstance(loc, (slice, np.ndarray)):
#    3817             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2810
#    2811         if not isinstance(key, tuple):
# -> 2812             loc = self._get_level_indexer(key, level=0)
#    2813             return _maybe_to_slice(loc)
#    2814
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                       old                             new  \
#                                 Indicator Numerator Denominator Indicator
# Code     LocalAuthority Year
# C&L01    Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                         2011-12      0.76   1554.00  2045051.00      0.76
#                         2012-13      3.64   7883.00  2163756.00      3.64
#                         2013-14      3.48   7726.00  2222588.00      3.48
#                         2014-15      3.02   7517.00  2487138.00      3.02
# ...                                   ...       ...         ...       ...
# FINSUS03 Scotland       2023-24       NaN       NaN         NaN       nan
# FINSUS04 Scotland       2023-24       NaN       NaN         NaN       nan
# SW01     Scotland       2023-24       NaN       NaN         NaN       nan
# SW02     Scotland       2023-24       NaN       NaN         NaN       nan
# SW05     Scotland       2023-24       NaN       NaN         NaN       nan
#
#
#                                 Numerator Denominator
# Code     LocalAuthority Year
# C&L01    Aberdeen City  2010-11    637.00  1922292.00
#                         2011-12   1554.00  2045051.00
#                         2012-13   7883.00  2163756.00
#                         2013-14   7726.00  2222588.00
#                         2014-15   7517.00  2487138.00
# ...                                   ...         ...
# FINSUS03 Scotland       2023-24       nan         nan
# FINSUS04 Scotland       2023-24       nan         nan
# SW01     Scotland       2023-24       nan         nan
# SW02     Scotland       2023-24       nan         nan
# SW05     Scotland       2023-24       nan         nan
#
# [37505 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# <ipython-input-19-59e016041985>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)
#                                     Indicator_old Numerator_old  \
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23          9.04      13216.00
# CORP06b North Ayrshire      2022-23         14.12      67592.00
# CORP08  East Lothian        2022-23          0.88      69713.00
# ECON06  Aberdeen City       2022-23      86839.91      19750.00
#         Aberdeenshire       2022-23     151509.38      39800.00
#         Angus               2022-23      33000.34       3832.00
#         Argyll & Bute       2022-23     123103.69      10614.00
#         Clackmannanshire    2022-23      84303.45       4345.00
#         Dumfries & Galloway 2022-23     103931.72      15464.00
#         Dundee City         2022-23     104217.44      15395.00
#         East Ayrshire       2022-23      81757.09       9976.00
#         East Dunbartonshire 2022-23      50358.13       5484.00
#         East Lothian        2022-23     219757.25      24081.00
#         East Renfrewshire   2022-23      55187.41       5330.00
#         Edinburgh City      2022-23      98660.89      51942.00
#         Eilean Siar         2022-23     332507.51       8858.00
#         Falkirk             2022-23      96894.84      15571.00
#         Fife                2022-23      99023.30      37107.00
#         Glasgow City        2022-23     179966.31     114302.00
#         Highland            2022-23     106805.01      25426.00
#         Inverclyde          2022-23     244185.14      18729.00
#         Midlothian          2022-23      52703.84       4990.00
#         Moray               2022-23      80510.32       7762.00
#         North Ayrshire      2022-23     168484.58      22614.00
#         North Lanarkshire   2022-23     131816.05      45002.00
#         Orkney Islands      2022-23     151774.62       3421.00
#         Perth & Kinross     2022-23      91710.55      14106.00
#         Renfrewshire        2022-23     125430.70      22570.00
#         Scottish Borders    2022-23      83149.46       9647.00
#         Shetland Islands    2022-23     260156.93       5968.00
#         South Ayrshire      2022-23      86554.02       9733.00
#         South Lanarkshire   2022-23      70043.08      22598.00
#         Stirling            2022-23      45811.49       4282.00
#         West Dunbartonshire 2022-23     121335.00      10652.00
#         West Lothian        2022-23      87487.88      16236.00
# ENV01a  Scottish Borders    2022-23         59.70       3832.00
# ENV02a  Scottish Borders    2022-23         95.23       6113.00
# CORP06a Scotland            2022-23          6.81     383063.00
# CORP06b Scotland            2022-23         13.21    2123233.00
# CORP08  Scotland            2022-23          0.91    3892004.00
# ECON06  Scotland            2022-23     114160.29     625587.00
# ENV01a  Scotland            2022-23         75.51     208762.00
# ENV02a  Scotland            2022-23         95.21     263236.00
#
#                                     Denominator_old Indicator_new  \
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23         1462.00          7.60
# CORP06b North Ayrshire      2022-23         4787.00         14.32
# CORP08  East Lothian        2022-23        78781.00          0.83
# ECON06  Aberdeen City       2022-23       227430.00      88094.92
#         Aberdeenshire       2022-23       262690.00     150900.47
#         Angus               2022-23       116120.00      33420.55
#         Argyll & Bute       2022-23        86220.00     120723.38
#         Clackmannanshire    2022-23        51540.00       8437.06
#         Dumfries & Galloway 2022-23       148790.00     298821.26
#         Dundee City         2022-23       147720.00     105611.58
#         East Ayrshire       2022-23       122020.00      67246.38
#         East Dunbartonshire 2022-23       108900.00      45551.96
#         East Lothian        2022-23       109580.00     220967.15
#         East Renfrewshire   2022-23        96580.00      47398.84
#         Edinburgh City      2022-23       526470.00     534602.72
#         Eilean Siar         2022-23        26640.00      55904.07
#         Falkirk             2022-23       160700.00      41931.92
#         Fife                2022-23       374730.00      59579.01
#         Glasgow City        2022-23       635130.00     484926.39
#         Highland            2022-23       238060.00     324559.61
#         Inverclyde          2022-23        76700.00     193022.78
#         Midlothian          2022-23        94680.00      52927.45
#         Moray               2022-23        96410.00     297166.92
#         North Ayrshire      2022-23       134220.00     169405.95
#         North Lanarkshire   2022-23       341400.00     131997.77
#         Orkney Islands      2022-23        22540.00     155358.76
#         Perth & Kinross     2022-23       153810.00      93343.04
#         Renfrewshire        2022-23       179940.00     122436.80
#         Scottish Borders    2022-23       116020.00      82580.04
#         Shetland Islands    2022-23        22940.00     259252.82
#         South Ayrshire      2022-23       112450.00      87244.53
#         South Lanarkshire   2022-23       322630.00      69016.28
#         Stirling            2022-23        93470.00      46276.88
#         West Dunbartonshire 2022-23        87790.00     120675.20
#         West Lothian        2022-23       185580.00      89346.25
# ENV01a  Scottish Borders    2022-23        64189.00         61.92
# ENV02a  Scottish Borders    2022-23        64189.00         98.78
# CORP06a Scotland            2022-23        56225.00          6.78
# CORP06b Scotland            2022-23       160673.00         13.22
# CORP08  Scotland            2022-23      4296380.00          0.90
# ECON06  Scotland            2022-23      5479900.00     114835.07
# ENV01a  Scotland            2022-23      2764772.00         75.57
# ENV02a  Scotland            2022-23      2764772.00         95.29
#
#                                     Numerator_new Denominator_new  \
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23      11117.00         1462.00
# CORP06b North Ayrshire      2022-23      68550.00         4787.00
# CORP08  East Lothian        2022-23      69713.00        84045.00
# ECON06  Aberdeen City       2022-23      19750.00       227430.00
#         Aberdeenshire       2022-23      39800.00       262690.00
#         Angus               2022-23       3832.00       116120.00
#         Argyll & Bute       2022-23      10614.00        86220.00
#         Clackmannanshire    2022-23       4345.00        51540.00
#         Dumfries & Galloway 2022-23      15464.00       148790.00
#         Dundee City         2022-23      15395.00       147720.00
#         East Ayrshire       2022-23       9976.00       122020.00
#         East Dunbartonshire 2022-23       5484.00       108900.00
#         East Lothian        2022-23      24081.00       109580.00
#         East Renfrewshire   2022-23       5330.00        96580.00
#         Edinburgh City      2022-23      51942.00       526470.00
#         Eilean Siar         2022-23       8858.00        26640.00
#         Falkirk             2022-23      15571.00       160700.00
#         Fife                2022-23      37107.00       374730.00
#         Glasgow City        2022-23     114302.00       635130.00
#         Highland            2022-23      25426.00       238060.00
#         Inverclyde          2022-23      18729.00        76700.00
#         Midlothian          2022-23       4990.00        94680.00
#         Moray               2022-23       7762.00        96410.00
#         North Ayrshire      2022-23      22614.00       134220.00
#         North Lanarkshire   2022-23      45002.00       341400.00
#         Orkney Islands      2022-23       3421.00        22540.00
#         Perth & Kinross     2022-23      14106.00       153810.00
#         Renfrewshire        2022-23      22570.00       179940.00
#         Scottish Borders    2022-23       9647.00       116020.00
#         Shetland Islands    2022-23       5968.00        22940.00
#         South Ayrshire      2022-23       9733.00       112450.00
#         South Lanarkshire   2022-23      22598.00       322630.00
#         Stirling            2022-23       4282.00        93470.00
#         West Dunbartonshire 2022-23      10652.00        87790.00
#         West Lothian        2022-23      16236.00       185580.00
# ENV01a  Scottish Borders    2022-23       3832.00        61886.00
# ENV02a  Scottish Borders    2022-23       6113.00        61886.00
# CORP06a Scotland            2022-23     380964.00        56225.00
# CORP06b Scotland            2022-23    2124191.00       160673.00
# CORP08  Scotland            2022-23    3892004.00      4301644.00
# ECON06  Scotland            2022-23     625587.00      5479900.00
# ENV01a  Scotland            2022-23     208762.00      2762469.00
# ENV02a  Scotland            2022-23     263236.00      2762469.00
#
#                                      Indicator_diff  Numerator_diff  \
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23            True            True
# CORP06b North Ayrshire      2022-23            True            True
# CORP08  East Lothian        2022-23            True           False
# ECON06  Aberdeen City       2022-23            True           False
#         Aberdeenshire       2022-23            True           False
#         Angus               2022-23            True           False
#         Argyll & Bute       2022-23            True           False
#         Clackmannanshire    2022-23            True           False
#         Dumfries & Galloway 2022-23            True           False
#         Dundee City         2022-23            True           False
#         East Ayrshire       2022-23            True           False
#         East Dunbartonshire 2022-23            True           False
#         East Lothian        2022-23            True           False
#         East Renfrewshire   2022-23            True           False
#         Edinburgh City      2022-23            True           False
#         Eilean Siar         2022-23            True           False
#         Falkirk             2022-23            True           False
#         Fife                2022-23            True           False
#         Glasgow City        2022-23            True           False
#         Highland            2022-23            True           False
#         Inverclyde          2022-23            True           False
#         Midlothian          2022-23            True           False
#         Moray               2022-23            True           False
#         North Ayrshire      2022-23            True           False
#         North Lanarkshire   2022-23            True           False
#         Orkney Islands      2022-23            True           False
#         Perth & Kinross     2022-23            True           False
#         Renfrewshire        2022-23            True           False
#         Scottish Borders    2022-23            True           False
#         Shetland Islands    2022-23            True           False
#         South Ayrshire      2022-23            True           False
#         South Lanarkshire   2022-23            True           False
#         Stirling            2022-23            True           False
#         West Dunbartonshire 2022-23            True           False
#         West Lothian        2022-23            True           False
# ENV01a  Scottish Borders    2022-23            True           False
# ENV02a  Scottish Borders    2022-23            True           False
# CORP06a Scotland            2022-23            True            True
# CORP06b Scotland            2022-23            True            True
# CORP08  Scotland            2022-23            True           False
# ECON06  Scotland            2022-23            True           False
# ENV01a  Scotland            2022-23            True           False
# ENV02a  Scotland            2022-23            True           False
#
#                                      Denominator_diff  Record_Changed  \
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23             False            True
# CORP06b North Ayrshire      2022-23             False            True
# CORP08  East Lothian        2022-23              True            True
# ECON06  Aberdeen City       2022-23             False            True
#         Aberdeenshire       2022-23             False            True
#         Angus               2022-23             False            True
#         Argyll & Bute       2022-23             False            True
#         Clackmannanshire    2022-23             False            True
#         Dumfries & Galloway 2022-23             False            True
#         Dundee City         2022-23             False            True
#         East Ayrshire       2022-23             False            True
#         East Dunbartonshire 2022-23             False            True
#         East Lothian        2022-23             False            True
#         East Renfrewshire   2022-23             False            True
#         Edinburgh City      2022-23             False            True
#         Eilean Siar         2022-23             False            True
#         Falkirk             2022-23             False            True
#         Fife                2022-23             False            True
#         Glasgow City        2022-23             False            True
#         Highland            2022-23             False            True
#         Inverclyde          2022-23             False            True
#         Midlothian          2022-23             False            True
#         Moray               2022-23             False            True
#         North Ayrshire      2022-23             False            True
#         North Lanarkshire   2022-23             False            True
#         Orkney Islands      2022-23             False            True
#         Perth & Kinross     2022-23             False            True
#         Renfrewshire        2022-23             False            True
#         Scottish Borders    2022-23             False            True
#         Shetland Islands    2022-23             False            True
#         South Ayrshire      2022-23             False            True
#         South Lanarkshire   2022-23             False            True
#         Stirling            2022-23             False            True
#         West Dunbartonshire 2022-23             False            True
#         West Lothian        2022-23             False            True
# ENV01a  Scottish Borders    2022-23              True            True
# ENV02a  Scottish Borders    2022-23              True            True
# CORP06a Scotland            2022-23             False            True
# CORP06b Scotland            2022-23             False            True
# CORP08  Scotland            2022-23              True            True
# ECON06  Scotland            2022-23             False            True
# ENV01a  Scotland            2022-23              True            True
# ENV02a  Scotland            2022-23              True            True
#
#                                                Cols_Changed
# Code    LocalAuthority      Year
# CORP06a North Ayrshire      2022-23    Indicator, Numerator
# CORP06b North Ayrshire      2022-23    Indicator, Numerator
# CORP08  East Lothian        2022-23  Indicator, Denominator
# ECON06  Aberdeen City       2022-23               Indicator
#         Aberdeenshire       2022-23               Indicator
#         Angus               2022-23               Indicator
#         Argyll & Bute       2022-23               Indicator
#         Clackmannanshire    2022-23               Indicator
#         Dumfries & Galloway 2022-23               Indicator
#         Dundee City         2022-23               Indicator
#         East Ayrshire       2022-23               Indicator
#         East Dunbartonshire 2022-23               Indicator
#         East Lothian        2022-23               Indicator
#         East Renfrewshire   2022-23               Indicator
#         Edinburgh City      2022-23               Indicator
#         Eilean Siar         2022-23               Indicator
#         Falkirk             2022-23               Indicator
#         Fife                2022-23               Indicator
#         Glasgow City        2022-23               Indicator
#         Highland            2022-23               Indicator
#         Inverclyde          2022-23               Indicator
#         Midlothian          2022-23               Indicator
#         Moray               2022-23               Indicator
#         North Ayrshire      2022-23               Indicator
#         North Lanarkshire   2022-23               Indicator
#         Orkney Islands      2022-23               Indicator
#         Perth & Kinross     2022-23               Indicator
#         Renfrewshire        2022-23               Indicator
#         Scottish Borders    2022-23               Indicator
#         Shetland Islands    2022-23               Indicator
#         South Ayrshire      2022-23               Indicator
#         South Lanarkshire   2022-23               Indicator
#         Stirling            2022-23               Indicator
#         West Dunbartonshire 2022-23               Indicator
#         West Lothian        2022-23               Indicator
# ENV01a  Scottish Borders    2022-23  Indicator, Denominator
# ENV02a  Scottish Borders    2022-23  Indicator, Denominator
# CORP06a Scotland            2022-23    Indicator, Numerator
# CORP06b Scotland            2022-23    Indicator, Numerator
# CORP08  Scotland            2022-23  Indicator, Denominator
# ECON06  Scotland            2022-23               Indicator
# ENV01a  Scotland            2022-23  Indicator, Denominator
# ENV02a  Scotland            2022-23  Indicator, Denominator

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5868
#    5869         if missing:
# -> 5870             raise KeyError(f"None of {missing} are in the columns")
#    5871
#    5872         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#          Code LocalAuthority     Year Indicator  Numerator Denominator  \
# 13174  CLIM01  Aberdeen City  2010-11      7.79        nan         nan
# 13175  CLIM01  Aberdeen City  2011-12      7.20        nan         nan
# 13176  CLIM01  Aberdeen City  2012-13      7.43        nan         nan
# 13177  CLIM01  Aberdeen City  2013-14      7.03        nan         nan
# 13179  CLIM01  Aberdeen City  2015-16      6.04        nan         nan
# ...       ...            ...      ...       ...        ...         ...
# 37297   SW04b       Scotland  2023-24      0.70        nan         nan
# 37298   SW04c       Scotland  2023-24      0.72        nan         nan
# 37299   SW04d       Scotland  2023-24      0.60        nan         nan
# 37300    SW06       Scotland  2022-23    102.22   97128.00   950151.00
# 37301    SW06       Scotland  2023-24    103.95  102941.00   990306.00
#
#            _merge
# 13174   left_only
# 13175   left_only
# 13176   left_only
# 13177   left_only
# 13179   left_only
# ...           ...
# 37297  right_only
# 37298  right_only
# 37299  right_only
# 37300  right_only
# 37301  right_only
#
# [2049 rows x 7 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36157   SW07       Scotland  2019-20      0.82       nan         nan
# 36158   SW07       Scotland  2020-21      0.82       nan         nan
# 36159   SW07       Scotland  2021-22      0.76       nan         nan
# 36160   SW07       Scotland  2022-23      0.75       nan         nan
# 36161   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36162 rows x 6 columns]

# %%
new_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36388   SW07       Scotland  2019-20      0.82       nan         nan
# 36389   SW07       Scotland  2020-21      0.82       nan         nan
# 36390   SW07       Scotland  2021-22      0.76       nan         nan
# 36391   SW07       Scotland  2022-23      0.75       nan         nan
# 36392   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36393 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([   13,    27,    41, ..., 37412, 37426, 37477])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#            Code    LocalAuthority     Year Indicator Numerator Denominator
# 13        C&L01     Aberdeen City  2023-24       nan       nan         nan
# 27        C&L01     Aberdeenshire  2023-24       nan       nan  1846056.00
# 41        C&L01             Angus  2023-24       nan       nan   783913.00
# 55        C&L01     Argyll & Bute  2023-24       nan       nan   582515.00
# 69        C&L01  Clackmannanshire  2023-24       nan       nan         nan
# ...         ...               ...      ...       ...       ...         ...
# 37327  FINSUS03          Scotland  2023-24       nan       nan         nan
# 37341  FINSUS04          Scotland  2023-24       nan       nan         nan
# 37412      SW01          Scotland  2023-24       nan       nan         nan
# 37426      SW02          Scotland  2023-24       nan       nan         nan
# 37477      SW05          Scotland  2023-24       nan       nan         nan
#
# [1112 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#            Code    LocalAuthority     Year New_Indicator New_Numerator  \
# 13        C&L01     Aberdeen City  2023-24           nan           nan
# 27        C&L01     Aberdeenshire  2023-24           nan           nan
# 41        C&L01             Angus  2023-24           nan           nan
# 55        C&L01     Argyll & Bute  2023-24           nan           nan
# 69        C&L01  Clackmannanshire  2023-24           nan           nan
# ...         ...               ...      ...           ...           ...
# 37327  FINSUS03          Scotland  2023-24           nan           nan
# 37341  FINSUS04          Scotland  2023-24           nan           nan
# 37412      SW01          Scotland  2023-24           nan           nan
# 37426      SW02          Scotland  2023-24           nan           nan
# 37477      SW05          Scotland  2023-24           nan           nan
#
#       New_Denominator
# 13                nan
# 27         1846056.00
# 41          783913.00
# 55          582515.00
# 69                nan
# ...               ...
# 37327             nan
# 37341             nan
# 37412             nan
# 37426             nan
# 37477             nan
#
# [1112 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36388   SW07       Scotland  2019-20      0.82       nan         nan
# 36389   SW07       Scotland  2020-21      0.82       nan         nan
# 36390   SW07       Scotland  2021-22      0.76       nan         nan
# 36391   SW07       Scotland  2022-23      0.75       nan         nan
# 36392   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36393 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([16358, 16358, 16774, 16774, 17463, 17463, 22975, 22975, 23391,
#        23391, 35794, 35794, 35807, 35807, 35833, 35833, 36001, 36001,
#        36014, 36014])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#           Code    LocalAuthority     Year Indicator New_Indicator   Numerator  \
# 16358  CORP06a    North Ayrshire  2022-23      9.04          7.60    13216.00
# 16774  CORP06b    North Ayrshire  2022-23     14.12         14.32    67592.00
# 17463   CORP08      East Lothian  2022-23      0.88          0.83    69713.00
# 22975   ENV01a  Scottish Borders  2022-23     59.70         61.92     3832.00
# 23391   ENV02a  Scottish Borders  2022-23     95.23         98.78     6113.00
# 35794  CORP06a          Scotland  2022-23      6.81          6.78   383063.00
# 35807  CORP06b          Scotland  2022-23     13.21         13.22  2123233.00
# 35833   CORP08          Scotland  2022-23      0.91          0.90  3892004.00
# 36001   ENV01a          Scotland  2022-23     75.51         75.57   208762.00
# 36014   ENV02a          Scotland  2022-23     95.21         95.29   263236.00
#
#       New_Numerator Denominator New_Denominator
# 16358      11117.00     1462.00         1462.00
# 16774      68550.00     4787.00         4787.00
# 17463      69713.00    78781.00        84045.00
# 22975       3832.00    64189.00        61886.00
# 23391       6113.00    64189.00        61886.00
# 35794     380964.00    56225.00        56225.00
# 35807    2124191.00   160673.00       160673.00
# 35833    3892004.00  4296380.00      4301644.00
# 36001     208762.00  2764772.00      2762469.00
# 36014     263236.00  2764772.00      2762469.00

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#       index    Code       LocalAuthority     Year Indicator New_Indicator  \
# 757   33038   SW04b        Aberdeen City  2023-24      0.63          0.74
# 789   33230   SW04c        Aberdeen City  2023-24      0.68          0.77
# 820   33422   SW04d        Aberdeen City  2023-24      0.48          0.57
# 1101  34422    SW06        Aberdeen City  2023-24       NaN        126.05
# 758   33044   SW04b        Aberdeenshire  2023-24      0.66          0.74
# ...     ...     ...                  ...      ...       ...           ...
# 723   13906  CLIM02             Stirling  2010-11      9.40          9.16
# 354   13534  CLIM01  West Dunbartonshire  2010-11      6.07          6.06
# 735   13918  CLIM02  West Dunbartonshire  2010-11      6.04          6.02
# 365   13546  CLIM01         West Lothian  2010-11      8.07          8.01
# 747   13930  CLIM02         West Lothian  2010-11      6.99          6.98
#
#      Numerator New_Numerator Denominator New_Denominator
# 757        nan           nan         nan             nan
# 789        nan           nan         nan             nan
# 820        nan           nan         nan             nan
# 1101       NaN       3835.00         NaN        30424.00
# 758        nan           nan         nan             nan
# ...        ...           ...         ...             ...
# 723        nan           nan         nan             nan
# 354        nan           nan         nan             nan
# 735        nan           nan         nan             nan
# 365        nan           nan         nan             nan
# 747        nan           nan         nan             nan
#
# [1140 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Final_Jan24.csv"
new_df = get_data(url_new)
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Table_Nov23.csv"
old_df = get_data(url_old)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#          Code LocalAuthority     Year Indicator  Numerator Denominator
# 61     C&L05a  Aberdeen City  2020-23      0.70        nan         nan
# 71     C&L05b  Aberdeen City  2020-23      0.87        nan         nan
# 81     C&L05c  Aberdeen City  2020-23      0.79        nan         nan
# 91     C&L05d  Aberdeen City  2020-23      0.73        nan         nan
# 222     CHN10  Aberdeen City  2020-23      0.72        nan         nan
# ...       ...            ...      ...       ...        ...         ...
# 35100  ENV01a       Scotland  2022-23     75.64  209129.00  2764772.00
# 35113  ENV02a       Scotland  2022-23     95.28  263416.00  2764772.00
# 35204  ENV04e       Scotland  2019-23      0.36        nan         nan
# 35264  ENV07a       Scotland  2020-23      0.78        nan         nan
# 35274  ENV07b       Scotland  2020-23      0.58        nan         nan
#
# [1017 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ECON09 Scotland       2022-23       NaN       NaN         NaN      0.12
# ECON10 Scotland       2022-23       NaN       NaN         NaN      0.23
# ENV04e Scotland       2019-23       NaN       NaN         NaN      0.36
# ENV07a Scotland       2020-23       NaN       NaN         NaN      0.78
# ENV07b Scotland       2020-23       NaN       NaN         NaN      0.58
#
#
#                               Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    637.00  1922292.00
#                       2011-12   1554.00  2045051.00
#                       2012-13   7883.00  2163756.00
#                       2013-14   7726.00  2222588.00
#                       2014-15   7517.00  2487138.00
# ...                                 ...         ...
# ECON09 Scotland       2022-23       nan         nan
# ECON10 Scotland       2022-23       nan         nan
# ENV04e Scotland       2019-23       nan         nan
# ENV07a Scotland       2020-23       nan         nan
# ENV07b Scotland       2020-23       nan         nan
#
# [35482 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# CLIM05 Scotland       2017-18       NaN       NaN         NaN     60.43
#                       2018-19       NaN       NaN         NaN     56.45
#                       2019-20       NaN       NaN         NaN     52.06
#                       2020-21       NaN       NaN         NaN     52.82
#                       2021-22       NaN       NaN         NaN     57.22
#
#
#                                Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11     637.00  1922292.00
#                       2011-12    1554.00  2045051.00
#                       2012-13    7883.00  2163756.00
#                       2013-14    7726.00  2222588.00
#                       2014-15    7517.00  2487138.00
# ...                                  ...         ...
# CLIM05 Scotland       2017-18  327834.30  5424800.00
#                       2018-19  306967.70  5438100.00
#                       2019-20  284444.01  5463300.00
#                       2020-21  288701.16  5466000.00
#                       2021-22  313548.16  5479900.00
#
# [18222 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3804         if is_single_key:
#    3805             if self.columns.nlevels > 1:
# -> 3806                 return self._getitem_multilevel(key)
#    3807             indexer = self.columns.get_loc(key)
#    3808             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3855     def _getitem_multilevel(self, key):
#    3856         # self.columns is a MultiIndex
# -> 3857         loc = self.columns.get_loc(key)
#    3858         if isinstance(loc, (slice, np.ndarray)):
#    3859             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key, method)
#    2914
#    2915         if not isinstance(key, tuple):
# -> 2916             loc = self._get_level_indexer(key, level=0)
#    2917             return _maybe_to_slice(loc)
#    2918
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3261         else:
#    3262
# -> 3263             idx = self._get_loc_single_level_index(level_index, key)
#    3264
#    3265             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2847             return -1
#    2848         else:
# -> 2849             return level_index.get_loc(key)
#    2850
#    2851     def get_loc(self, key, method=None):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
# -> 3804                 raise KeyError(key) from err
#    3805             except TypeError:
#    3806                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ECON09 Scotland       2022-23       NaN       NaN         NaN      0.12
# ECON10 Scotland       2022-23       NaN       NaN         NaN      0.23
# ENV04e Scotland       2019-23       NaN       NaN         NaN      0.36
# ENV07a Scotland       2020-23       NaN       NaN         NaN      0.78
# ENV07b Scotland       2020-23       NaN       NaN         NaN      0.58
#
#
#                               Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    637.00  1922292.00
#                       2011-12   1554.00  2045051.00
#                       2012-13   7883.00  2163756.00
#                       2013-14   7726.00  2222588.00
#                       2014-15   7517.00  2487138.00
# ...                                 ...         ...
# ECON09 Scotland       2022-23       nan         nan
# ECON10 Scotland       2022-23       nan         nan
# ENV04e Scotland       2019-23       nan         nan
# ENV07a Scotland       2020-23       nan         nan
# ENV07b Scotland       2020-23       nan         nan
#
# [35482 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                    Indicator_old  Numerator_old  \
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23           nan        6525.00
# ENV02a   Aberdeen City     2022-23           nan       14221.00
# CORP07   Aberdeenshire     2022-23          0.96   153239000.00
# ECON04   Angus             2022-23          0.42            nan
# CORP04   East Lothian      2022-23          7.93      416615.51
# ECON04   Eilean Siar       2022-23          0.29            nan
# FINSUS01 South Lanarkshire 2022-23          0.22            nan
# FINSUS03 South Lanarkshire 2022-23          0.05            nan
# FINSUS04 South Lanarkshire 2022-23          0.17            nan
# CORP04   Scotland          2022-23          6.84    18541998.48
# CORP07   Scotland          2022-23          0.96  2724082770.00
# ENV01a   Scotland          2022-23         79.20      209129.00
# ENV02a   Scotland          2022-23         99.76      263416.00
#
#                                    Denominator_old Indicator_new  \
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23             nan         52.46
# ENV02a   Aberdeen City     2022-23             nan        114.35
# CORP07   Aberdeenshire     2022-23    159540000.00          0.97
# ECON04   Angus             2022-23             nan          0.32
# CORP04   East Lothian      2022-23        52518.00          8.01
# ECON04   Eilean Siar       2022-23             nan          0.28
# FINSUS01 South Lanarkshire 2022-23             nan          0.21
# FINSUS03 South Lanarkshire 2022-23             nan          0.04
# FINSUS04 South Lanarkshire 2022-23             nan          0.14
# CORP04   Scotland          2022-23      2711494.00          6.84
# CORP07   Scotland          2022-23   2831919562.00          0.96
# ENV01a   Scotland          2022-23      2640403.00         75.64
# ENV02a   Scotland          2022-23      2640403.00         95.28
#
#                                     Numerator_new Denominator_new  \
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23        6525.00       124369.00
# ENV02a   Aberdeen City     2022-23       14221.00       124369.00
# CORP07   Aberdeenshire     2022-23   154629000.00    159537000.00
# ECON04   Angus             2022-23            nan             nan
# CORP04   East Lothian      2022-23      416615.51        51982.00
# ECON04   Eilean Siar       2022-23            nan             nan
# FINSUS01 South Lanarkshire 2022-23            nan             nan
# FINSUS03 South Lanarkshire 2022-23            nan             nan
# FINSUS04 South Lanarkshire 2022-23            nan             nan
# CORP04   Scotland          2022-23    18541998.48      2710958.00
# CORP07   Scotland          2022-23  2725472770.00   2831916562.00
# ENV01a   Scotland          2022-23      209129.00      2764772.00
# ENV02a   Scotland          2022-23      263416.00      2764772.00
#
#                                     Indicator_diff  Numerator_diff  \
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23            True           False
# ENV02a   Aberdeen City     2022-23            True           False
# CORP07   Aberdeenshire     2022-23            True            True
# ECON04   Angus             2022-23            True           False
# CORP04   East Lothian      2022-23            True           False
# ECON04   Eilean Siar       2022-23            True           False
# FINSUS01 South Lanarkshire 2022-23            True           False
# FINSUS03 South Lanarkshire 2022-23            True           False
# FINSUS04 South Lanarkshire 2022-23            True           False
# CORP04   Scotland          2022-23           False           False
# CORP07   Scotland          2022-23           False            True
# ENV01a   Scotland          2022-23            True           False
# ENV02a   Scotland          2022-23            True           False
#
#                                     Denominator_diff  Record_Changed  \
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23              True            True
# ENV02a   Aberdeen City     2022-23              True            True
# CORP07   Aberdeenshire     2022-23              True            True
# ECON04   Angus             2022-23             False            True
# CORP04   East Lothian      2022-23              True            True
# ECON04   Eilean Siar       2022-23             False            True
# FINSUS01 South Lanarkshire 2022-23             False            True
# FINSUS03 South Lanarkshire 2022-23             False            True
# FINSUS04 South Lanarkshire 2022-23             False            True
# CORP04   Scotland          2022-23              True            True
# CORP07   Scotland          2022-23              True            True
# ENV01a   Scotland          2022-23              True            True
# ENV02a   Scotland          2022-23              True            True
#
#                                                          Cols_Changed
# Code     LocalAuthority    Year
# ENV01a   Aberdeen City     2022-23             Indicator, Denominator
# ENV02a   Aberdeen City     2022-23             Indicator, Denominator
# CORP07   Aberdeenshire     2022-23  Indicator, Numerator, Denominator
# ECON04   Angus             2022-23                          Indicator
# CORP04   East Lothian      2022-23             Indicator, Denominator
# ECON04   Eilean Siar       2022-23                          Indicator
# FINSUS01 South Lanarkshire 2022-23                          Indicator
# FINSUS03 South Lanarkshire 2022-23                          Indicator
# FINSUS04 South Lanarkshire 2022-23                          Indicator
# CORP04   Scotland          2022-23                        Denominator
# CORP07   Scotland          2022-23             Numerator, Denominator
# ENV01a   Scotland          2022-23             Indicator, Denominator
# ENV02a   Scotland          2022-23             Indicator, Denominator

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 228    Aberdeen City        CHN12a  2019-20          849.3100
# 229    Aberdeen City        CHN12a  2020-21          866.1900
# 230    Aberdeen City        CHN12a  2021-22          957.2600
# 239    Aberdeen City        CHN12b  2019-20          511.0000
# 240    Aberdeen City        CHN12b  2020-21          578.0000
# ...              ...           ...      ...               ...
# 35761       Scotland          SW02  2019-20            0.0769
# 35762       Scotland          SW02  2022-23            0.0863
# 35763       Scotland         SW03a  2022-23            0.6154
# 35764       Scotland          SW05  2021-22          659.1519
# 35765       Scotland          SW05  2022-23          677.1817
#
#        NumeratorCash_LA  DenominatorCash_LA      _merge
# 228                 NaN                 NaN   left_only
# 229                 NaN                 NaN   left_only
# 230                 NaN                 NaN   left_only
# 239                 NaN                 NaN   left_only
# 240                 NaN                 NaN   left_only
# ...                 ...                 ...         ...
# 35761       265984.0000         3458888.245  right_only
# 35762       371997.7443         4308343.000  right_only
# 35763               NaN                 NaN  right_only
# 35764       957925.6043           27947.500  right_only
# 35765       994692.0000           28247.500  right_only
#
# [4555 rows x 7 columns]

# %%
old_df
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 0      Aberdeen City         C&L01  2010-11             0.330
# 1      Aberdeen City         C&L01  2011-12             0.760
# 2      Aberdeen City         C&L01  2012-13             3.640
# 3      Aberdeen City         C&L01  2013-14             3.480
# 4      Aberdeen City         C&L01  2014-15             3.020
# ...              ...           ...      ...               ...
# 32561       Scotland          SW07  2019-20             0.818
# 32562       Scotland          SW07  2020-21             0.825
# 32563       Scotland          SW07  2021-22             0.758
# 32564       Scotland          SW07  2022-23             0.750
# 32565       Scotland        CHN20a  2020-21            11.870
#
#        NumeratorCash_LA  DenominatorCash_LA
# 0                 637.0           1922292.0
# 1                1554.0           2045051.0
# 2                7883.0           2163756.0
# 3                7726.0           2222588.0
# 4                7517.0           2487138.0
# ...                 ...                 ...
# 32561               NaN                 NaN
# 32562               NaN                 NaN
# 32563               NaN                 NaN
# 32564               NaN                 NaN
# 32565               NaN                 NaN
#
# [32566 rows x 6 columns]

# %%
new_df
# Out:
#       LocalAuthority IndicatorCode     Year  IndicatorCash_LA  \
# 0      Aberdeen City         C&L01  2010-11             0.330
# 1      Aberdeen City         C&L01  2011-12             0.760
# 2      Aberdeen City         C&L01  2012-13             3.640
# 3      Aberdeen City         C&L01  2013-14             3.480
# 4      Aberdeen City         C&L01  2014-15             3.020
# ...              ...           ...      ...               ...
# 34406       Scotland          SW07  2019-20             0.818
# 34407       Scotland          SW07  2020-21             0.825
# 34408       Scotland          SW07  2021-22             0.758
# 34409       Scotland          SW07  2022-23             0.750
# 34410       Scotland        CHN20a  2020-21            11.870
#
#        NumeratorCash_LA  DenominatorCash_LA
# 0                 637.0           1922292.0
# 1                1554.0           2045051.0
# 2                7883.0           2163756.0
# 3                7726.0           2222588.0
# 4                7517.0           2487138.0
# ...                 ...                 ...
# 34406               NaN                 NaN
# 34407               NaN                 NaN
# 34408               NaN                 NaN
# 34409               NaN                 NaN
# 34410               NaN                 NaN
#
# [34411 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([   61,    71,    81, ..., 35204, 35264, 35274])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#          Code LocalAuthority     Year Indicator Numerator Denominator
# 61     C&L05a  Aberdeen City  2020-23      0.70       nan         nan
# 71     C&L05b  Aberdeen City  2020-23      0.87       nan         nan
# 81     C&L05c  Aberdeen City  2020-23      0.79       nan         nan
# 91     C&L05d  Aberdeen City  2020-23      0.73       nan         nan
# 222     CHN10  Aberdeen City  2020-23      0.72       nan         nan
# ...       ...            ...      ...       ...       ...         ...
# 35066  ECON09       Scotland  2022-23      0.12       nan         nan
# 35075  ECON10       Scotland  2022-23      0.23       nan         nan
# 35204  ENV04e       Scotland  2019-23      0.36       nan         nan
# 35264  ENV07a       Scotland  2020-23      0.78       nan         nan
# 35274  ENV07b       Scotland  2020-23      0.58       nan         nan
#
# [1004 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#          Code LocalAuthority     Year New_Indicator New_Numerator  \
# 61     C&L05a  Aberdeen City  2020-23          0.70           nan
# 71     C&L05b  Aberdeen City  2020-23          0.87           nan
# 81     C&L05c  Aberdeen City  2020-23          0.79           nan
# 91     C&L05d  Aberdeen City  2020-23          0.73           nan
# 222     CHN10  Aberdeen City  2020-23          0.72           nan
# ...       ...            ...      ...           ...           ...
# 35066  ECON09       Scotland  2022-23          0.12           nan
# 35075  ECON10       Scotland  2022-23          0.23           nan
# 35204  ENV04e       Scotland  2019-23          0.36           nan
# 35264  ENV07a       Scotland  2020-23          0.78           nan
# 35274  ENV07b       Scotland  2020-23          0.58           nan
#
#       New_Denominator
# 61                nan
# 71                nan
# 81                nan
# 91                nan
# 222               nan
# ...               ...
# 35066             nan
# 35075             nan
# 35204             nan
# 35264             nan
# 35274             nan
#
# [1004 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#          Code LocalAuthority     Year Indicator Numerator Denominator
# 0       C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1       C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2       C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3       C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4       C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...       ...            ...      ...       ...       ...         ...
# 34473    SW07       Scotland  2019-20      0.82       nan         nan
# 34474    SW07       Scotland  2020-21      0.82       nan         nan
# 34475    SW07       Scotland  2021-22      0.76       nan         nan
# 34476    SW07       Scotland  2022-23      0.75       nan         nan
# 34477  CHN20a       Scotland  2020-21     11.87       nan         nan
#
# [34478 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([  682,   682,   695,   695,  1561,  1561,  1561,  2725,  9906,
#         9906, 13170, 30042, 30068, 30081, 33883, 33922, 33922, 34099,
#        34099, 34112, 34112])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#            Code     LocalAuthority     Year Indicator New_Indicator  \
# 682      ENV01a      Aberdeen City  2022-23       nan         52.46
# 695      ENV02a      Aberdeen City  2022-23       nan        114.35
# 1561     CORP07      Aberdeenshire  2022-23      0.96          0.97
# 2725     ECON04              Angus  2022-23      0.42          0.32
# 9906     CORP04       East Lothian  2022-23      7.93          8.01
# 13170    ECON04        Eilean Siar  2022-23      0.29          0.28
# 30042  FINSUS01  South Lanarkshire  2022-23      0.22          0.21
# 30068  FINSUS03  South Lanarkshire  2022-23      0.05          0.04
# 30081  FINSUS04  South Lanarkshire  2022-23      0.17          0.14
# 33883    CORP04           Scotland  2022-23      6.84          6.84
# 33922    CORP07           Scotland  2022-23      0.96          0.96
# 34099    ENV01a           Scotland  2022-23     79.20         75.64
# 34112    ENV02a           Scotland  2022-23     99.76         95.28
#
#            Numerator  New_Numerator    Denominator New_Denominator
# 682          6525.00        6525.00            nan       124369.00
# 695         14221.00       14221.00            nan       124369.00
# 1561    153239000.00   154629000.00   159540000.00    159537000.00
# 2725             nan            nan            nan             nan
# 9906       416615.51      416615.51       52518.00        51982.00
# 13170            nan            nan            nan             nan
# 30042            nan            nan            nan             nan
# 30068            nan            nan            nan             nan
# 30081            nan            nan            nan             nan
# 33883    18541998.48    18541998.48     2711494.00      2710958.00
# 33922  2724082770.00  2725472770.00  2831919562.00   2831916562.00
# 34099      209129.00      209129.00     2640403.00      2764772.00
# 34112      263416.00      263416.00     2640403.00      2764772.00

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#      index    Code       LocalAuthority     Year Indicator New_Indicator  \
# 0      682  ENV01a        Aberdeen City  2022-23       nan         52.46
# 1      695  ENV02a        Aberdeen City  2022-23       nan        114.35
# 18     309  CHN13a        Aberdeen City  2022-23       NaN          0.71
# 19     313  CHN13b        Aberdeen City  2022-23       NaN          0.78
# 20     317  CHN14a        Aberdeen City  2022-23       NaN         23.36
# ..     ...     ...                  ...      ...       ...           ...
# 940  32644  CLIM04  West Dunbartonshire  2017-18       NaN         88.87
# 945  32649  CLIM05  West Dunbartonshire  2017-18       NaN         56.00
# 965  33729  CLIM03         West Lothian  2017-18       NaN         25.80
# 970  33734  CLIM04         West Lothian  2017-18       NaN        103.45
# 975  33739  CLIM05         West Lothian  2017-18       NaN         66.30
#
#     Numerator New_Numerator Denominator New_Denominator
# 0     6525.00       6525.00         nan       124369.00
# 1    14221.00      14221.00         nan       124369.00
# 18        NaN           nan         NaN             nan
# 19        NaN           nan         NaN             nan
# 20        NaN           nan         NaN             nan
# ..        ...           ...         ...             ...
# 940       NaN       7963.72         NaN        89610.00
# 945       NaN       4885.42         NaN        89610.00
# 965       NaN       4678.50         NaN       181310.00
# 970       NaN      18756.44         NaN       181310.00
# 975       NaN      12647.59         NaN       181310.00
#
# [1017 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

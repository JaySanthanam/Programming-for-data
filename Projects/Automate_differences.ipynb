# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/refs/heads/main/Datasets/LGBF_Data_Nov2024.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/refs/heads/main/Datasets/LGBF_Data_Jan08.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code    LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2  C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3  C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4  C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#            Code    LocalAuthority     Year Indicator    Numerator  Denominator
# 13        C&L01     Aberdeen City  2023-24      3.01      5956.00   1978218.00
# 27        C&L01     Aberdeenshire  2023-24      4.25      7846.00   1846056.00
# 41        C&L01             Angus  2023-24      5.42      4247.00    783913.00
# 55        C&L01     Argyll & Bute  2023-24      3.60      2095.00    582515.00
# 69        C&L01  Clackmannanshire  2023-24      3.08       470.00    152421.00
# ...         ...               ...      ...       ...          ...          ...
# 39034  FINSUS04          Scotland  2023-24      0.20          nan          nan
# 39045  FINSUS05          Scotland  2023-24      1.00  15765785.63  15830201.66
# 39110      SW01          Scotland  2023-24     33.59    844017.00  25130517.61
# 39124      SW02          Scotland  2023-24      0.09    416205.75   4592159.00
# 39176      SW05          Scotland  2023-24    722.63   1060047.31     28210.00
#
# [7476 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW07  West Lothian   2019-20      0.81       nan         nan      0.81
#                      2020-21      0.84       nan         nan      0.84
#                      2021-22      0.81       nan         nan      0.81
#                      2022-23      0.76       nan         nan      0.76
#                      2023-24      0.85       nan         nan      0.85
#
#
#                              Numerator Denominator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11    637.00  1922292.00
#                      2011-12   1554.00  2045051.00
#                      2012-13   7883.00  2163756.00
#                      2013-14   7726.00  2222588.00
#                      2014-15   7517.00  2487138.00
# ...                                ...         ...
# SW07  West Lothian   2019-20       nan         nan
#                      2020-21       nan         nan
#                      2021-22       nan         nan
#                      2022-23       nan         nan
#                      2023-24       nan         nan
#
# [41679 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW06  West Lothian   2019-20    112.73   3780.00    33532.00    112.73
#                      2020-21    122.85   3485.00    28368.00    122.85
#                      2021-22    106.67   3464.00    32473.00    106.67
#                      2022-23     95.34   3088.00    32389.00     95.34
#                      2023-24     94.52   3330.00    35231.00     94.52
#
#
#                              Numerator Denominator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11    637.00  1922292.00
#                      2011-12   1554.00  2045051.00
#                      2012-13   7883.00  2163756.00
#                      2013-14   7726.00  2222588.00
#                      2014-15   7517.00  2487138.00
# ...                                ...         ...
# SW06  West Lothian   2019-20   3780.00    33532.00
#                      2020-21   3485.00    28368.00
#                      2021-22   3464.00    32473.00
#                      2022-23   3088.00    32389.00
#                      2023-24   3330.00    35231.00
#
# [19811 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
df1.merge(df2, on=['Code','LocalAuthority','Year'], suffixes=['_old','_new']).drop_duplicates(keep= False) # just a test no need to run this!!!
# Out:
#         Code    LocalAuthority     Year Indicator_old Numerator_old  \
# 0      C&L01     Aberdeen City  2010-11          0.33        637.00
# 1      C&L01     Aberdeenshire  2010-11          4.48       5641.00
# 2      C&L01             Angus  2010-11          1.96       3074.00
# 3      C&L01     Argyll & Bute  2010-11          2.42       1590.00
# 4      C&L01  Clackmannanshire  2010-11          3.00       1639.00
# ...      ...               ...      ...           ...           ...
# 35061   SW07          Scotland  2019-20          0.82           nan
# 35062   SW07          Scotland  2020-21          0.82           nan
# 35063   SW07          Scotland  2021-22          0.76           nan
# 35064   SW07          Scotland  2022-23          0.75           nan
# 35065   SW07          Scotland  2023-24          0.77           nan
#
#       Denominator_old Indicator_new Numerator_new Denominator_new
# 0          1922292.00          0.33        637.00      1922292.00
# 1          1260286.00          4.48       5641.00      1260286.00
# 2          1568948.00          1.96       3074.00      1568948.00
# 3           656840.00          2.42       1590.00       656840.00
# 4           545939.00          3.00       1639.00       545939.00
# ...               ...           ...           ...             ...
# 35061             nan          0.82           nan             nan
# 35062             nan          0.82           nan             nan
# 35063             nan          0.76           nan             nan
# 35064             nan          0.75           nan             nan
# 35065             nan          0.77           nan             nan
#
# [35066 rows x 9 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                   Indicator_old Numerator_old Denominator_old  \
# Code     LocalAuthority   Year
# C&L04    Aberdeen City    2010-11      21412.12       4649.00       217120.00
#          Aberdeenshire    2010-11      19566.28       4809.00       245780.00
#          Angus            2010-11      29248.44       3234.00       110570.00
#          Argyll & Bute    2010-11      15672.65       1398.00        89200.00
#          Clackmannanshire 2010-11      32510.37       1646.00        50630.00
# ...                                         ...           ...             ...
# ENV05b   Scotland         2022-23      15340.40      84064.00      5479900.00
# FINSUS02 Scotland         2018-19          0.04           nan             nan
#                           2019-20          0.04           nan             nan
#                           2020-21          0.04           nan             nan
#                           2021-22          0.04           nan             nan
#
#                                   Indicator_new Numerator_new Denominator_new  \
# Code     LocalAuthority   Year
# C&L04    Aberdeen City    2010-11      21157.78       4649.00       219730.00
#          Aberdeenshire    2010-11      19126.60       4809.00       251430.00
#          Angus            2010-11      28021.84       3234.00       115410.00
#          Argyll & Bute    2010-11      15775.22       1398.00        88620.00
#          Clackmannanshire 2010-11      32067.02       1646.00        51330.00
# ...                                         ...           ...             ...
# ENV05b   Scotland         2022-23      15433.08      84064.00      5447000.00
# FINSUS02 Scotland         2018-19          0.03           nan             nan
#                           2019-20          0.03           nan             nan
#                           2020-21          0.03           nan             nan
#                           2021-22          0.03           nan             nan
#
#                                    Indicator_diff  Numerator_diff  \
# Code     LocalAuthority   Year
# C&L04    Aberdeen City    2010-11            True           False
#          Aberdeenshire    2010-11            True           False
#          Angus            2010-11            True           False
#          Argyll & Bute    2010-11            True           False
#          Clackmannanshire 2010-11            True           False
# ...                                           ...             ...
# ENV05b   Scotland         2022-23            True           False
# FINSUS02 Scotland         2018-19            True           False
#                           2019-20            True           False
#                           2020-21            True           False
#                           2021-22            True           False
#
#                                    Denominator_diff  Record_Changed  \
# Code     LocalAuthority   Year
# C&L04    Aberdeen City    2010-11              True            True
#          Aberdeenshire    2010-11              True            True
#          Angus            2010-11              True            True
#          Argyll & Bute    2010-11              True            True
#          Clackmannanshire 2010-11              True            True
# ...                                             ...             ...
# ENV05b   Scotland         2022-23              True            True
# FINSUS02 Scotland         2018-19             False            True
#                           2019-20             False            True
#                           2020-21             False            True
#                           2021-22             False            True
#
#                                              Cols_Changed
# Code     LocalAuthority   Year
# C&L04    Aberdeen City    2010-11  Indicator, Denominator
#          Aberdeenshire    2010-11  Indicator, Denominator
#          Angus            2010-11  Indicator, Denominator
#          Argyll & Bute    2010-11  Indicator, Denominator
#          Clackmannanshire 2010-11  Indicator, Denominator
# ...                                                   ...
# ENV05b   Scotland         2022-23  Indicator, Denominator
# FINSUS02 Scotland         2018-19               Indicator
#                           2019-20               Indicator
#                           2020-21               Indicator
#                           2021-22               Indicator
#
# [3338 rows x 11 columns]

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-d1042f31dbcc> in <cell line: 1>()
# ----> 1 out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
#       2                suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#       3
#       4 out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#       5 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/merge.py in _get_merge_keys(self)
#    1295                         rk = cast(Hashable, rk)
#    1296                         if rk is not None:
# -> 1297                             right_keys.append(right._get_label_or_level_values(rk))
#    1298                         else:
#    1299                             # work-around for merge_asof(right_index=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#
# KeyError: 'ServiceAreaBreakdown'

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Community                                                7763.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Economic Development & Tourism                          10412.0
#                        Homecare                                                13516.0
# ...                                                                                ...
# West Lothian   2022-23 Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#                        Trading Standards & Env. Health                          3305.0
#                        Waste Collection                                         6951.0
#                        Waste Disposal                                          10524.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Community                                                7763.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Economic Development & Tourism                          10412.0
#                        Homecare                                                13516.0
# ...                                                                                ...
# West Lothian   2022-23 Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#                        Trading Standards & Env. Health                          3305.0
#                        Waste Collection                                         6951.0
#                        Waste Disposal                                          10524.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#           Code    LocalAuthority        Year  Indicator  Numerator  \
# 16785  CORP03b  Clackmannanshire     2023-24     0.6018       68.0
# 16786  CORP03b  Clackmannanshire     2023-24     0.6932      122.0
# 17080  CORP03b          Scotland     2023-24     0.5983     6212.0
# 17081  CORP03b          Scotland     2023-24     0.5999     6266.0
# 19785   CORP09     Aberdeen City  2024-25 Q1     0.9900     4370.0
# ...        ...               ...         ...        ...        ...
# 35440    SW03a      West Lothian     2023-24     0.6590        NaN
# 36466     SW05        Inverclyde     2022-23   674.4740    19553.0
# 36467     SW05        Inverclyde     2022-23   733.0113    21250.0
# 36571     SW05          Scotland     2022-23   682.8106  1002960.0
# 36572     SW05          Scotland     2022-23   683.9660  1004657.0
#
#        Denominator      _merge
# 16785        113.0  right_only
# 16786        176.0   left_only
# 17080      10382.0  right_only
# 17081      10445.0   left_only
# 19785       4405.0  right_only
# ...            ...         ...
# 35440          NaN  right_only
# 36466        557.5  right_only
# 36467        557.5   left_only
# 36571      28247.5  right_only
# 36572      28247.5   left_only
#
# [353 rows x 7 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year  Indicator  Numerator  Denominator
# 0      C&L01  Aberdeen City  2010-11   0.330000      637.0    1922292.0
# 1      C&L01  Aberdeen City  2011-12   0.760000     1554.0    2045051.0
# 2      C&L01  Aberdeen City  2012-13   3.640000     7883.0    2163756.0
# 3      C&L01  Aberdeen City  2013-14   3.480000     7726.0    2222588.0
# 4      C&L01  Aberdeen City  2014-15   3.020000     7517.0    2487138.0
# ...      ...            ...      ...        ...        ...          ...
# 37211   SW07       Scotland  2019-20   0.817997        NaN          NaN
# 37212   SW07       Scotland  2020-21   0.825000        NaN          NaN
# 37213   SW07       Scotland  2021-22   0.757977        NaN          NaN
# 37214   SW07       Scotland  2022-23   0.750000        NaN          NaN
# 37215   SW07       Scotland  2023-24   0.770000        NaN          NaN
#
# [37216 rows x 6 columns]

# %%
new_df
# Out:
#         Code    LocalAuthority     Year  Indicator  Numerator  Denominator
# 0      C&L01     Aberdeen City  2010-11   0.330000      637.0    1922292.0
# 1      C&L01     Aberdeenshire  2010-11   4.480000     5641.0    1260286.0
# 2      C&L01             Angus  2010-11   1.960000     3074.0    1568948.0
# 3      C&L01     Argyll & Bute  2010-11   2.420000     1590.0     656840.0
# 4      C&L01  Clackmannanshire  2010-11   3.000000     1639.0     545939.0
# ...      ...               ...      ...        ...        ...          ...
# 37536   SW07          Scotland  2019-20   0.817997        NaN          NaN
# 37537   SW07          Scotland  2020-21   0.825000        NaN          NaN
# 37538   SW07          Scotland  2021-22   0.757977        NaN          NaN
# 37539   SW07          Scotland  2022-23   0.750000        NaN          NaN
# 37540   SW07          Scotland  2023-24   0.770000        NaN          NaN
#
# [37541 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
old_df
# Out:
#         Code    LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2      C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3      C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4      C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00
# ...      ...               ...      ...       ...       ...         ...
# 37536   SW07          Scotland  2019-20      0.82       nan         nan
# 37537   SW07          Scotland  2020-21      0.82       nan         nan
# 37538   SW07          Scotland  2021-22      0.76       nan         nan
# 37539   SW07          Scotland  2022-23      0.75       nan         nan
# 37540   SW07          Scotland  2023-24      0.77       nan         nan
#
# [37541 rows x 6 columns]

# %%
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
temp
# Out:
#         Code LocalAuthority Year_new Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 39199   SW07       Scotland  2019-20      0.82       nan         nan
# 39200   SW07       Scotland  2020-21      0.82       nan         nan
# 39201   SW07       Scotland  2021-22      0.76       nan         nan
# 39202   SW07       Scotland  2022-23      0.75       nan         nan
# 39203   SW07       Scotland  2023-24      0.77       nan         nan
#
# [39204 rows x 6 columns]

# %%
old_df
# Out:
#         Code    LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2      C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3      C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4      C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00
# ...      ...               ...      ...       ...       ...         ...
# 37536   SW07          Scotland  2019-20      0.82       nan         nan
# 37537   SW07          Scotland  2020-21      0.82       nan         nan
# 37538   SW07          Scotland  2021-22      0.76       nan         nan
# 37539   SW07          Scotland  2022-23      0.75       nan         nan
# 37540   SW07          Scotland  2023-24      0.77       nan         nan
#
# [37541 rows x 6 columns]

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([], dtype=int64)

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#            Code    LocalAuthority     Year Indicator    Numerator  Denominator
# 1664     C&L05a     Aberdeen City  2010-14      0.73          nan          nan
# 1665     C&L05a     Aberdeenshire  2010-14      0.78          nan          nan
# 1666     C&L05a             Angus  2010-14      0.78          nan          nan
# 1667     C&L05a     Argyll & Bute  2010-14      0.72          nan          nan
# 1668     C&L05a  Clackmannanshire  2010-14      0.78          nan          nan
# ...         ...               ...      ...       ...          ...          ...
# 39034  FINSUS04          Scotland  2023-24      0.20          nan          nan
# 39045  FINSUS05          Scotland  2023-24      1.00  15765785.63  15830201.66
# 39110      SW01          Scotland  2023-24     33.59    844017.00  25130517.61
# 39124      SW02          Scotland  2023-24      0.09    416205.75   4592159.00
# 39176      SW05          Scotland  2023-24    722.63   1060047.31     28210.00
#
# [6613 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('new_Data.xlsx')
files.download('new_Data.xlsx')

# %% [markdown]
# #Use diff and new_Data to get the Change log

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Extract_Apr2024.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Extract_May2024.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#          Code    LocalAuthority     Year Indicator   Numerator Denominator
# 5676   CHN08a     Argyll & Bute  2019-20   2599.36     3244.00       24.00
# 5677   CHN08a     Argyll & Bute  2020-21   2701.18     3652.00       26.00
# 5678   CHN08a     Argyll & Bute  2021-22   3050.77     3966.00       25.00
# 5679   CHN08a     Argyll & Bute  2022-23   3635.53     3970.00       21.00
# 5681   CHN08a  Clackmannanshire  2011-12   1696.58     1588.00       18.00
# ...       ...               ...      ...       ...         ...         ...
# 35313  CLIM05          Scotland  2020-21     56.77   310328.36  5466000.00
# 35314  CLIM05          Scotland  2021-22     60.89   333677.39  5479900.00
# 35315  CLIM05          Scotland  2022-23     57.23   313592.29  5479900.00
# 35414  CORP08          Scotland  2022-23      0.91  3892004.00  4296380.00
# 35622  ENV03c          Scotland  2023-24      0.92         nan         nan
#
# [360 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ENV03c West Lothian   2023-24       NaN       NaN         NaN      0.94
# CLIM03 Scotland       2022-23       NaN       NaN         NaN     27.67
# CLIM04 Scotland       2022-23       NaN       NaN         NaN     43.46
# CLIM05 Scotland       2022-23       NaN       NaN         NaN     57.23
# ENV03c Scotland       2023-24       NaN       NaN         NaN      0.92
#
#
#                                Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11     637.00  1922292.00
#                       2011-12    1554.00  2045051.00
#                       2012-13    7883.00  2163756.00
#                       2013-14    7726.00  2222588.00
#                       2014-15    7517.00  2487138.00
# ...                                  ...         ...
# ENV03c West Lothian   2023-24        nan         nan
# CLIM03 Scotland       2022-23  151611.40  5479900.00
# CLIM04 Scotland       2022-23  238134.79  5479900.00
# CLIM05 Scotland       2022-23  313592.29  5479900.00
# ENV03c Scotland       2023-24        nan         nan
#
# [35964 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                       old                             new  \
#                                 Indicator Numerator Denominator Indicator
# Code   LocalAuthority   Year
# C&L01  Aberdeen City    2010-11      0.33    637.00  1922292.00      0.33
#                         2011-12      0.76   1554.00  2045051.00      0.76
#                         2012-13      3.64   7883.00  2163756.00      3.64
#                         2013-14      3.48   7726.00  2222588.00      3.48
#                         2014-15      3.02   7517.00  2487138.00      3.02
# ...                                   ...       ...         ...       ...
# ENV03c Falkirk          2023-24       NaN       NaN         NaN      0.95
#        Shetland Islands 2023-24       NaN       NaN         NaN      0.99
# CLIM03 Scotland         2022-23       NaN       NaN         NaN     27.67
# CLIM04 Scotland         2022-23       NaN       NaN         NaN     43.46
# CLIM05 Scotland         2022-23       NaN       NaN         NaN     57.23
#
#
#                                  Numerator Denominator
# Code   LocalAuthority   Year
# C&L01  Aberdeen City    2010-11     637.00  1922292.00
#                         2011-12    1554.00  2045051.00
#                         2012-13    7883.00  2163756.00
#                         2013-14    7726.00  2222588.00
#                         2014-15    7517.00  2487138.00
# ...                                    ...         ...
# ENV03c Falkirk          2023-24        nan         nan
#        Shetland Islands 2023-24        nan         nan
# CLIM03 Scotland         2022-23  151611.40  5479900.00
# CLIM04 Scotland         2022-23  238134.79  5479900.00
# CLIM05 Scotland         2022-23  313592.29  5479900.00
#
# [18338 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3758         if is_single_key:
#    3759             if self.columns.nlevels > 1:
# -> 3760                 return self._getitem_multilevel(key)
#    3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3813     def _getitem_multilevel(self, key):
#    3814         # self.columns is a MultiIndex
# -> 3815         loc = self.columns.get_loc(key)
#    3816         if isinstance(loc, (slice, np.ndarray)):
#    3817             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2810
#    2811         if not isinstance(key, tuple):
# -> 2812             loc = self._get_level_indexer(key, level=0)
#    2813             return _maybe_to_slice(loc)
#    2814
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ENV03c West Lothian   2023-24       NaN       NaN         NaN      0.94
# CLIM03 Scotland       2022-23       NaN       NaN         NaN     27.67
# CLIM04 Scotland       2022-23       NaN       NaN         NaN     43.46
# CLIM05 Scotland       2022-23       NaN       NaN         NaN     57.23
# ENV03c Scotland       2023-24       NaN       NaN         NaN      0.92
#
#
#                                Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11     637.00  1922292.00
#                       2011-12    1554.00  2045051.00
#                       2012-13    7883.00  2163756.00
#                       2013-14    7726.00  2222588.00
#                       2014-15    7517.00  2487138.00
# ...                                  ...         ...
# ENV03c West Lothian   2023-24        nan         nan
# CLIM03 Scotland       2022-23  151611.40  5479900.00
# CLIM04 Scotland       2022-23  238134.79  5479900.00
# CLIM05 Scotland       2022-23  313592.29  5479900.00
# ENV03c Scotland       2023-24        nan         nan
#
# [35964 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                 Indicator_old Numerator_old Denominator_old  \
# Code   LocalAuthority   Year
# CHN08a Argyll & Bute    2019-20       2310.54       3244.00           27.00
#                         2020-21       3053.51       3652.00           23.00
#                         2021-22       2179.12       3966.00           35.00
#                         2022-23       1908.65       3970.00           40.00
#        Clackmannanshire 2011-12       2035.90       1588.00           15.00
# ...                                       ...           ...             ...
# CLIM05 Scotland         2018-19         56.45     306967.70      5438100.00
#                         2019-20         52.06     284444.01      5463300.00
#                         2020-21         52.82     288701.16      5466000.00
#                         2021-22         57.22     313548.16      5479900.00
# CORP08 Scotland         2022-23          0.91    3892004.00      4295380.00
#
#                                 Indicator_new Numerator_new Denominator_new  \
# Code   LocalAuthority   Year
# CHN08a Argyll & Bute    2019-20       2599.36       3244.00           24.00
#                         2020-21       2701.18       3652.00           26.00
#                         2021-22       3050.77       3966.00           25.00
#                         2022-23       3635.53       3970.00           21.00
#        Clackmannanshire 2011-12       1696.58       1588.00           18.00
# ...                                       ...           ...             ...
# CLIM05 Scotland         2018-19         60.29     327864.09      5438100.00
#                         2019-20         55.94     305638.43      5463300.00
#                         2020-21         56.77     310328.36      5466000.00
#                         2021-22         60.89     333677.39      5479900.00
# CORP08 Scotland         2022-23          0.91    3892004.00      4296380.00
#
#                                  Indicator_diff  Numerator_diff  \
# Code   LocalAuthority   Year
# CHN08a Argyll & Bute    2019-20            True           False
#                         2020-21            True           False
#                         2021-22            True           False
#                         2022-23            True           False
#        Clackmannanshire 2011-12            True           False
# ...                                         ...             ...
# CLIM05 Scotland         2018-19            True            True
#                         2019-20            True            True
#                         2020-21            True            True
#                         2021-22            True            True
# CORP08 Scotland         2022-23           False           False
#
#                                  Denominator_diff  Record_Changed  \
# Code   LocalAuthority   Year
# CHN08a Argyll & Bute    2019-20              True            True
#                         2020-21              True            True
#                         2021-22              True            True
#                         2022-23              True            True
#        Clackmannanshire 2011-12              True            True
# ...                                           ...             ...
# CLIM05 Scotland         2018-19             False            True
#                         2019-20             False            True
#                         2020-21             False            True
#                         2021-22             False            True
# CORP08 Scotland         2022-23              True            True
#
#                                            Cols_Changed
# Code   LocalAuthority   Year
# CHN08a Argyll & Bute    2019-20  Indicator, Denominator
#                         2020-21  Indicator, Denominator
#                         2021-22  Indicator, Denominator
#                         2022-23  Indicator, Denominator
#        Clackmannanshire 2011-12  Indicator, Denominator
# ...                                                 ...
# CLIM05 Scotland         2018-19    Indicator, Numerator
#                         2019-20    Indicator, Numerator
#                         2020-21    Indicator, Numerator
#                         2021-22    Indicator, Numerator
# CORP08 Scotland         2022-23             Denominator
#
# [229 rows x 11 columns]

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#          Code    LocalAuthority     Year Indicator   Numerator Denominator  \
# 5676   CHN08a     Argyll & Bute  2019-20   2310.54     3244.00       27.00
# 5677   CHN08a     Argyll & Bute  2020-21   3053.51     3652.00       23.00
# 5678   CHN08a     Argyll & Bute  2021-22   2179.12     3966.00       35.00
# 5679   CHN08a     Argyll & Bute  2022-23   1908.65     3970.00       40.00
# 5681   CHN08a  Clackmannanshire  2011-12   2035.90     1588.00       15.00
# ...       ...               ...      ...       ...         ...         ...
# 36188  CLIM05          Scotland  2020-21     56.77   310328.36  5466000.00
# 36189  CLIM05          Scotland  2021-22     60.89   333677.39  5479900.00
# 36190  CLIM05          Scotland  2022-23     57.23   313592.29  5479900.00
# 36191  CORP08          Scotland  2022-23      0.91  3892004.00  4296380.00
# 36192  ENV03c          Scotland  2023-24      0.92         nan         nan
#
#            _merge
# 5676    left_only
# 5677    left_only
# 5678    left_only
# 5679    left_only
# 5681    left_only
# ...           ...
# 36188  right_only
# 36189  right_only
# 36190  right_only
# 36191  right_only
# 36192  right_only
#
# [589 rows x 7 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35828   SW07       Scotland  2018-19      0.82       nan         nan
# 35829   SW07       Scotland  2019-20      0.82       nan         nan
# 35830   SW07       Scotland  2020-21      0.82       nan         nan
# 35831   SW07       Scotland  2021-22      0.76       nan         nan
# 35832   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35833 rows x 6 columns]

# %%
new_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35959   SW07       Scotland  2018-19      0.82       nan         nan
# 35960   SW07       Scotland  2019-20      0.82       nan         nan
# 35961   SW07       Scotland  2020-21      0.82       nan         nan
# 35962   SW07       Scotland  2021-22      0.76       nan         nan
# 35963   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35964 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([13915, 13921, 13927, 13933, 13939, 13945, 13951, 13957, 13963,
#        13969, 13975, 13981, 13987, 13993, 13999, 14005, 14011, 14017,
#        14023, 14029, 14035, 14041, 14047, 14053, 14059, 14065, 14071,
#        14077, 14083, 14089, 14095, 14101, 14107, 14113, 14119, 14125,
#        14131, 14137, 14143, 14149, 14155, 14161, 14167, 14173, 14179,
#        14185, 14191, 14197, 14203, 14209, 14215, 14221, 14227, 14233,
#        14239, 14245, 14251, 14257, 14263, 14269, 14275, 14281, 14287,
#        14293, 14299, 14305, 14311, 14317, 14323, 14329, 14335, 14341,
#        14347, 14353, 14359, 14365, 14371, 14377, 14383, 14389, 14395,
#        14401, 14407, 14413, 14419, 14425, 14431, 14437, 14443, 14449,
#        14455, 14461, 14467, 14473, 14479, 14485, 23803, 23817, 23831,
#        23845, 23859, 23873, 23887, 23901, 23915, 23929, 23943, 23957,
#        23971, 23985, 23999, 24013, 24027, 24041, 24055, 24072, 24086,
#        24100, 24114, 24128, 24142, 24156, 24170, 24184, 24198, 24212,
#        24226, 35303, 35309, 35315, 35622])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#          Code    LocalAuthority     Year Indicator  Numerator Denominator
# 13915  CLIM03     Aberdeen City  2022-23     16.65    3786.36   227430.00
# 13921  CLIM03     Aberdeenshire  2022-23     41.28   10842.57   262690.00
# 13927  CLIM03             Angus  2022-23     23.63    2743.39   116120.00
# 13933  CLIM03     Argyll & Bute  2022-23     36.69    3163.19    86220.00
# 13939  CLIM03  Clackmannanshire  2022-23     18.66     961.64    51540.00
# ...       ...               ...      ...       ...        ...         ...
# 24226  ENV03c      West Lothian  2023-24      0.94        nan         nan
# 35303  CLIM03          Scotland  2022-23     27.67  151611.40  5479900.00
# 35309  CLIM04          Scotland  2022-23     43.46  238134.79  5479900.00
# 35315  CLIM05          Scotland  2022-23     57.23  313592.29  5479900.00
# 35622  ENV03c          Scotland  2023-24      0.92        nan         nan
#
# [131 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#          Code    LocalAuthority     Year New_Indicator New_Numerator  \
# 13915  CLIM03     Aberdeen City  2022-23         16.65       3786.36
# 13921  CLIM03     Aberdeenshire  2022-23         41.28      10842.57
# 13927  CLIM03             Angus  2022-23         23.63       2743.39
# 13933  CLIM03     Argyll & Bute  2022-23         36.69       3163.19
# 13939  CLIM03  Clackmannanshire  2022-23         18.66        961.64
# ...       ...               ...      ...           ...           ...
# 24226  ENV03c      West Lothian  2023-24          0.94           nan
# 35303  CLIM03          Scotland  2022-23         27.67     151611.40
# 35309  CLIM04          Scotland  2022-23         43.46     238134.79
# 35315  CLIM05          Scotland  2022-23         57.23     313592.29
# 35622  ENV03c          Scotland  2023-24          0.92           nan
#
#       New_Denominator
# 13915       227430.00
# 13921       262690.00
# 13927       116120.00
# 13933        86220.00
# 13939        51540.00
# ...               ...
# 24226             nan
# 35303      5479900.00
# 35309      5479900.00
# 35315      5479900.00
# 35622             nan
#
# [131 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#         Code       LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01        Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01        Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2      C&L01                Angus  2010-11      1.96   3074.00  1568948.00
# 3      C&L01        Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4      C&L01     Clackmannanshire  2010-11      3.00   1639.00   545939.00
# ...      ...                  ...      ...       ...       ...         ...
# 35828   SW07       South Ayrshire  2022-23      0.68       nan         nan
# 35829   SW07    South Lanarkshire  2022-23      0.77       nan         nan
# 35830   SW07             Stirling  2022-23      0.82       nan         nan
# 35831   SW07  West Dunbartonshire  2022-23      0.82       nan         nan
# 35832   SW07         West Lothian  2022-23      0.76       nan         nan
#
# [35833 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True, False, False, False, False, False],
#        [ True, False, False, False, False, False],
#        ...,
#        [ True, False, False,  True,  True,  True],
#        [ True, False, False, False,  True,  True],
#        [ True, False,  True, False,  True,  True]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([    1,     1,     1, ..., 35831, 35832, 35832])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#         Code LocalAuthority     Year Indicator New_Indicator Numerator  \
# 1      C&L01  Aberdeen City  2011-12      0.76          4.48   1554.00
# 2      C&L01  Aberdeen City  2012-13      3.64          1.96   7883.00
# 3      C&L01  Aberdeen City  2013-14      3.48          2.42   7726.00
# 4      C&L01  Aberdeen City  2014-15      3.02          3.00   7517.00
# 5      C&L01  Aberdeen City  2015-16      3.13          4.16   7977.00
# ...      ...            ...      ...       ...           ...       ...
# 35828   SW07       Scotland  2018-19      0.82          0.68       nan
# 35829   SW07       Scotland  2019-20      0.82          0.77       nan
# 35830   SW07       Scotland  2020-21      0.82          0.82       nan
# 35831   SW07       Scotland  2021-22      0.76          0.82       nan
# 35832   SW07       Scotland  2022-23      0.75          0.76       nan
#
#       New_Numerator Denominator New_Denominator
# 1           5641.00  2045051.00      1260286.00
# 2           3074.00  2163756.00      1568948.00
# 3           1590.00  2222588.00       656840.00
# 4           1639.00  2487138.00       545939.00
# 5           5385.00  2549135.00      1293585.00
# ...             ...         ...             ...
# 35828           nan         nan             nan
# 35829           nan         nan             nan
# 35830           nan         nan             nan
# 35831           nan         nan             nan
# 35832           nan         nan             nan
#
# [35816 rows x 9 columns]

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#        index    Code       LocalAuthority     Year Indicator New_Indicator  \
# 11        12   C&L01        Aberdeen City  2022-23      4.24          2.11
# 424      428   C&L02        Aberdeen City  2022-23      2.44          1.47
# 840      844   C&L03        Aberdeen City  2022-23      3.13          6.55
# 1256    1260   C&L04        Aberdeen City  2022-23  28391.15          1.72
# 2947    2956   CHN01        Aberdeen City  2022-23   6393.60          0.72
# ...      ...     ...                  ...      ...       ...           ...
# 26098  26115  ENV04e       South Ayrshire  2007-11      0.45          0.30
# 26111  26128  ENV04e    South Lanarkshire  2007-11      0.39          0.36
# 26124  26141  ENV04e             Stirling  2007-11      0.48          0.31
# 26137  26154  ENV04e  West Dunbartonshire  2007-11      0.36          0.44
# 26150  26167  ENV04e         West Lothian  2007-11      0.29          0.32
#
#       Numerator New_Numerator Denominator New_Denominator
# 11      7352.00        679.00  1734240.00       321497.00
# 424     4025.00       3112.00  1648447.00      2120654.00
# 840     4190.00       2127.00  1339942.00       324560.00
# 1256    6457.00       2472.00   227430.00      1437648.00
# 2947   93174.00           nan    14573.00             nan
# ...         ...           ...         ...             ...
# 26098       nan           nan         nan             nan
# 26111       nan           nan         nan             nan
# 26124       nan           nan         nan             nan
# 26137       nan           nan         nan             nan
# 26150       nan           nan         nan             nan
#
# [35915 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

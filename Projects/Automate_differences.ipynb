# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Sept_Cash.csv"
new_df = get_data(url_new)
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_July_Cash.csv"
old_df = get_data(url_old)

# %%
old_df.dtypes
# Out:
# LocalAuthority     object
# Code               object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# LocalAuthority     object
# Code               object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
#new_df['Indicator'] = new_df['Indicator'].map("{:.4f}".format)
#new_df['Numerator'] = new_df['Numerator'].map('{:.4f}'.format)
#new_df['Denominator'] = new_df['Denominator'].map('{:.4f}'.format)

# %%
#old_df['Indicator'] = old_df['Indicator'].map('{:.4f}'.format)
#old_df['Numerator'] = old_df['Numerator'].map('{:.4f}'.format)
#old_df['Denominator'] = old_df['Denominator'].map('{:.4f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#   LocalAuthority   Code     Year  Indicator  Numerator  Denominator
# 0  Aberdeen City  C&L01  2010-11       0.33      637.0    1922292.0
# 1  Aberdeen City  C&L01  2011-12       0.76     1554.0    2045051.0
# 2  Aberdeen City  C&L01  2012-13       3.64     7883.0    2163756.0
# 3  Aberdeen City  C&L01  2013-14       3.48     7726.0    2222588.0
# 4  Aberdeen City  C&L01  2014-15       3.02     7517.0    2487138.0

# %%
new_df.head()
# Out:
#   LocalAuthority   Code     Year  Indicator  Numerator  Denominator
# 0  Aberdeen City  C&L01  2010-11       0.33      637.0    1922292.0
# 1  Aberdeen City  C&L01  2011-12       0.76     1554.0    2045051.0
# 2  Aberdeen City  C&L01  2012-13       3.64     7883.0    2163756.0
# 3  Aberdeen City  C&L01  2013-14       3.48     7726.0    2222588.0
# 4  Aberdeen City  C&L01  2014-15       3.02     7517.0    2487138.0

# %%
old_df.reset_index(drop=True).equals(new_df.reset_index(drop=True))
# Out:
# False

# %%
df1 = old_df
df2 =new_df

# %%
out = pd.merge(df1, df2, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_df1', '_df2')).set_index(['Code', 'LocalAuthority','Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)) \
                           .swaplevel()

diff_out = out['df1'].compare(out['df2'], keep_equal=True)

# %%
diff_out
# Out:
#                               Indicator         Numerator       Denominator  \
#                                    self   other      self other        self
# Code   LocalAuthority Year
# CHN10  Scotland       2010-14      0.82  0.8240       NaN   NaN         NaN
#                       2014-17      0.75  0.7530       NaN   NaN         NaN
#                       2015-18      0.72  0.7230       NaN   NaN         NaN
#                       2016-19      0.72  0.7180       NaN   NaN         NaN
#                       2017-20      0.72  0.7180       NaN   NaN         NaN
# ...                                 ...     ...       ...   ...         ...
# C&L05d Scotland       2019-22       NaN  0.7230       NaN   NaN         NaN
# CHN10  Scotland       2019-22       NaN  0.7500       NaN   NaN         NaN
# CHN24  Scotland       2021-22       NaN  0.2262       NaN   NaN         NaN
# ENV07a Scotland       2019-22       NaN  0.7600       NaN   NaN         NaN
# ENV07b Scotland       2019-22       NaN  0.5867       NaN   NaN         NaN
#
#
#                               other
# Code   LocalAuthority Year
# CHN10  Scotland       2010-14   NaN
#                       2014-17   NaN
#                       2015-18   NaN
#                       2016-19   NaN
#                       2017-20   NaN
# ...                             ...
# C&L05d Scotland       2019-22   NaN
# CHN10  Scotland       2019-22   NaN
# CHN24  Scotland       2021-22   NaN
# ENV07a Scotland       2019-22   NaN
# ENV07b Scotland       2019-22   NaN
#
# [329 rows x 6 columns]

# %%
from google.colab import files
diff_out. to_excel('diff_out.xlsx')
files.download('diff_out.xlsx')

# %%
#diff = old_df.compare(new_df, keep_equal=True, keep_shape = True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-173-52da0f254091> in <cell line: 1>()
# ----> 1 diff = old_df.compare(new_df, keep_equal=True, keep_shape = True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    7848         result_names: Suffixes = ("self", "other"),
#    7849     ) -> DataFrame:
# -> 7850         return super().compare(
#    7851             other=other,
#    7852             align_axis=align_axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in compare(self, other, align_axis, keep_shape, keep_equal, result_names)
#    9214             )
#    9215
# -> 9216         mask = ~((self == other) | (self.isna() & other.isna()))
#    9217
#    9218         if not keep_equal:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      70         other = item_from_zerodim(other)
#      71
# ---> 72         return method(self, other)
#      73
#      74     return new_method
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arraylike.py in __eq__(self, other)
#      40     @unpack_zerodim_and_defer("__eq__")
#      41     def __eq__(self, other):
# ---> 42         return self._cmp_method(other, operator.eq)
#      43
#      44     @unpack_zerodim_and_defer("__ne__")
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _cmp_method(self, other, op)
#    7577         axis = 1  # only relevant for Series other case
#    7578
# -> 7579         self, other = ops.align_method_FRAME(self, other, axis, flex=False, level=None)
#    7580
#    7581         # See GH#4537 for discussion of scalar op behavior
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/ops/__init__.py in align_method_FRAME(left, right, axis, flex, level)
#     287                 left, right = left.align(right, join="outer", level=level, copy=False)
#     288             else:
# --> 289                 raise ValueError(
#     290                     "Can only compare identically-labeled DataFrame objects"
#     291                 )
#
# ValueError: Can only compare identically-labeled DataFrame objects

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#         LocalAuthority     Code     Year  Indicator    Numerator  Denominator  \
# 456      Aberdeen City  CORP06a  2022-23     5.5605       9842.0       1770.0
# 469      Aberdeen City  CORP06b  2022-23    13.8537      68479.0       4943.0
# 912      Aberdeen City    HSN02  2022-23     0.0570          NaN          NaN
# 1512     Aberdeenshire   CORP07  2022-23     1.0829  153239000.0  141508000.0
# 1942     Aberdeenshire    HSN02  2022-23     0.0203          NaN          NaN
# ...                ...      ...      ...        ...          ...          ...
# 1034291       Scotland  CORP06b  2022-23    13.1313    2009099.0     153000.0
# 1034292       Scotland  CORP06b  2022-23    13.1313    2009099.0     153000.0
# 1034293       Scotland  CORP06b  2022-23    13.1313    2009099.0     153000.0
# 1034294       Scotland  CORP06b  2022-23    13.1313    2009099.0     153000.0
# 1034295       Scotland  CORP06b  2022-23    13.1313    2009099.0     153000.0
#
#              _merge
# 456       left_only
# 469       left_only
# 912       left_only
# 1512      left_only
# 1942      left_only
# ...             ...
# 1034291  right_only
# 1034292  right_only
# 1034293  right_only
# 1034294  right_only
# 1034295  right_only
#
# [1531 rows x 7 columns]

# %%
old_df
# Out:
#       LocalAuthority   Code     Year  Indicator  Numerator  Denominator
# 0      Aberdeen City  C&L01  2010-11     0.3300      637.0    1922292.0
# 1      Aberdeen City  C&L01  2011-12     0.7600     1554.0    2045051.0
# 2      Aberdeen City  C&L01  2012-13     3.6400     7883.0    2163756.0
# 3      Aberdeen City  C&L01  2013-14     3.4800     7726.0    2222588.0
# 4      Aberdeen City  C&L01  2014-15     3.0200     7517.0    2487138.0
# ...              ...    ...      ...        ...        ...          ...
# 64971       Scotland   SW07  2018-19     0.8217        NaN          NaN
# 64972       Scotland   SW07  2019-20     0.8180        NaN          NaN
# 64973       Scotland   SW07  2020-21     0.8250        NaN          NaN
# 64974       Scotland   SW07  2021-22     0.7580        NaN          NaN
# 64975       Scotland   SW07  2022-23     0.7500        NaN          NaN
#
# [64976 rows x 6 columns]

# %%
new_df
# Out:
#       LocalAuthority   Code     Year  Indicator  Numerator  Denominator
# 0      Aberdeen City  C&L01  2010-11     0.3300      637.0    1922292.0
# 1      Aberdeen City  C&L01  2011-12     0.7600     1554.0    2045051.0
# 2      Aberdeen City  C&L01  2012-13     3.6400     7883.0    2163756.0
# 3      Aberdeen City  C&L01  2013-14     3.4800     7726.0    2222588.0
# 4      Aberdeen City  C&L01  2014-15     3.0200     7517.0    2487138.0
# ...              ...    ...      ...        ...        ...          ...
# 65020       Scotland   SW07  2018-19     0.8217        NaN          NaN
# 65021       Scotland   SW07  2019-20     0.8180        NaN          NaN
# 65022       Scotland   SW07  2020-21     0.8250        NaN          NaN
# 65023       Scotland   SW07  2021-22     0.7580        NaN          NaN
# 65024       Scotland   SW07  2022-23     0.7500        NaN          NaN
#
# [65025 rows x 6 columns]

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = old_df.set_index(['Code', 'LocalAuthority','Year'])
df2 = new_df.set_index(['Code', 'LocalAuthority','Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                Indicator_old  Numerator_old  Denominator_old  \
# Code   LocalAuthority Year
# C&L05a Aberdeen City  2010-14         0.7340            NaN              NaN
#                       2012-15         0.7130            NaN              NaN
#                       2013-16         0.7070            NaN              NaN
#                       2014-17         0.7400            NaN              NaN
#                       2015-18         0.7230            NaN              NaN
# ...                                      ...            ...              ...
# SW07   West Lothian   2018-19         0.8542            NaN              NaN
#                       2019-20         0.8125            NaN              NaN
#                       2020-21         0.8430            NaN              NaN
#                       2021-22         0.8075            NaN              NaN
#                       2022-23         0.7600            NaN              NaN
#
#                                Indicator_new  Numerator_new  Denominator_new  \
# Code   LocalAuthority Year
# C&L05a Aberdeen City  2010-14         0.7340            NaN              NaN
#                       2012-15         0.7130            NaN              NaN
#                       2013-16         0.7070            NaN              NaN
#                       2014-17         0.7400            NaN              NaN
#                       2015-18         0.7230            NaN              NaN
# ...                                      ...            ...              ...
# SW07   West Lothian   2018-19         0.8542            NaN              NaN
#                       2019-20         0.8125            NaN              NaN
#                       2020-21         0.8430            NaN              NaN
#                       2021-22         0.8075            NaN              NaN
#                       2022-23         0.7600            NaN              NaN
#
#                                Indicator_diff  Numerator_diff  \
# Code   LocalAuthority Year
# C&L05a Aberdeen City  2010-14           False            True
#                       2012-15           False            True
#                       2013-16           False            True
#                       2014-17           False            True
#                       2015-18           False            True
# ...                                       ...             ...
# SW07   West Lothian   2018-19           False            True
#                       2019-20           False            True
#                       2020-21           False            True
#                       2021-22           False            True
#                       2022-23           False            True
#
#                                Denominator_diff  Record_Changed  \
# Code   LocalAuthority Year
# C&L05a Aberdeen City  2010-14              True            True
#                       2012-15              True            True
#                       2013-16              True            True
#                       2014-17              True            True
#                       2015-18              True            True
# ...                                         ...             ...
# SW07   West Lothian   2018-19              True            True
#                       2019-20              True            True
#                       2020-21              True            True
#                       2021-22              True            True
#                       2022-23              True            True
#
#                                          Cols_Changed
# Code   LocalAuthority Year
# C&L05a Aberdeen City  2010-14  Numerator, Denominator
#                       2012-15  Numerator, Denominator
#                       2013-16  Numerator, Denominator
#                       2014-17  Numerator, Denominator
#                       2015-18  Numerator, Denominator
# ...                                               ...
# SW07   West Lothian   2018-19  Numerator, Denominator
#                       2019-20  Numerator, Denominator
#                       2020-21  Numerator, Denominator
#                       2021-22  Numerator, Denominator
#                       2022-23  Numerator, Denominator
#
# [679278 rows x 11 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([    374,    1523,    2679,    3835,    4923,    6074,    7174,
#           8330,    9486,   10639,   11780,   12932,   14031,   15121,
#          16277,   17433,   18533,   19682,   20769,   21908,   23054,
#          24208,   25320,   26465,   27618,   28771,   29820,   30955,
#          32106,   33262,   34416,   35571,   36352,   48104,   84236,
#         120565,  156894,  191435,  227621,  262499,  298828,  335157,
#         371405,  407304,  443511,  478182,  512775,  549104,  585433,
#         620311,  656437,  690943,  726808,  762827,  799098,  834174,
#         870192,  906440,  942691,  976104, 1011835, 1048027, 1084356,
#        1120631, 1156934])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#             LocalAuthority     Code     Year  Indicator  Numerator  \
# 456          Aberdeen City  CORP06a  2022-23     5.5605    9842.00
# 469          Aberdeen City  CORP06b  2022-23    13.8537   68479.00
# 4489      Clackmannanshire  CORP03b  2022-23     0.5982      67.00
# 4497      Clackmannanshire  CORP03c  2022-23     0.0208      16.86
# 10656    East Renfrewshire  CORP06a  2022-23     4.1353    5947.00
# 10669    East Renfrewshire  CORP06b  2022-23    12.3578   32241.00
# 27763       South Ayrshire   CORP04  2022-23     6.6542  374325.00
# 27815       South Ayrshire   CORP08  2022-23     0.9538   83694.00
# 374          Aberdeen City    CHN24  2021-22     0.2049        NaN
# 1403         Aberdeenshire    CHN24  2021-22     0.1602        NaN
# 2439                 Angus    CHN24  2021-22     0.2419        NaN
# 3475         Argyll & Bute    CHN24  2021-22     0.2171        NaN
# 4443      Clackmannanshire    CHN24  2021-22     0.2826        NaN
# 5474   Dumfries & Galloway    CHN24  2021-22     0.2604        NaN
# 6454           Dundee City    CHN24  2021-22     0.2712        NaN
# 7490         East Ayrshire    CHN24  2021-22     0.2719        NaN
# 8526   East Dunbartonshire    CHN24  2021-22     0.1494        NaN
# 9559          East Lothian    CHN24  2021-22     0.2113        NaN
# 10580    East Renfrewshire    CHN24  2021-22     0.1444        NaN
# 11612       Edinburgh City    CHN24  2021-22     0.1954        NaN
# 12591          Eilean Siar    CHN24  2021-22     0.1980        NaN
# 13561              Falkirk    CHN24  2021-22     0.2534        NaN
# 14597                 Fife    CHN24  2021-22     0.2613        NaN
# 15633         Glasgow City    CHN24  2021-22     0.3202        NaN
# 16613             Highland    CHN24  2021-22     0.2279        NaN
# 17642           Inverclyde    CHN24  2021-22     0.2437        NaN
# 18609           Midlothian    CHN24  2021-22     0.2274        NaN
# 19628                Moray    CHN24  2021-22     0.2407        NaN
# 20654       North Ayrshire    CHN24  2021-22     0.2896        NaN
# 21688    North Lanarkshire    CHN24  2021-22     0.2662        NaN
# 22680       Orkney Islands    CHN24  2021-22     0.2009        NaN
# 23705      Perth & Kinross    CHN24  2021-22     0.2190        NaN
# 24738         Renfrewshire    CHN24  2021-22     0.2334        NaN
# 25771     Scottish Borders    CHN24  2021-22     0.2338        NaN
# 26700     Shetland Islands    CHN24  2021-22     0.1544        NaN
# 27715       South Ayrshire    CHN24  2021-22     0.2442        NaN
# 28746    South Lanarkshire    CHN24  2021-22     0.2284        NaN
# 29782             Stirling    CHN24  2021-22     0.2079        NaN
# 30816  West Dunbartonshire    CHN24  2021-22     0.2764        NaN
# 31851         West Lothian    CHN24  2021-22     0.2391        NaN
# 32512                  NaN      NaN      NaN        NaN        NaN
#
#        Denominator
# 456        1770.00
# 469        4943.00
# 4489        112.00
# 4497         16.51
# 10656      1438.00
# 10669      2609.00
# 27763     56254.00
# 27815     87746.00
# 374            NaN
# 1403           NaN
# 2439           NaN
# 3475           NaN
# 4443           NaN
# 5474           NaN
# 6454           NaN
# 7490           NaN
# 8526           NaN
# 9559           NaN
# 10580          NaN
# 11612          NaN
# 12591          NaN
# 13561          NaN
# 14597          NaN
# 15633          NaN
# 16613          NaN
# 17642          NaN
# 18609          NaN
# 19628          NaN
# 20654          NaN
# 21688          NaN
# 22680          NaN
# 23705          NaN
# 24738          NaN
# 25771          NaN
# 26700          NaN
# 27715          NaN
# 28746          NaN
# 29782          NaN
# 30816          NaN
# 31851          NaN
# 32512          NaN

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-c0840ad59200> in <cell line: 2>()
#       1 #new year added data
# ----> 2 new_Data = new_df.loc[new_year_df]
#       3 new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
#       4 new_Data = new_Data.drop_duplicates()
#       5 new_Data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1071
#    1072             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073             return self._getitem_axis(maybe_callable, axis=axis)
#    1074
#    1075     def _is_scalar_access(self, key: tuple):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1299                     raise ValueError("Cannot index with multidimensional key")
#    1300
# -> 1301                 return self._getitem_iterable(key, axis=axis)
#    1302
#    1303             # nested tuple slicing
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1237
#    1238         # A collection of keys
# -> 1239         keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1240         return self.obj._reindex_with_indexers(
#    1241             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1430         axis_name = self.obj._get_axis_name(axis)
#    1431
# -> 1432         keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1433
#    1434         return keyarr, indexer
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6131
#    6132             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133             raise KeyError(f"{not_found} not in index")
#    6134
#    6135     @overload
#
# KeyError: '[84236, 120565, 156894, 191435, 227621, 262499, 298828, 335157, 371405, 407304, 443511, 478182, 512775, 549104, 585433, 620311, 656437, 690943, 726808, 762827, 799098, 834174, 870192, 906440, 942691, 976104, 1011835, 1048027, 1084356, 1120631, 1156934] not in index'

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-41-d28a3798df40> in <cell line: 2>()
#       1 #make df with only changes
# ----> 2 new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
#       3 new_update
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#     977             )
#     978         # fall back to Int64Index
# --> 979         return super().__getitem__(key)
#     980
#     981     def _getitem_slice(self: RangeIndex, slobj: slice) -> RangeIndex:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5337                 key = np.asarray(key, dtype=bool)
#    5338
# -> 5339         result = getitem(key)
#    5340         # Because we ruled out integer above, we always get an arraylike here
#    5341         if result.ndim > 1:
#
# IndexError: index 84236 is out of bounds for axis 0 with size 65025

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-e2be420cbd72> in <cell line: 1>()
# ----> 1 old_df.values==new_update.values
#
# NameError: name 'new_update' is not defined

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# <ipython-input-28-6d539fd913ec>:2: DeprecationWarning: elementwise comparison failed; this will raise an error in the future.
#   comparison_values = old_df.values == new_update.values
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6d539fd913ec> in <cell line: 3>()
#       1 #compare the old df to find the changes
#       2 comparison_values = old_df.values == new_update.values
# ----> 3 rows,cols=np.where(comparison_values==False)
#       4 rows
#
# ValueError: not enough values to unpack (expected 2, got 1)

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-4fdcc668f1cd> in <cell line: 2>()
#       1 change_df = pd.DataFrame()
# ----> 2 change_df = old_df.loc[rows]
#       3 AddNew_df = new_update.loc[rows]
#       4 change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
#       5 change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
#
# NameError: name 'rows' is not defined

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#        index    Code       LocalAuthority     Year   Indicator New_Indicator  \
# 110      407   C&L02        Aberdeen City  2021-22      2.4476        2.1544
# 506      803   C&L03        Aberdeen City  2021-22      3.1229       47.2555
# 865     1162   C&L04        Aberdeen City  2021-22  14269.6162    21752.0543
# 2317    2614   CHN01        Aberdeen City  2021-22   5902.8563     5711.4908
# 2713    3010   CHN02        Aberdeen City  2021-22   7107.2086     7866.6148
# ...      ...     ...                  ...      ...         ...           ...
# 23235  23532  ENV04e       South Ayrshire  2007-11      0.4461     4372.3525
# 23247  23544  ENV04e    South Lanarkshire  2007-11      0.3873    10411.2838
# 23259  23556  ENV04e             Stirling  2007-11      0.4834     3608.1957
# 23271  23568  ENV04e  West Dunbartonshire  2007-11      0.3585     11269.645
# 23283  23580  ENV04e         West Lothian  2007-11      0.2853    15435.0184
#
#         Numerator New_Numerator  Denominator New_Denominator
# 110     3297.3084     3192.3941    1347180.0       1481816.0
# 506     3718.9642      415.6607    1190854.0          8796.0
# 865     3245.0000        1875.0     227430.0         86220.0
# 2317   83136.1361       52134.0      14084.0          9128.0
# 2713   71363.7459       59298.0      10041.0          7538.0
# ...           ...           ...          ...             ...
# 23235         NaN       1374.49          NaN        314360.0
# 23247         NaN      953.4628          NaN         91580.0
# 23259         NaN      324.2318          NaN         89860.0
# 23271         NaN     2052.6478          NaN        182140.0
# 23283         NaN      3535.563          NaN        229060.0
#
# [31061 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Final_Jan24.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Extract_Apr2024.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#            Code     LocalAuthority     Year Indicator  Numerator  Denominator
# 38        C&L01              Angus  2022-23      6.15    4747.00    771832.00
# 155       C&L01     Edinburgh City  2022-23      3.32   10043.00   3026419.00
# 207       C&L01       Glasgow City  2022-23     12.26   45850.00   3738577.00
# 285       C&L01  North Lanarkshire  2022-23      3.80   10127.00   2664982.00
# 623       C&L02       Glasgow City  2022-23      5.86   15535.00   2651675.00
# ...         ...                ...      ...       ...        ...          ...
# 35593    ENV05b           Scotland  2022-23  15340.40   84064.00   5479900.00
# 35678  FINSUS04           Scotland  2022-23      0.22        nan          nan
# 35748      SW01           Scotland  2022-23     30.45  735984.00  24174147.30
# 35760      SW02           Scotland  2021-22      0.08  328806.00   3921342.00
# 35761      SW02           Scotland  2022-23      0.09  374324.00   4292335.00
#
# [2586 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# CHN17  Scotland       2022-23       NaN       NaN         NaN      0.82
# CHN20a Scotland       2022-23       NaN       NaN         NaN     16.56
# CHN22  Scotland       2022-23       NaN       NaN         NaN      0.06
# CHN23  Scotland       2022-23       NaN       NaN         NaN      0.17
# ECON11 Scotland       2022-23       NaN       NaN         NaN  27039.18
#
#
#                               Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    637.00  1922292.00
#                       2011-12   1554.00  2045051.00
#                       2012-13   7883.00  2163756.00
#                       2013-14   7726.00  2222588.00
#                       2014-15   7517.00  2487138.00
# ...                                 ...         ...
# CHN17  Scotland       2022-23       nan         nan
# CHN20a Scotland       2022-23       nan         nan
# CHN22  Scotland       2022-23       nan         nan
# CHN23  Scotland       2022-23       nan         nan
# ECON11 Scotland       2022-23       nan         nan
#
# [35846 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                          old                             new  \
#                                    Indicator Numerator Denominator Indicator
# Code   LocalAuthority      Year
# C&L01  Aberdeen City       2010-11      0.33    637.00  1922292.00      0.33
#                            2011-12      0.76   1554.00  2045051.00      0.76
#                            2012-13      3.64   7883.00  2163756.00      3.64
#                            2013-14      3.48   7726.00  2222588.00      3.48
#                            2014-15      3.02   7517.00  2487138.00      3.02
# ...                                      ...       ...         ...       ...
# ECON11 Stirling            2022-23       NaN       NaN         NaN  26211.62
#        West Dunbartonshire 2022-23       NaN       NaN         NaN  20082.01
#        West Lothian        2022-23       NaN       NaN         NaN  29297.34
# CHN20a Scotland            2022-23       NaN       NaN         NaN     16.56
# ECON11 Scotland            2022-23       NaN       NaN         NaN  27039.18
#
#
#                                    Numerator Denominator
# Code   LocalAuthority      Year
# C&L01  Aberdeen City       2010-11    637.00  1922292.00
#                            2011-12   1554.00  2045051.00
#                            2012-13   7883.00  2163756.00
#                            2013-14   7726.00  2222588.00
#                            2014-15   7517.00  2487138.00
# ...                                      ...         ...
# ECON11 Stirling            2022-23       nan         nan
#        West Dunbartonshire 2022-23       nan         nan
#        West Lothian        2022-23       nan         nan
# CHN20a Scotland            2022-23       nan         nan
# ECON11 Scotland            2022-23       nan         nan
#
# [18564 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3758         if is_single_key:
#    3759             if self.columns.nlevels > 1:
# -> 3760                 return self._getitem_multilevel(key)
#    3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3813     def _getitem_multilevel(self, key):
#    3814         # self.columns is a MultiIndex
# -> 3815         loc = self.columns.get_loc(key)
#    3816         if isinstance(loc, (slice, np.ndarray)):
#    3817             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2810
#    2811         if not isinstance(key, tuple):
# -> 2812             loc = self._get_level_indexer(key, level=0)
#    2813             return _maybe_to_slice(loc)
#    2814
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# CHN17  Scotland       2022-23       NaN       NaN         NaN      0.82
# CHN20a Scotland       2022-23       NaN       NaN         NaN     16.56
# CHN22  Scotland       2022-23       NaN       NaN         NaN      0.06
# CHN23  Scotland       2022-23       NaN       NaN         NaN      0.17
# ECON11 Scotland       2022-23       NaN       NaN         NaN  27039.18
#
#
#                               Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11    637.00  1922292.00
#                       2011-12   1554.00  2045051.00
#                       2012-13   7883.00  2163756.00
#                       2013-14   7726.00  2222588.00
#                       2014-15   7517.00  2487138.00
# ...                                 ...         ...
# CHN17  Scotland       2022-23       nan         nan
# CHN20a Scotland       2022-23       nan         nan
# CHN22  Scotland       2022-23       nan         nan
# CHN23  Scotland       2022-23       nan         nan
# ECON11 Scotland       2022-23       nan         nan
#
# [35846 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                 Indicator_old Numerator_old Denominator_old  \
# Code     LocalAuthority Year
# CHN02    Aberdeen City  2022-23       7795.21      81304.00        10430.00
# CHN04    Aberdeen City  2011-12          0.47           nan             nan
#                         2012-13          0.48           nan             nan
#                         2013-14          0.49           nan             nan
#                         2014-15          0.52           nan             nan
# ...                                       ...           ...             ...
# ENV05b   Scotland       2022-23      15239.10      83509.00      5479900.00
# FINSUS04 Scotland       2022-23          0.21           nan             nan
# SW01     Scotland       2022-23         31.85     770027.00     24174147.30
# SW02     Scotland       2021-22          0.08     328806.00      3920394.00
#                         2022-23          0.09     374796.00      4310078.00
#
#                                 Indicator_new Numerator_new Denominator_new  \
# Code     LocalAuthority Year
# CHN02    Aberdeen City  2022-23       7797.12      81324.00        10430.00
# CHN04    Aberdeen City  2011-12          0.50           nan             nan
#                         2012-13          0.49           nan             nan
#                         2013-14          0.52           nan             nan
#                         2014-15          0.56           nan             nan
# ...                                       ...           ...             ...
# ENV05b   Scotland       2022-23      15340.40      84064.00      5479900.00
# FINSUS04 Scotland       2022-23          0.22           nan             nan
# SW01     Scotland       2022-23         30.45     735984.00     24174147.30
# SW02     Scotland       2021-22          0.08     328806.00      3921342.00
#                         2022-23          0.09     374324.00      4292335.00
#
#                                  Indicator_diff  Numerator_diff  \
# Code     LocalAuthority Year
# CHN02    Aberdeen City  2022-23            True            True
# CHN04    Aberdeen City  2011-12            True           False
#                         2012-13            True           False
#                         2013-14            True           False
#                         2014-15            True           False
# ...                                         ...             ...
# ENV05b   Scotland       2022-23            True            True
# FINSUS04 Scotland       2022-23            True           False
# SW01     Scotland       2022-23            True            True
# SW02     Scotland       2021-22           False           False
#                         2022-23           False            True
#
#                                  Denominator_diff  Record_Changed  \
# Code     LocalAuthority Year
# CHN02    Aberdeen City  2022-23             False            True
# CHN04    Aberdeen City  2011-12             False            True
#                         2012-13             False            True
#                         2013-14             False            True
#                         2014-15             False            True
# ...                                           ...             ...
# ENV05b   Scotland       2022-23             False            True
# FINSUS04 Scotland       2022-23             False            True
# SW01     Scotland       2022-23             False            True
# SW02     Scotland       2021-22              True            True
#                         2022-23              True            True
#
#                                            Cols_Changed
# Code     LocalAuthority Year
# CHN02    Aberdeen City  2022-23    Indicator, Numerator
# CHN04    Aberdeen City  2011-12               Indicator
#                         2012-13               Indicator
#                         2013-14               Indicator
#                         2014-15               Indicator
# ...                                                 ...
# ENV05b   Scotland       2022-23    Indicator, Numerator
# FINSUS04 Scotland       2022-23               Indicator
# SW01     Scotland       2022-23    Indicator, Numerator
# SW02     Scotland       2021-22             Denominator
#                         2022-23  Numerator, Denominator
#
# [2222 rows x 11 columns]

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#            Code LocalAuthority     Year Indicator  Numerator  Denominator  \
# 117       CHN02  Aberdeen City  2022-23   7795.21   81304.00     10430.00
# 131       CHN04  Aberdeen City  2011-12      0.47        nan          nan
# 132       CHN04  Aberdeen City  2012-13      0.48        nan          nan
# 133       CHN04  Aberdeen City  2013-14      0.49        nan          nan
# 134       CHN04  Aberdeen City  2014-15      0.52        nan          nan
# ...         ...            ...      ...       ...        ...          ...
# 38063    ENV05b       Scotland  2022-23  15340.40   84064.00   5479900.00
# 38064  FINSUS04       Scotland  2022-23      0.22        nan          nan
# 38065      SW01       Scotland  2022-23     30.45  735984.00  24174147.30
# 38066      SW02       Scotland  2021-22      0.08  328806.00   3921342.00
# 38067      SW02       Scotland  2022-23      0.09  374324.00   4292335.00
#
#            _merge
# 117     left_only
# 131     left_only
# 132     left_only
# 133     left_only
# 134     left_only
# ...           ...
# 38063  right_only
# 38064  right_only
# 38065  right_only
# 38066  right_only
# 38067  right_only
#
# [4821 rows x 7 columns]

# %%
old_df
# Out:
#          Code LocalAuthority     Year Indicator Numerator Denominator
# 0       C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1       C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2       C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3       C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4       C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...       ...            ...      ...       ...       ...         ...
# 35477    SW07       Scotland  2019-20      0.82       nan         nan
# 35478    SW07       Scotland  2020-21      0.82       nan         nan
# 35479    SW07       Scotland  2021-22      0.76       nan         nan
# 35480    SW07       Scotland  2022-23      0.75       nan         nan
# 35481  CHN20a       Scotland  2020-21     11.87       nan         nan
#
# [35482 rows x 6 columns]

# %%
new_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35828   SW07       Scotland  2018-19      0.82       nan         nan
# 35829   SW07       Scotland  2019-20      0.82       nan         nan
# 35830   SW07       Scotland  2020-21      0.82       nan         nan
# 35831   SW07       Scotland  2021-22      0.76       nan         nan
# 35832   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35833 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([ 4203,  4215,  4227,  4239,  4251,  4263,  4275,  4287,  4299,
#         4311,  4323,  4335,  4347,  4359,  4371,  4383,  4395,  4407,
#         4419,  4431,  4443,  4455,  4467,  4479,  4491,  4503,  4515,
#         4527,  4539,  4551,  4563,  4575,  4587,  4599,  4611,  4623,
#         4635,  4647,  4659,  4671,  4683,  4695,  4707,  4719,  4731,
#         4743,  4755,  4767,  4779,  4791,  4803,  4815,  4827,  4839,
#         4851,  4863,  4875,  4887,  4899,  4911,  4923,  4935,  4947,
#         4959,  4971,  4983,  4995,  5007,  5019,  5031,  5043,  5055,
#         5067,  5079,  5091,  5103,  5104,  5116,  5128,  5140,  5152,
#         5164,  5176,  5188,  5200,  5212,  5224,  5236,  5248,  5260,
#         5272,  5284,  5296,  5308,  5313,  5315,  5327,  5339,  5351,
#         5363,  5375,  5387,  5399,  5407,  5419,  5431,  5432,  5444,
#         5456,  5468,  5480,  5492,  5504,  5505,  5509,  5521,  5533,
#         5545,  5557,  5567,  5579,  5591,  5603,  5615,  5627,  6472,
#         6485,  6498,  6511,  6524,  6537,  6550,  6563,  6576,  6589,
#         6602,  6615,  6628,  6641,  6654,  6667,  6680,  6693,  6706,
#         6719,  6732,  6745,  6758,  6771,  6784,  6797,  6810,  6823,
#         6836,  6849,  6862,  6875,  7207,  7219,  7231,  7243,  7255,
#         7267,  7279,  7291,  7303,  7315,  7327,  7339,  7351,  7363,
#         7375,  7387,  7399,  7411,  7423,  7435,  7447,  7459,  7471,
#         7483,  7495,  7507,  7519,  7531,  7543,  7555,  7567,  7579,
#        10322, 10332, 10342, 10352, 10362, 10372, 10382, 10392, 10402,
#        10412, 10422, 10432, 10442, 10452, 10462, 10472, 10482, 10492,
#        10502, 10512, 10522, 10532, 10542, 10552, 10562, 10572, 10582,
#        10592, 10602, 10612, 10622, 10632, 11470, 11477, 11484, 11491,
#        11497, 11504, 11511, 11518, 11525, 11532, 11539, 11546, 11553,
#        11560, 11567, 11574, 11581, 11588, 11595, 11602, 11609, 11616,
#        11622, 11629, 11636, 11643, 11650, 11657, 11664, 11671, 11678,
#        11685, 12128, 12139, 12150, 12161, 12172, 12183, 12194, 12205,
#        12216, 12227, 12238, 12249, 12260, 12271, 12282, 12293, 12304,
#        12315, 12326, 12337, 12348, 12359, 12370, 12381, 12392, 12403,
#        12414, 12425, 12436, 12447, 12458, 12469, 12482, 12495, 12508,
#        12521, 12534, 12547, 12560, 12573, 12586, 12599, 12612, 12625,
#        12638, 12651, 12664, 12677, 12690, 12703, 12716, 12729, 12742,
#        12755, 12768, 12781, 12794, 12807, 12820, 12833, 12846, 12859,
#        12872, 12885, 20935, 20975, 21019, 21049, 22042, 22055, 22068,
#        22081, 22094, 22107, 22120, 22133, 22146, 22159, 22172, 22185,
#        22198, 22211, 22224, 22237, 22250, 22263, 22276, 22289, 22302,
#        22315, 22328, 22341, 22354, 22367, 22380, 22393, 22406, 22419,
#        22432, 22445, 34872, 34884, 34896, 34908, 34947, 34969, 35067,
#        35099, 35125, 35138, 35439])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#          Code     LocalAuthority     Year Indicator Numerator Denominator
# 1258    CHN07      Aberdeenshire  2018-19      0.07       nan         nan
# 4966   ECON07   Clackmannanshire  2022-23      0.14       nan         nan
# 9884    CHN07       East Lothian  2013-14      0.08       nan         nan
# 11459  ECON07  East Renfrewshire  2022-23      0.07       nan         nan
# 13135   CHN06        Eilean Siar  2018-19      0.00       nan         nan
# ...       ...                ...      ...       ...       ...         ...
# 35067   CHN17           Scotland  2022-23      0.82       nan         nan
# 35099  CHN20a           Scotland  2022-23     16.56       nan         nan
# 35125   CHN22           Scotland  2022-23      0.06       nan         nan
# 35138   CHN23           Scotland  2022-23      0.17       nan         nan
# 35439  ECON11           Scotland  2022-23  27039.18       nan         nan
#
# [377 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#          Code    LocalAuthority     Year New_Indicator New_Numerator  \
# 4203    CHN04     Aberdeen City  2022-23          0.63           nan
# 4215    CHN04     Aberdeenshire  2022-23          0.68           nan
# 4227    CHN04             Angus  2022-23          0.64           nan
# 4239    CHN04     Argyll & Bute  2022-23          0.66           nan
# 4251    CHN04  Clackmannanshire  2022-23          0.57           nan
# ...       ...               ...      ...           ...           ...
# 35067   CHN17          Scotland  2022-23          0.82           nan
# 35099  CHN20a          Scotland  2022-23         16.56           nan
# 35125   CHN22          Scotland  2022-23          0.06           nan
# 35138   CHN23          Scotland  2022-23          0.17           nan
# 35439  ECON11          Scotland  2022-23      27039.18           nan
#
#       New_Denominator
# 4203              nan
# 4215              nan
# 4227              nan
# 4239              nan
# 4251              nan
# ...               ...
# 35067             nan
# 35099             nan
# 35125             nan
# 35138             nan
# 35439             nan
#
# [364 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35464   SW07       Scotland  2018-19      0.82       nan         nan
# 35465   SW07       Scotland  2019-20      0.82       nan         nan
# 35466   SW07       Scotland  2020-21      0.82       nan         nan
# 35467   SW07       Scotland  2021-22      0.76       nan         nan
# 35468   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35469 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-e2be420cbd72> in <cell line: 1>()
# ----> 1 old_df.values==new_update.values
#
# ValueError: operands could not be broadcast together with shapes (35482,6) (35469,6)

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-6d539fd913ec> in <cell line: 2>()
#       1 #compare the old df to find the changes
# ----> 2 comparison_values = old_df.values == new_update.values
#       3 rows,cols=np.where(comparison_values==False)
#       4 rows
#
# ValueError: operands could not be broadcast together with shapes (35482,6) (35469,6)

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#            Code     LocalAuthority     Year Indicator New_Indicator  \
# 682      ENV01a      Aberdeen City  2022-23       nan         52.46
# 695      ENV02a      Aberdeen City  2022-23       nan        114.35
# 1561     CORP07      Aberdeenshire  2022-23      0.96          0.97
# 2725     ECON04              Angus  2022-23      0.42          0.32
# 9906     CORP04       East Lothian  2022-23      7.93          8.01
# 13170    ECON04        Eilean Siar  2022-23      0.29          0.28
# 30042  FINSUS01  South Lanarkshire  2022-23      0.22          0.21
# 30068  FINSUS03  South Lanarkshire  2022-23      0.05          0.04
# 30081  FINSUS04  South Lanarkshire  2022-23      0.17          0.14
# 33883    CORP04           Scotland  2022-23      6.84          6.84
# 33922    CORP07           Scotland  2022-23      0.96          0.96
# 34099    ENV01a           Scotland  2022-23     79.20         75.64
# 34112    ENV02a           Scotland  2022-23     99.76         95.28
#
#            Numerator  New_Numerator    Denominator New_Denominator
# 682          6525.00        6525.00            nan       124369.00
# 695         14221.00       14221.00            nan       124369.00
# 1561    153239000.00   154629000.00   159540000.00    159537000.00
# 2725             nan            nan            nan             nan
# 9906       416615.51      416615.51       52518.00        51982.00
# 13170            nan            nan            nan             nan
# 30042            nan            nan            nan             nan
# 30068            nan            nan            nan             nan
# 30081            nan            nan            nan             nan
# 33883    18541998.48    18541998.48     2711494.00      2710958.00
# 33922  2724082770.00  2725472770.00  2831919562.00   2831916562.00
# 34099      209129.00      209129.00     2640403.00      2764772.00
# 34112      263416.00      263416.00     2640403.00      2764772.00

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#      index    Code       LocalAuthority     Year Indicator New_Indicator  \
# 0      682  ENV01a        Aberdeen City  2022-23       nan         52.46
# 1      695  ENV02a        Aberdeen City  2022-23       nan        114.35
# 18     309  CHN13a        Aberdeen City  2022-23       NaN          0.71
# 19     313  CHN13b        Aberdeen City  2022-23       NaN          0.78
# 20     317  CHN14a        Aberdeen City  2022-23       NaN         23.36
# ..     ...     ...                  ...      ...       ...           ...
# 940  32644  CLIM04  West Dunbartonshire  2017-18       NaN         88.87
# 945  32649  CLIM05  West Dunbartonshire  2017-18       NaN         56.00
# 965  33729  CLIM03         West Lothian  2017-18       NaN         25.80
# 970  33734  CLIM04         West Lothian  2017-18       NaN        103.45
# 975  33739  CLIM05         West Lothian  2017-18       NaN         66.30
#
#     Numerator New_Numerator Denominator New_Denominator
# 0     6525.00       6525.00         nan       124369.00
# 1    14221.00      14221.00         nan       124369.00
# 18        NaN           nan         NaN             nan
# 19        NaN           nan         NaN             nan
# 20        NaN           nan         NaN             nan
# ..        ...           ...         ...             ...
# 940       NaN       7963.72         NaN        89610.00
# 945       NaN       4885.42         NaN        89610.00
# 965       NaN       4678.50         NaN       181310.00
# 970       NaN      18756.44         NaN       181310.00
# 975       NaN      12647.59         NaN       181310.00
#
# [1017 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/refs/heads/main/Datasets/LGBF_Data_Extract_Oct2024.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/refs/heads/main/Datasets/LGBF_Data_Nov2024.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code    LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2  C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3  C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4  C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#           Code    LocalAuthority          Year Indicator   Numerator  \
# 15728  CORP03b  Clackmannanshire       2023-24      0.60       68.00
# 18282   CORP09     Aberdeen City    2024-25 Q1      0.99     4370.00
# 18283   CORP09     Aberdeenshire    2024-25 Q1      0.99     1715.00
# 18284   CORP09             Angus    2024-25 Q1      0.99      895.00
# 18285   CORP09     Argyll & Bute    2024-25 Q1      1.00      315.00
# ...        ...               ...           ...       ...         ...
# 37129  ECON12a          Scotland  2024 October      0.03   111400.00
# 37130  ECON12b          Scotland  2024 October      0.04    19590.00
# 37169   ENV03a          Scotland       2022-23  14296.25    78342.00
# 37476    SW03a          Scotland       2023-24      0.63         nan
# 37513     SW05          Scotland       2022-23    682.81  1002960.00
#
#       Denominator
# 15728      113.00
# 18282     4405.00
# 18283     1725.00
# 18284      905.00
# 18285      315.00
# ...           ...
# ...

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW07  West Lothian   2019-20      0.81       nan         nan      0.81
#                      2020-21      0.84       nan         nan      0.84
#                      2021-22      0.81       nan         nan      0.81
#                      2022-23      0.76       nan         nan      0.76
#                      2023-24      0.85       nan         nan      0.85
#
#
# ...

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW06  West Lothian   2019-20    112.73   3780.00    33532.00    112.73
#                      2020-21    122.85   3485.00    28368.00    122.85
#                      2021-22    106.67   3464.00    32473.00    106.67
#                      2022-23     95.34   3088.00    32389.00     95.34
#                      2023-24     94.52   3330.00    35231.00     94.52
#
#
# ...

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['old_df'].compare(out['new_df'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'old_df'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-049b1674f2fc> in <cell line: 1>()
# ...

# %%
out
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW07  West Lothian   2019-20      0.81       nan         nan      0.81
#                      2020-21      0.84       nan         nan      0.84
#                      2021-22      0.81       nan         nan      0.81
#                      2022-23      0.76       nan         nan      0.76
#                      2023-24      0.85       nan         nan      0.85
#
#
# ...

# %%
df1.merge(df2, on=['Code','LocalAuthority','Year'], suffixes=['_old','_new']).drop_duplicates(keep= False)
# Out:
#         Code LocalAuthority     Year Indicator_old Numerator_old  \
# 0      C&L01  Aberdeen City  2010-11          0.33        637.00
# 1      C&L01  Aberdeen City  2011-12          0.76       1554.00
# 2      C&L01  Aberdeen City  2012-13          3.64       7883.00
# 3      C&L01  Aberdeen City  2013-14          3.48       7726.00
# 4      C&L01  Aberdeen City  2014-15          3.02       7517.00
# ...      ...            ...      ...           ...           ...
# 37207   SW07       Scotland  2019-20          0.82           nan
# 37208   SW07       Scotland  2020-21          0.82           nan
# 37209   SW07       Scotland  2021-22          0.76           nan
# 37210   SW07       Scotland  2022-23          0.75           nan
# 37211   SW07       Scotland  2023-24          0.77           nan
#
#       Denominator_old Indicator_new Numerator_new Denominator_new
# 0          1922292.00          0.33        637.00      1922292.00
# ...

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                  Indicator_old Numerator_old Denominator_old  \
# Code    LocalAuthority   Year
# CORP03b Clackmannanshire 2023-24          0.69        122.00          176.00
# ENV03a  Inverclyde       2022-23      18044.33       1384.00        76700.00
# SW03a   Aberdeen City    2022-23          0.51           nan             nan
#         Highland         2022-23          0.53           nan             nan
#         South Ayrshire   2022-23          0.58           nan             nan
# SW05    Inverclyde       2022-23        733.01      21250.00          557.50
# CORP03b Scotland         2023-24          0.60       6266.00        10445.00
# ENV03a  Scotland         2022-23      14255.00      78116.00      5479900.00
# SW05    Scotland         2022-23        683.97    1004657.00        28247.50
#
#                                  Indicator_new Numerator_new Denominator_new  \
# Code    LocalAuthority   Year
# ...

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
# ...

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#          Code LocalAuthority     Year Indicator   Numerator Denominator  \
# 8256   CHN12b  Aberdeen City  2020-21    505.00         nan         nan
# 8257   CHN12b  Aberdeen City  2020-21    566.00         nan         nan
# 8258   CHN12b  Aberdeen City  2021-22    566.00         nan         nan
# 8259   CHN12b  Aberdeen City  2021-22    567.00         nan         nan
# 8260   CHN12b  Aberdeen City  2022-23    567.00         nan         nan
# ...       ...            ...      ...       ...         ...         ...
# 35568   SW03a   West Lothian  2023-24      0.66         nan         nan
# 36594    SW05     Inverclyde  2022-23    674.47    19553.00      557.50
# 36595    SW05     Inverclyde  2022-23    733.01    21250.00      557.50
# 36699    SW05       Scotland  2022-23    682.81  1002960.00    28247.50
# 36700    SW05       Scotland  2022-23    683.97  1004657.00    28247.50
#
#            _merge
# 8256    left_only
# 8257   right_only
# 8258    left_only
# 8259   right_only
# ...

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 37211   SW07       Scotland  2019-20      0.82       nan         nan
# 37212   SW07       Scotland  2020-21      0.82       nan         nan
# 37213   SW07       Scotland  2021-22      0.76       nan         nan
# 37214   SW07       Scotland  2022-23      0.75       nan         nan
# 37215   SW07       Scotland  2023-24      0.77       nan         nan
#
# [37216 rows x 6 columns]

# %%
new_df
# Out:
#         Code    LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2      C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3      C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4      C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00
# ...      ...               ...      ...       ...       ...         ...
# 37536   SW07          Scotland  2019-20      0.82       nan         nan
# 37537   SW07          Scotland  2020-21      0.82       nan         nan
# 37538   SW07          Scotland  2021-22      0.76       nan         nan
# 37539   SW07          Scotland  2022-23      0.75       nan         nan
# 37540   SW07          Scotland  2023-24      0.77       nan         nan
#
# [37541 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 37211   SW07       Scotland  2019-20      0.82       nan         nan
# 37212   SW07       Scotland  2020-21      0.82       nan         nan
# 37213   SW07       Scotland  2021-22      0.76       nan         nan
# 37214   SW07       Scotland  2022-23      0.75       nan         nan
# 37215   SW07       Scotland  2023-24      0.77       nan         nan
#
# [37216 rows x 6 columns]

# %%
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
temp
# Out:
#         Code    LocalAuthority Year_new Indicator Numerator Denominator
# 0      C&L01     Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01     Aberdeenshire  2010-11      4.48   5641.00  1260286.00
# 2      C&L01             Angus  2010-11      1.96   3074.00  1568948.00
# 3      C&L01     Argyll & Bute  2010-11      2.42   1590.00   656840.00
# 4      C&L01  Clackmannanshire  2010-11      3.00   1639.00   545939.00
# ...      ...               ...      ...       ...       ...         ...
# 37536   SW07          Scotland  2019-20      0.82       nan         nan
# 37537   SW07          Scotland  2020-21      0.82       nan         nan
# 37538   SW07          Scotland  2021-22      0.76       nan         nan
# 37539   SW07          Scotland  2022-23      0.75       nan         nan
# 37540   SW07          Scotland  2023-24      0.77       nan         nan
#
# [37541 rows x 6 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 37211   SW07       Scotland  2019-20      0.82       nan         nan
# 37212   SW07       Scotland  2020-21      0.82       nan         nan
# 37213   SW07       Scotland  2021-22      0.76       nan         nan
# 37214   SW07       Scotland  2022-23      0.75       nan         nan
# 37215   SW07       Scotland  2023-24      0.77       nan         nan
#
# [37216 rows x 6 columns]

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([1265175, 1265176, 1265177, 1265178, 1265179, 1265180, 1265181,
#        1265182, 1265183, 1265184, 1265185, 1265186, 1265187, 1265188,
#        1265189, 1265190, 1265191, 1265192, 1265193, 1265194, 1265195,
#        1265196, 1265197, 1265198, 1265199, 1265200, 1265201, 1265202,
#        1265203, 1265204, 1265205, 1265206, 1265207, 1265208, 1265209,
#        1265210, 1265211, 1265212, 1265213, 1265214, 1265215, 1265216,
#        1265217, 1265218, 1265219, 1265220, 1265221, 1265222, 1265223,
#        1265224, 1265225, 1265226, 1265227, 1265228, 1265229, 1265230,
#        1265231, 1265232, 1265233, 1265234, 1265235, 1265236, 1265237,
#        1265238, 1493163, 1493164, 1493165, 1493166, 1493167, 1493168,
#        1493169, 1493170, 1493171, 1493172, 1493173, 1493174, 1493175,
#        1493176, 1493177, 1493178, 1493179, 1493180, 1493181, 1493182,
#        1493183, 1493184, 1493185, 1493186, 1493187, 1493188, 1493189,
# ...

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#           Code LocalAuthority          Year Indicator  Numerator Denominator
# 20530   ECON03  Aberdeen City       2021-22       nan        nan         nan
# 20531   ECON03  Aberdeen City       2022-23       nan        nan         nan
# 20673   ECON03        Falkirk       2021-22       nan        nan         nan
# 20674   ECON03        Falkirk       2022-23       nan        nan         nan
# 18282   CORP09  Aberdeen City    2024-25 Q1      0.99    4370.00     4405.00
# ...        ...            ...           ...       ...        ...         ...
# 37062   ECON05       Scotland  2024 October      1.06     581.00  5479900.00
# 37106   ECON09       Scotland       2023-24      0.12        nan         nan
# 37129  ECON12a       Scotland  2024 October      0.03  111400.00  3494517.00
# 37130  ECON12b       Scotland  2024 October      0.04   19590.00   557816.00
# 37476    SW03a       Scotland       2023-24      0.63        nan         nan
#
# [333 rows x 6 columns]

# %%
#new year added data
#new_Data = new_df.loc[new_year_df]
#new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
#new_Data = new_Data.drop_duplicates()
#new_Data
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-c0840ad59200> in <cell line: 2>()
#       1 #new year added data
# ----> 2 new_Data = new_df.loc[new_year_df]
#       3 new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
#       4 new_Data = new_Data.drop_duplicates()
#       5 new_Data
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1189             maybe_callable = com.apply_if_callable(key, self.obj)
#    1190             maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191             return self._getitem_axis(maybe_callable, axis=axis)
#    1192
#    1193     def _is_scalar_access(self, key: tuple):
#
# ...

# %%
from google.colab import files
new_Data. to_excel('new_Data.xlsx')
files.download('new_Data.xlsx')

# %% [markdown]
# #Use diff and new_Data

# %% [markdown]
# #STOP HERE

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-d28a3798df40> in <cell line: 2>()
#       1 #make df with only changes
# ----> 2 new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
#       3 new_update
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/range.py in __getitem__(self, key)
#    1028                 "arrays are valid indices"
#    1029             )
# -> 1030         return super().__getitem__(key)
#    1031
#    1032     def _getitem_slice(self, slobj: slice) -> Self:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    5414                     )
#    5415
# -> 5416         result = getitem(key)
#    5417         # Because we ruled out integer above, we always get an arraylike here
#    5418         if result.ndim > 1:
#
# ...

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-e2be420cbd72> in <cell line: 1>()
# ----> 1 old_df.values==new_update.values
#
# NameError: name 'new_update' is not defined

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-6d539fd913ec> in <cell line: 2>()
#       1 #compare the old df to find the changes
# ----> 2 comparison_values = old_df.values == new_update.values
#       3 rows,cols=np.where(comparison_values==False)
#       4 rows
#
# NameError: name 'new_update' is not defined

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-4fdcc668f1cd> in <cell line: 2>()
#       1 change_df = pd.DataFrame()
# ----> 2 change_df = old_df.loc[rows]
#       3 AddNew_df = new_update.loc[rows]
#       4 change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
#       5 change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
#
# NameError: name 'rows' is not defined

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#      index     Code       LocalAuthority     Year Indicator New_Indicator  \
# 124  12221    CHN21        Aberdeen City  2023-24       NaN          0.90
# 156  15426  CORP03b        Aberdeen City  2023-24       NaN          0.56
# 170  15869  CORP03c        Aberdeen City  2023-24       NaN         -0.06
# 183  16161   CORP04        Aberdeen City  2023-24       NaN          6.25
# 201  16609  CORP06a        Aberdeen City  2023-24       NaN          7.20
# ..     ...      ...                  ...      ...       ...           ...
# 25   12452    CHN21             Stirling  2022-23      0.96          0.94
# 26   12460    CHN21  West Dunbartonshire  2022-23      0.93          0.91
# 27   12468    CHN21         West Lothian  2022-23      0.95          0.94
# 47   16843  CORP06a      Perth & Kinross  2021-22      6.97          6.15
# 115  36882  CORP06a             Scotland  2021-22      5.84          5.82
#
#      Numerator New_Numerator Denominator New_Denominator
# ...

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

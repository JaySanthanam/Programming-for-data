# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_data_June2024.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_Data_Jul2024.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#          Code LocalAuthority     Year Indicator  Numerator Denominator
# 13174  CLIM01  Aberdeen City  2010-11      7.80        nan         nan
# 13175  CLIM01  Aberdeen City  2011-12      7.21        nan         nan
# 13176  CLIM01  Aberdeen City  2012-13      7.46        nan         nan
# 13177  CLIM01  Aberdeen City  2013-14      7.06        nan         nan
# 13179  CLIM01  Aberdeen City  2015-16      6.06        nan         nan
# ...       ...            ...      ...       ...        ...         ...
# 36334   SW04b       Scotland  2023-24      0.70        nan         nan
# 36340   SW04c       Scotland  2023-24      0.72        nan         nan
# 36346   SW04d       Scotland  2023-24      0.60        nan         nan
# 36378    SW06       Scotland  2022-23    102.22   97128.00   950151.00
# 36379    SW06       Scotland  2023-24    103.95  102941.00   990306.00
#
# [1140 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ENV04b Scotland       2022-24       NaN       NaN         NaN      0.29
# ENV04c Scotland       2022-24       NaN       NaN         NaN      0.32
# ENV04d Scotland       2022-24       NaN       NaN         NaN      0.33
# ENV04e Scotland       2020-24       NaN       NaN         NaN      0.36
# SW06   Scotland       2023-24       NaN       NaN         NaN    103.95
#
#
#                                Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11     637.00  1922292.00
#                       2011-12    1554.00  2045051.00
#                       2012-13    7883.00  2163756.00
#                       2013-14    7726.00  2222588.00
#                       2014-15    7517.00  2487138.00
# ...                                  ...         ...
# ENV04b Scotland       2022-24        nan         nan
# ENV04c Scotland       2022-24        nan         nan
# ENV04d Scotland       2022-24        nan         nan
# ENV04e Scotland       2020-24        nan         nan
# SW06   Scotland       2023-24  102941.00   990306.00
#
# [36393 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                          old                             new  \
#                                    Indicator Numerator Denominator Indicator
# Code   LocalAuthority      Year
# C&L01  Aberdeen City       2010-11      0.33    637.00  1922292.00      0.33
#                            2011-12      0.76   1554.00  2045051.00      0.76
#                            2012-13      3.64   7883.00  2163756.00      3.64
#                            2013-14      3.48   7726.00  2222588.00      3.48
#                            2014-15      3.02   7517.00  2487138.00      3.02
# ...                                      ...       ...         ...       ...
# SW06   West Dunbartonshire 2023-24       NaN       NaN         NaN     84.06
#        West Lothian        2023-24       NaN       NaN         NaN     94.52
# CLIM01 Scotland            2022-23       NaN       NaN         NaN      4.81
# CLIM02 Scotland            2022-23       NaN       NaN         NaN      4.27
# SW06   Scotland            2023-24       NaN       NaN         NaN    103.95
#
#
#                                     Numerator Denominator
# Code   LocalAuthority      Year
# C&L01  Aberdeen City       2010-11     637.00  1922292.00
#                            2011-12    1554.00  2045051.00
#                            2012-13    7883.00  2163756.00
#                            2013-14    7726.00  2222588.00
#                            2014-15    7517.00  2487138.00
# ...                                       ...         ...
# SW06   West Dunbartonshire 2023-24    1857.00    22091.00
#        West Lothian        2023-24    3330.00    35231.00
# CLIM01 Scotland            2022-23        nan         nan
# CLIM02 Scotland            2022-23        nan         nan
# SW06   Scotland            2023-24  102941.00   990306.00
#
# [19123 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3758         if is_single_key:
#    3759             if self.columns.nlevels > 1:
# -> 3760                 return self._getitem_multilevel(key)
#    3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3813     def _getitem_multilevel(self, key):
#    3814         # self.columns is a MultiIndex
# -> 3815         loc = self.columns.get_loc(key)
#    3816         if isinstance(loc, (slice, np.ndarray)):
#    3817             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2810
#    2811         if not isinstance(key, tuple):
# -> 2812             loc = self._get_level_indexer(key, level=0)
#    2813             return _maybe_to_slice(loc)
#    2814
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                     old                             new  \
#                               Indicator Numerator Denominator Indicator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                       2011-12      0.76   1554.00  2045051.00      0.76
#                       2012-13      3.64   7883.00  2163756.00      3.64
#                       2013-14      3.48   7726.00  2222588.00      3.48
#                       2014-15      3.02   7517.00  2487138.00      3.02
# ...                                 ...       ...         ...       ...
# ENV04b Scotland       2022-24       NaN       NaN         NaN      0.29
# ENV04c Scotland       2022-24       NaN       NaN         NaN      0.32
# ENV04d Scotland       2022-24       NaN       NaN         NaN      0.33
# ENV04e Scotland       2020-24       NaN       NaN         NaN      0.36
# SW06   Scotland       2023-24       NaN       NaN         NaN    103.95
#
#
#                                Numerator Denominator
# Code   LocalAuthority Year
# C&L01  Aberdeen City  2010-11     637.00  1922292.00
#                       2011-12    1554.00  2045051.00
#                       2012-13    7883.00  2163756.00
#                       2013-14    7726.00  2222588.00
#                       2014-15    7517.00  2487138.00
# ...                                  ...         ...
# ENV04b Scotland       2022-24        nan         nan
# ENV04c Scotland       2022-24        nan         nan
# ENV04d Scotland       2022-24        nan         nan
# ENV04e Scotland       2020-24        nan         nan
# SW06   Scotland       2023-24  102941.00   990306.00
#
# [36393 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                               Indicator_old Numerator_old Denominator_old  \
# Code   LocalAuthority Year
# CLIM01 Aberdeen City  2010-11          7.79           nan             nan
#                       2011-12          7.20           nan             nan
#                       2012-13          7.43           nan             nan
#                       2013-14          7.03           nan             nan
#                       2015-16          6.04           nan             nan
# ...                                     ...           ...             ...
# CLIM02 Scotland       2021-22          4.57           nan             nan
# SW04b  Scotland       2023-24          0.61           nan             nan
# SW04c  Scotland       2023-24          0.64           nan             nan
# SW04d  Scotland       2023-24          0.53           nan             nan
# SW06   Scotland       2022-23        101.68      94572.00       930133.00
#
#                               Indicator_new Numerator_new Denominator_new  \
# Code   LocalAuthority Year
# CLIM01 Aberdeen City  2010-11          7.80           nan             nan
#                       2011-12          7.21           nan             nan
#                       2012-13          7.46           nan             nan
#                       2013-14          7.06           nan             nan
#                       2015-16          6.06           nan             nan
# ...                                     ...           ...             ...
# CLIM02 Scotland       2021-22          4.53           nan             nan
# SW04b  Scotland       2023-24          0.70           nan             nan
# SW04c  Scotland       2023-24          0.72           nan             nan
# SW04d  Scotland       2023-24          0.60           nan             nan
# SW06   Scotland       2022-23        102.22      97128.00       950151.00
#
#                                Indicator_diff  Numerator_diff  \
# Code   LocalAuthority Year
# CLIM01 Aberdeen City  2010-11            True           False
#                       2011-12            True           False
#                       2012-13            True           False
#                       2013-14            True           False
#                       2015-16            True           False
# ...                                       ...             ...
# CLIM02 Scotland       2021-22            True           False
# SW04b  Scotland       2023-24            True           False
# SW04c  Scotland       2023-24            True           False
# SW04d  Scotland       2023-24            True           False
# SW06   Scotland       2022-23            True            True
#
#                                Denominator_diff  Record_Changed  \
# Code   LocalAuthority Year
# CLIM01 Aberdeen City  2010-11             False            True
#                       2011-12             False            True
#                       2012-13             False            True
#                       2013-14             False            True
#                       2015-16             False            True
# ...                                         ...             ...
# CLIM02 Scotland       2021-22             False            True
# SW04b  Scotland       2023-24             False            True
# SW04c  Scotland       2023-24             False            True
# SW04d  Scotland       2023-24             False            True
# SW06   Scotland       2022-23              True            True
#
#                                                     Cols_Changed
# Code   LocalAuthority Year
# CLIM01 Aberdeen City  2010-11                          Indicator
#                       2011-12                          Indicator
#                       2012-13                          Indicator
#                       2013-14                          Indicator
#                       2015-16                          Indicator
# ...                                                          ...
# CLIM02 Scotland       2021-22                          Indicator
# SW04b  Scotland       2023-24                          Indicator
# SW04c  Scotland       2023-24                          Indicator
# SW04d  Scotland       2023-24                          Indicator
# SW06   Scotland       2022-23  Indicator, Numerator, Denominator
#
# [909 rows x 11 columns]

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#          Code LocalAuthority     Year Indicator  Numerator Denominator  \
# 13174  CLIM01  Aberdeen City  2010-11      7.79        nan         nan
# 13175  CLIM01  Aberdeen City  2011-12      7.20        nan         nan
# 13176  CLIM01  Aberdeen City  2012-13      7.43        nan         nan
# 13177  CLIM01  Aberdeen City  2013-14      7.03        nan         nan
# 13179  CLIM01  Aberdeen City  2015-16      6.04        nan         nan
# ...       ...            ...      ...       ...        ...         ...
# 37297   SW04b       Scotland  2023-24      0.70        nan         nan
# 37298   SW04c       Scotland  2023-24      0.72        nan         nan
# 37299   SW04d       Scotland  2023-24      0.60        nan         nan
# 37300    SW06       Scotland  2022-23    102.22   97128.00   950151.00
# 37301    SW06       Scotland  2023-24    103.95  102941.00   990306.00
#
#            _merge
# 13174   left_only
# 13175   left_only
# 13176   left_only
# 13177   left_only
# 13179   left_only
# ...           ...
# 37297  right_only
# 37298  right_only
# 37299  right_only
# 37300  right_only
# 37301  right_only
#
# [2049 rows x 7 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36157   SW07       Scotland  2019-20      0.82       nan         nan
# 36158   SW07       Scotland  2020-21      0.82       nan         nan
# 36159   SW07       Scotland  2021-22      0.76       nan         nan
# 36160   SW07       Scotland  2022-23      0.75       nan         nan
# 36161   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36162 rows x 6 columns]

# %%
new_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36388   SW07       Scotland  2019-20      0.82       nan         nan
# 36389   SW07       Scotland  2020-21      0.82       nan         nan
# 36390   SW07       Scotland  2021-22      0.76       nan         nan
# 36391   SW07       Scotland  2022-23      0.75       nan         nan
# 36392   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36393 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([13186, 13199, 13212, 13225, 13238, 13251, 13264, 13277, 13290,
#        13303, 13316, 13329, 13342, 13355, 13368, 13381, 13394, 13407,
#        13420, 13433, 13446, 13459, 13472, 13485, 13498, 13511, 13524,
#        13537, 13550, 13563, 13576, 13589, 13602, 13615, 13628, 13641,
#        13654, 13667, 13680, 13693, 13706, 13719, 13732, 13745, 13758,
#        13771, 13784, 13797, 13810, 13823, 13836, 13849, 13862, 13875,
#        13888, 13901, 13914, 13927, 13940, 13953, 13966, 13979, 13992,
#        14005, 24752, 24766, 24780, 24794, 24808, 24822, 24836, 24850,
#        24864, 24878, 24892, 24906, 24920, 24934, 24948, 24962, 24976,
#        24990, 25004, 25018, 25032, 25046, 25060, 25074, 25088, 25102,
#        25116, 25130, 25144, 25158, 25172, 25186, 25200, 25214, 25228,
#        25242, 25256, 25270, 25284, 25298, 25312, 25326, 25340, 25354,
#        25368, 25382, 25396, 25410, 25424, 25438, 25452, 25466, 25480,
#        25494, 25508, 25522, 25536, 25550, 25564, 25578, 25592, 25606,
#        25620, 25634, 25648, 25662, 25676, 25690, 25704, 25718, 25732,
#        25746, 25760, 25774, 25788, 25802, 25816, 25830, 25844, 25858,
#        25872, 25886, 25900, 25914, 25928, 25942, 25956, 25970, 25984,
#        25998, 26012, 26026, 26040, 26054, 26068, 26082, 26096, 26110,
#        26124, 26138, 26152, 26166, 26180, 26194, 26208, 26222, 26236,
#        26250, 26264, 26278, 26292, 26306, 26320, 26334, 26348, 26362,
#        26376, 26390, 26404, 26418, 26432, 26446, 26460, 26474, 26488,
#        26502, 26516, 26530, 34422, 34436, 34450, 34464, 34478, 34492,
#        34506, 34520, 34534, 34548, 34562, 34576, 34590, 34604, 34618,
#        34632, 34646, 34660, 34674, 34688, 34702, 34716, 34730, 34744,
#        34758, 34772, 34786, 34800, 34814, 34828, 34842, 34856, 35703,
#        35716, 36068, 36082, 36096, 36110, 36379])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#          Code    LocalAuthority     Year Indicator  Numerator Denominator
# 13186  CLIM01     Aberdeen City  2022-23      4.74        nan         nan
# 13199  CLIM01     Aberdeenshire  2022-23      6.34        nan         nan
# 13212  CLIM01             Angus  2022-23      8.02        nan         nan
# 13225  CLIM01     Argyll & Bute  2022-23     -3.51        nan         nan
# 13238  CLIM01  Clackmannanshire  2022-23      9.08        nan         nan
# ...       ...               ...      ...       ...        ...         ...
# 36068  ENV04b          Scotland  2022-24      0.29        nan         nan
# 36082  ENV04c          Scotland  2022-24      0.32        nan         nan
# 36096  ENV04d          Scotland  2022-24      0.33        nan         nan
# 36110  ENV04e          Scotland  2020-24      0.36        nan         nan
# 36379    SW06          Scotland  2023-24    103.95  102941.00   990306.00
#
# [231 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#          Code    LocalAuthority     Year New_Indicator New_Numerator  \
# 13186  CLIM01     Aberdeen City  2022-23          4.74           nan
# 13199  CLIM01     Aberdeenshire  2022-23          6.34           nan
# 13212  CLIM01             Angus  2022-23          8.02           nan
# 13225  CLIM01     Argyll & Bute  2022-23         -3.51           nan
# 13238  CLIM01  Clackmannanshire  2022-23          9.08           nan
# ...       ...               ...      ...           ...           ...
# 36068  ENV04b          Scotland  2022-24          0.29           nan
# 36082  ENV04c          Scotland  2022-24          0.32           nan
# 36096  ENV04d          Scotland  2022-24          0.33           nan
# 36110  ENV04e          Scotland  2020-24          0.36           nan
# 36379    SW06          Scotland  2023-24        103.95     102941.00
#
#       New_Denominator
# 13186             nan
# 13199             nan
# 13212             nan
# 13225             nan
# 13238             nan
# ...               ...
# 36068             nan
# 36082             nan
# 36096             nan
# 36110             nan
# 36379       990306.00
#
# [231 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36157   SW07       Scotland  2019-20      0.82       nan         nan
# 36158   SW07       Scotland  2020-21      0.82       nan         nan
# 36159   SW07       Scotland  2021-22      0.76       nan         nan
# 36160   SW07       Scotland  2022-23      0.75       nan         nan
# 36161   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36162 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([13174, 13175, 13176, 13177, 13179, 13180, 13181, 13182, 13183,
#        13184, 13185, 13186, 13187, 13188, 13189, 13190, 13191, 13192,
#        13193, 13194, 13195, 13196, 13197, 13198, 13199, 13200, 13201,
#        13202, 13204, 13205, 13206, 13207, 13208, 13209, 13210, 13211,
#        13212, 13213, 13214, 13215, 13216, 13217, 13218, 13219, 13220,
#        13221, 13222, 13223, 13224, 13225, 13226, 13227, 13228, 13229,
#        13230, 13231, 13232, 13233, 13234, 13235, 13236, 13237, 13238,
#        13239, 13240, 13241, 13242, 13243, 13244, 13245, 13246, 13247,
#        13248, 13249, 13250, 13251, 13252, 13253, 13254, 13255, 13256,
#        13257, 13258, 13259, 13260, 13261, 13262, 13263, 13264, 13265,
#        13266, 13267, 13268, 13269, 13270, 13271, 13272, 13273, 13274,
#        13275, 13276, 13277, 13278, 13279, 13280, 13281, 13282, 13283,
#        13285, 13286, 13287, 13290, 13291, 13292, 13293, 13294, 13295,
#        13296, 13297, 13298, 13299, 13300, 13301, 13302, 13303, 13304,
#        13305, 13306, 13307, 13308, 13309, 13310, 13311, 13312, 13313,
#        13314, 13315, 13316, 13317, 13318, 13319, 13320, 13321, 13322,
#        13323, 13324, 13325, 13326, 13327, 13328, 13329, 13330, 13331,
#        13332, 13333, 13334, 13335, 13336, 13337, 13338, 13339, 13340,
#        13341, 13342, 13343, 13344, 13345, 13346, 13347, 13348, 13349,
#        13350, 13351, 13352, 13353, 13354, 13355, 13356, 13357, 13358,
#        13359, 13360, 13361, 13362, 13363, 13364, 13365, 13366, 13367,
#        13368, 13369, 13370, 13371, 13372, 13373, 13374, 13375, 13376,
#        13377, 13378, 13379, 13380, 13381, 13382, 13383, 13384, 13385,
#        13386, 13387, 13388, 13389, 13390, 13391, 13392, 13393, 13394,
#        13395, 13396, 13397, 13398, 13399, 13400, 13401, 13402, 13403,
#        13404, 13405, 13406, 13407, 13408, 13409, 13410, 13411, 13412,
#        13413, 13414, 13415, 13416, 13417, 13418, 13419, 13420, 13421,
#        13422, 13423, 13424, 13425, 13426, 13427, 13428, 13429, 13430,
#        13431, 13432, 13433, 13434, 13435, 13437, 13438, 13439, 13440,
#        13441, 13442, 13443, 13444, 13445, 13446, 13447, 13448, 13449,
#        13450, 13451, 13452, 13453, 13454, 13455, 13456, 13457, 13458,
#        13459, 13460, 13461, 13462, 13463, 13464, 13465, 13466, 13467,
#        13468, 13469, 13470, 13471, 13472, 13473, 13474, 13475, 13476,
#        13477, 13478, 13479, 13480, 13481, 13482, 13483, 13484, 13485,
#        13486, 13487, 13488, 13489, 13490, 13491, 13492, 13493, 13494,
#        13495, 13496, 13497, 13498, 13499, 13500, 13501, 13502, 13503,
#        13504, 13505, 13506, 13507, 13508, 13509, 13510, 13511, 13512,
#        13513, 13514, 13515, 13516, 13517, 13518, 13519, 13520, 13521,
#        13522, 13523, 13524, 13525, 13526, 13527, 13528, 13529, 13530,
#        13531, 13532, 13533, 13534, 13535, 13536, 13538, 13539, 13540,
#        13541, 13542, 13543, 13544, 13545, 13546, 13547, 13548, 13549,
#        13550, 13551, 13552, 13553, 13554, 13555, 13557, 13558, 13559,
#        13560, 13561, 13563, 13564, 13565, 13566, 13567, 13568, 13569,
#        13570, 13571, 13572, 13573, 13574, 13575, 13576, 13577, 13578,
#        13579, 13580, 13581, 13582, 13583, 13584, 13585, 13586, 13587,
#        13588, 13589, 13590, 13591, 13592, 13593, 13594, 13595, 13596,
#        13597, 13598, 13599, 13600, 13601, 13602, 13603, 13604, 13605,
#        13606, 13607, 13608, 13609, 13610, 13611, 13612, 13613, 13614,
#        13615, 13616, 13617, 13618, 13619, 13620, 13621, 13622, 13623,
#        13624, 13625, 13626, 13627, 13628, 13629, 13630, 13631, 13632,
#        13633, 13634, 13635, 13636, 13637, 13638, 13639, 13640, 13641,
#        13642, 13643, 13644, 13645, 13646, 13647, 13648, 13649, 13650,
#        13651, 13652, 13653, 13654, 13655, 13656, 13657, 13658, 13659,
#        13660, 13661, 13662, 13663, 13664, 13665, 13666, 13667, 13668,
#        13669, 13670, 13671, 13672, 13673, 13674, 13675, 13676, 13677,
#        13678, 13679, 13680, 13681, 13682, 13683, 13684, 13685, 13686,
#        13687, 13688, 13689, 13690, 13691, 13692, 13693, 13694, 13695,
#        13696, 13697, 13698, 13699, 13700, 13701, 13702, 13703, 13704,
#        13705, 13706, 13707, 13708, 13709, 13710, 13711, 13712, 13713,
#        13714, 13715, 13716, 13717, 13718, 13719, 13720, 13721, 13722,
#        13723, 13724, 13725, 13726, 13727, 13728, 13729, 13730, 13731,
#        13732, 13733, 13734, 13735, 13736, 13737, 13738, 13739, 13740,
#        13741, 13742, 13743, 13744, 13745, 13746, 13747, 13748, 13749,
#        13750, 13751, 13752, 13753, 13754, 13755, 13756, 13757, 13758,
#        13759, 13760, 13761, 13762, 13763, 13764, 13765, 13766, 13767,
#        13768, 13769, 13770, 13771, 13772, 13773, 13774, 13775, 13776,
#        13777, 13778, 13779, 13780, 13781, 13782, 13783, 13784, 13785,
#        13786, 13787, 13788, 13789, 13790, 13791, 13792, 13793, 13794,
#        13795, 13796, 13797, 13798, 13799, 13800, 13801, 13802, 13803,
#        13804, 13805, 13806, 13807, 13808, 13809, 13810, 13811, 13812,
#        13813, 13814, 13815, 13816, 13817, 13818, 13819, 13820, 13821,
#        13822, 13823, 13824, 13825, 13826, 13827, 13828, 13829, 13830,
#        13831, 13832, 13833, 13834, 13835, 13836, 13837, 13838, 13839,
#        13840, 13841, 13842, 13843, 13844, 13845, 13846, 13847, 13848,
#        13849, 13850, 13851, 13852, 13853, 13854, 13855, 13856, 13857,
#        13858, 13859, 13860, 13861, 13862, 13863, 13864, 13865, 13866,
#        13867, 13868, 13869, 13870, 13871, 13872, 13873, 13874, 13875,
#        13876, 13877, 13878, 13879, 13880, 13881, 13882, 13883, 13884,
#        13885, 13886, 13887, 13888, 13889, 13890, 13891, 13892, 13893,
#        13894, 13895, 13896, 13897, 13898, 13899, 13900, 13901, 13902,
#        13903, 13904, 13905, 13906, 13907, 13908, 13909, 13910, 13911,
#        13912, 13913, 13914, 13915, 13916, 13917, 13918, 13919, 13920,
#        13921, 13922, 13923, 13924, 13925, 13926, 13927, 13928, 13929,
#        13930, 13931, 13932, 13933, 13934, 13935, 13936, 13938, 13939,
#        13940, 33038, 33044, 33050, 33056, 33062, 33068, 33074, 33080,
#        33086, 33092, 33098, 33104, 33110, 33116, 33122, 33128, 33134,
#        33140, 33146, 33152, 33158, 33164, 33170, 33176, 33182, 33188,
#        33194, 33200, 33206, 33212, 33218, 33224, 33230, 33236, 33242,
#        33248, 33260, 33266, 33272, 33278, 33284, 33290, 33296, 33302,
#        33308, 33314, 33320, 33326, 33332, 33338, 33344, 33350, 33356,
#        33362, 33368, 33374, 33380, 33386, 33392, 33398, 33404, 33410,
#        33416, 33422, 33428, 33434, 33440, 33446, 33452, 33458, 33464,
#        33470, 33476, 33482, 33488, 33494, 33500, 33506, 33512, 33518,
#        33524, 33530, 33536, 33542, 33548, 33554, 33560, 33566, 33572,
#        33584, 33590, 33596, 33602, 33608, 34229, 34229, 34229, 34242,
#        34242, 34242, 34255, 34255, 34255, 34268, 34268, 34268, 34281,
#        34281, 34281, 34294, 34294, 34294, 34307, 34307, 34307, 34320,
#        34320, 34320, 34333, 34333, 34333, 34346, 34346, 34346, 34359,
#        34359, 34359, 34372, 34372, 34372, 34385, 34385, 34385, 34398,
#        34398, 34398, 34411, 34411, 34411, 34424, 34424, 34424, 34437,
#        34437, 34437, 34450, 34450, 34450, 34463, 34463, 34463, 34476,
#        34476, 34476, 34489, 34489, 34489, 34502, 34502, 34502, 34515,
#        34515, 34528, 34528, 34528, 34541, 34541, 34541, 34554, 34554,
#        34554, 34567, 34567, 34567, 34580, 34580, 34580, 34593, 34593,
#        34593, 34606, 34606, 34606, 34619, 34619, 34619, 34632, 34632,
#        34632, 35467, 35468, 35469, 35470, 35471, 35472, 35473, 35474,
#        35475, 35476, 35477, 35478, 35479, 35480, 35481, 35482, 35483,
#        35484, 35485, 35486, 35488, 35490, 36104, 36110, 36116, 36148,
#        36148, 36148])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#          Code LocalAuthority     Year Indicator New_Indicator Numerator  \
# 13174  CLIM01  Aberdeen City  2010-11      7.79          7.80       nan
# 13175  CLIM01  Aberdeen City  2011-12      7.20          7.21       nan
# 13176  CLIM01  Aberdeen City  2012-13      7.43          7.46       nan
# 13177  CLIM01  Aberdeen City  2013-14      7.03          7.06       nan
# 13179  CLIM01  Aberdeen City  2015-16      6.04          6.06       nan
# ...       ...            ...      ...       ...           ...       ...
# 35490  CLIM02       Scotland  2021-22      4.57          4.53       nan
# 36104   SW04b       Scotland  2023-24      0.61          0.70       nan
# 36110   SW04c       Scotland  2023-24      0.64          0.72       nan
# 36116   SW04d       Scotland  2023-24      0.53          0.60       nan
# 36148    SW06       Scotland  2022-23    101.68        102.22  94572.00
#
#       New_Numerator Denominator New_Denominator
# 13174           nan         nan             nan
# 13175           nan         nan             nan
# 13176           nan         nan             nan
# 13177           nan         nan             nan
# 13179           nan         nan             nan
# ...             ...         ...             ...
# 35490           nan         nan             nan
# 36104           nan         nan             nan
# 36110           nan         nan             nan
# 36116           nan         nan             nan
# 36148      97128.00   930133.00       950151.00
#
# [909 rows x 9 columns]

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#       index    Code       LocalAuthority     Year Indicator New_Indicator  \
# 757   33038   SW04b        Aberdeen City  2023-24      0.63          0.74
# 789   33230   SW04c        Aberdeen City  2023-24      0.68          0.77
# 820   33422   SW04d        Aberdeen City  2023-24      0.48          0.57
# 1101  34422    SW06        Aberdeen City  2023-24       NaN        126.05
# 758   33044   SW04b        Aberdeenshire  2023-24      0.66          0.74
# ...     ...     ...                  ...      ...       ...           ...
# 723   13906  CLIM02             Stirling  2010-11      9.40          9.16
# 354   13534  CLIM01  West Dunbartonshire  2010-11      6.07          6.06
# 735   13918  CLIM02  West Dunbartonshire  2010-11      6.04          6.02
# 365   13546  CLIM01         West Lothian  2010-11      8.07          8.01
# 747   13930  CLIM02         West Lothian  2010-11      6.99          6.98
#
#      Numerator New_Numerator Denominator New_Denominator
# 757        nan           nan         nan             nan
# 789        nan           nan         nan             nan
# 820        nan           nan         nan             nan
# 1101       NaN       3835.00         NaN        30424.00
# 758        nan           nan         nan             nan
# ...        ...           ...         ...             ...
# 723        nan           nan         nan             nan
# 354        nan           nan         nan             nan
# 735        nan           nan         nan             nan
# 365        nan           nan         nan             nan
# 747        nan           nan         nan             nan
#
# [1140 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

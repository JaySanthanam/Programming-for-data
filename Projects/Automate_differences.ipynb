# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %% [markdown]
# #Load files
#
# ##new_df is new data including new year's data
# ##diff_df has old data (no changes or new data for the new year)

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

# %%
url_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_data_May.csv"
url_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/LGBF_data_June.csv"
old_df = get_data(url_old)
new_df = get_data(url_new)

# %%
old_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df.dtypes
# Out:
# Code               object
# LocalAuthority     object
# Year               object
# Indicator         float64
# Numerator         float64
# Denominator       float64
# dtype: object

# %%
new_df['Indicator'] = new_df['Indicator'].map("{:.2f}".format)
new_df['Numerator'] = new_df['Numerator'].map('{:.2f}'.format)
new_df['Denominator'] = new_df['Denominator'].map('{:.2f}'.format)

# %%
old_df['Indicator'] = old_df['Indicator'].map('{:.2f}'.format)
old_df['Numerator'] = old_df['Numerator'].map('{:.2f}'.format)
old_df['Denominator'] = old_df['Denominator'].map('{:.2f}'.format)

# %%
old_df = old_df.round(4)
new_df = new_df.round(4)

# %%
old_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
new_df.head()
# Out:
#     Code LocalAuthority     Year Indicator Numerator Denominator
# 0  C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1  C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2  C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3  C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4  C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00

# %%
df1 = old_df
df2 = new_df

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
#         Code    LocalAuthority     Year Indicator Numerator Denominator
# 12894  CHN24     Aberdeen City  2022-23      0.22       nan         nan
# 12903  CHN24     Aberdeenshire  2022-23      0.17       nan         nan
# 12912  CHN24             Angus  2022-23      0.25       nan         nan
# 12921  CHN24     Argyll & Bute  2022-23      0.23       nan         nan
# 12930  CHN24  Clackmannanshire  2022-23      0.29       nan         nan
# ...      ...               ...      ...       ...       ...         ...
# 36104  SW04b          Scotland  2023-24      0.61       nan         nan
# 36110  SW04c          Scotland  2023-24      0.64       nan         nan
# 36116  SW04d          Scotland  2023-24      0.53       nan         nan
# 36122  SW04e          Scotland  2023-24      0.31       nan         nan
# 36161   SW07          Scotland  2023-24      0.77       nan         nan
#
# [234 rows x 6 columns]

# %%
out = pd.merge(old_df, new_df, on=['Code', 'LocalAuthority', 'Year'], how='outer',
               suffixes=('_old', '_new')).set_index(['Code', 'LocalAuthority', 'Year'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()

# %%
out
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW04b Scotland       2023-24       NaN       NaN         NaN      0.61
# SW04c Scotland       2023-24       NaN       NaN         NaN      0.64
# SW04d Scotland       2023-24       NaN       NaN         NaN      0.53
# SW04e Scotland       2023-24       NaN       NaN         NaN      0.31
# SW07  Scotland       2023-24       NaN       NaN         NaN      0.77
#
#
#                              Numerator Denominator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11    637.00  1922292.00
#                      2011-12   1554.00  2045051.00
#                      2012-13   7883.00  2163756.00
#                      2013-14   7726.00  2222588.00
#                      2014-15   7517.00  2487138.00
# ...                                ...         ...
# SW04b Scotland       2023-24       nan         nan
# SW04c Scotland       2023-24       nan         nan
# SW04d Scotland       2023-24       nan         nan
# SW04e Scotland       2023-24       nan         nan
# SW07  Scotland       2023-24       nan         nan
#
# [36162 rows x 6 columns]

# %%
newdf=out.drop_duplicates(keep=False)
newdf
# Out:
#                                         old                             new  \
#                                   Indicator Numerator Denominator Indicator
# Code  LocalAuthority      Year
# C&L01 Aberdeen City       2010-11      0.33    637.00  1922292.00      0.33
#                           2011-12      0.76   1554.00  2045051.00      0.76
#                           2012-13      3.64   7883.00  2163756.00      3.64
#                           2013-14      3.48   7726.00  2222588.00      3.48
#                           2014-15      3.02   7517.00  2487138.00      3.02
# ...                                     ...       ...         ...       ...
# SW07  Dumfries & Galloway 2023-24       NaN       NaN         NaN      0.74
#       East Dunbartonshire 2023-24       NaN       NaN         NaN      0.86
#       East Lothian        2023-24       NaN       NaN         NaN      0.82
#       Falkirk             2023-24       NaN       NaN         NaN      0.87
#       Stirling            2023-24       NaN       NaN         NaN      0.84
#
#
#                                   Numerator Denominator
# Code  LocalAuthority      Year
# C&L01 Aberdeen City       2010-11    637.00  1922292.00
#                           2011-12   1554.00  2045051.00
#                           2012-13   7883.00  2163756.00
#                           2013-14   7726.00  2222588.00
#                           2014-15   7517.00  2487138.00
# ...                                     ...         ...
# SW07  Dumfries & Galloway 2023-24       nan         nan
#       East Dunbartonshire 2023-24       nan         nan
#       East Lothian        2023-24       nan         nan
#       Falkirk             2023-24       nan         nan
#       Stirling            2023-24       nan         nan
#
# [18372 rows x 6 columns]

# %%
from google.colab import files
newdf. to_excel('newdf.xlsx')
files.download('newdf.xlsx')

# %%
diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'df1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-084292704967> in <cell line: 1>()
# ----> 1 diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "Code"])).reset_index()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3758         if is_single_key:
#    3759             if self.columns.nlevels > 1:
# -> 3760                 return self._getitem_multilevel(key)
#    3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in _getitem_multilevel(self, key)
#    3813     def _getitem_multilevel(self, key):
#    3814         # self.columns is a MultiIndex
# -> 3815         loc = self.columns.get_loc(key)
#    3816         if isinstance(loc, (slice, np.ndarray)):
#    3817             new_columns = self.columns[loc]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in get_loc(self, key)
#    2810
#    2811         if not isinstance(key, tuple):
# -> 2812             loc = self._get_level_indexer(key, level=0)
#    2813             return _maybe_to_slice(loc)
#    2814
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_level_indexer(self, key, level, indexer)
#    3158
#    3159         else:
# -> 3160             idx = self._get_loc_single_level_index(level_index, key)
#    3161
#    3162             if level > 0 or self._lexsort_depth == 0:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/multi.py in _get_loc_single_level_index(self, level_index, key)
#    2750             return -1
#    2751         else:
# -> 2752             return level_index.get_loc(key)
#    2753
#    2754     def get_loc(self, key):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'df1'

# %%
out
# Out:
#                                    old                             new  \
#                              Indicator Numerator Denominator Indicator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11      0.33    637.00  1922292.00      0.33
#                      2011-12      0.76   1554.00  2045051.00      0.76
#                      2012-13      3.64   7883.00  2163756.00      3.64
#                      2013-14      3.48   7726.00  2222588.00      3.48
#                      2014-15      3.02   7517.00  2487138.00      3.02
# ...                                ...       ...         ...       ...
# SW04b Scotland       2023-24       NaN       NaN         NaN      0.61
# SW04c Scotland       2023-24       NaN       NaN         NaN      0.64
# SW04d Scotland       2023-24       NaN       NaN         NaN      0.53
# SW04e Scotland       2023-24       NaN       NaN         NaN      0.31
# SW07  Scotland       2023-24       NaN       NaN         NaN      0.77
#
#
#                              Numerator Denominator
# Code  LocalAuthority Year
# C&L01 Aberdeen City  2010-11    637.00  1922292.00
#                      2011-12   1554.00  2045051.00
#                      2012-13   7883.00  2163756.00
#                      2013-14   7726.00  2222588.00
#                      2014-15   7517.00  2487138.00
# ...                                ...         ...
# SW04b Scotland       2023-24       nan         nan
# SW04c Scotland       2023-24       nan         nan
# SW04d Scotland       2023-24       nan         nan
# SW04e Scotland       2023-24       nan         nan
# SW07  Scotland       2023-24       nan         nan
#
# [36162 rows x 6 columns]

# %%
def dataframe_difference(df1, df2, which=None):
    """Find rows which are different between two DataFrames."""
    comparison_df = df1.merge(
        df2,
        indicator=True,
        how='outer'
    )
    if which is None:
        diff_df = comparison_df[comparison_df['_merge'] != 'both']  # Identify data changes/updates
    else:
        diff_df = comparison_df[comparison_df['_merge'] == which]
    return diff_df

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)

# %%
df1 = old_df.set_index(['Code', 'LocalAuthority', 'Year'])
df2 = new_df.set_index(['Code','LocalAuthority', 'Year'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
#                                   Indicator_old Numerator_old Denominator_old  \
# Code  LocalAuthority      Year
# ENV06 Argyll & Bute       2010-11          0.42           nan             nan
#       Clackmannanshire    2017-18          0.60           nan             nan
#       Dumfries & Galloway 2010-11          0.38           nan             nan
#                           2019-20          0.30           nan             nan
#       Dundee City         2017-18          0.36           nan             nan
#       East Ayrshire       2022-23          0.49           nan             nan
#       Eilean Siar         2019-20          0.21           nan             nan
#       Fife                2019-20          0.44           nan             nan
#       Glasgow City        2012-13          0.30           nan             nan
#       Highland            2011-12          0.44           nan             nan
#                           2015-16          0.44           nan             nan
#       Inverclyde          2010-11          0.31           nan             nan
#                           2013-14          0.55           nan             nan
#       North Ayrshire      2010-11          0.44           nan             nan
#                           2014-15          0.57           nan             nan
#       North Lanarkshire   2010-11          0.44           nan             nan
#       Orkney Islands      2012-13          0.22           nan             nan
#                           2020-21          0.26           nan             nan
#       Perth & Kinross     2014-15          0.57           nan             nan
#       Shetland Islands    2010-11          0.18           nan             nan
#                           2012-13          0.13           nan             nan
#                           2018-19          0.11           nan             nan
#       South Ayrshire      2015-16          0.51           nan             nan
#                           2017-18          0.55           nan             nan
#       Stirling            2010-11          0.48           nan             nan
#                           2011-12          0.53           nan             nan
#       West Dunbartonshire 2018-19          0.44           nan             nan
# CHN24 Scotland            2014-15          0.20           nan             nan
#                           2015-16          0.21           nan             nan
#                           2016-17          0.22           nan             nan
#                           2017-18          0.22           nan             nan
#                           2018-19          0.21           nan             nan
#                           2019-20          0.23           nan             nan
#                           2020-21          0.21           nan             nan
#                           2021-22          0.23           nan             nan
# ENV06 Scotland            2010-11          0.39           nan             nan
#
#                                   Indicator_new Numerator_new Denominator_new  \
# Code  LocalAuthority      Year
# ENV06 Argyll & Bute       2010-11          0.41           nan             nan
#       Clackmannanshire    2017-18          0.59           nan             nan
#       Dumfries & Galloway 2010-11          0.39           nan             nan
#                           2019-20          0.29           nan             nan
#       Dundee City         2017-18          0.35           nan             nan
#       East Ayrshire       2022-23          0.48           nan             nan
#       Eilean Siar         2019-20          0.20           nan             nan
#       Fife                2019-20          0.45           nan             nan
#       Glasgow City        2012-13          0.29           nan             nan
#       Highland            2011-12          0.45           nan             nan
#                           2015-16          0.45           nan             nan
#       Inverclyde          2010-11          0.32           nan             nan
#                           2013-14          0.56           nan             nan
#       North Ayrshire      2010-11          0.43           nan             nan
#                           2014-15          0.56           nan             nan
#       North Lanarkshire   2010-11          0.43           nan             nan
#       Orkney Islands      2012-13          0.23           nan             nan
#                           2020-21          0.23           nan             nan
#       Perth & Kinross     2014-15          0.56           nan             nan
#       Shetland Islands    2010-11          0.20           nan             nan
#                           2012-13          0.14           nan             nan
#                           2018-19          0.10           nan             nan
#       South Ayrshire      2015-16          0.52           nan             nan
#                           2017-18          0.53           nan             nan
#       Stirling            2010-11          0.47           nan             nan
#                           2011-12          0.54           nan             nan
#       West Dunbartonshire 2018-19          0.43           nan             nan
# CHN24 Scotland            2014-15          0.19           nan             nan
#                           2015-16          0.20           nan             nan
#                           2016-17          0.20           nan             nan
#                           2017-18          0.21           nan             nan
#                           2018-19          0.20           nan             nan
#                           2019-20          0.22           nan             nan
#                           2020-21          0.20           nan             nan
#                           2021-22          0.21           nan             nan
# ENV06 Scotland            2010-11          0.38           nan             nan
#
#                                    Indicator_diff  Numerator_diff  \
# Code  LocalAuthority      Year
# ENV06 Argyll & Bute       2010-11            True           False
#       Clackmannanshire    2017-18            True           False
#       Dumfries & Galloway 2010-11            True           False
#                           2019-20            True           False
#       Dundee City         2017-18            True           False
#       East Ayrshire       2022-23            True           False
#       Eilean Siar         2019-20            True           False
#       Fife                2019-20            True           False
#       Glasgow City        2012-13            True           False
#       Highland            2011-12            True           False
#                           2015-16            True           False
#       Inverclyde          2010-11            True           False
#                           2013-14            True           False
#       North Ayrshire      2010-11            True           False
#                           2014-15            True           False
#       North Lanarkshire   2010-11            True           False
#       Orkney Islands      2012-13            True           False
#                           2020-21            True           False
#       Perth & Kinross     2014-15            True           False
#       Shetland Islands    2010-11            True           False
#                           2012-13            True           False
#                           2018-19            True           False
#       South Ayrshire      2015-16            True           False
#                           2017-18            True           False
#       Stirling            2010-11            True           False
#                           2011-12            True           False
#       West Dunbartonshire 2018-19            True           False
# CHN24 Scotland            2014-15            True           False
#                           2015-16            True           False
#                           2016-17            True           False
#                           2017-18            True           False
#                           2018-19            True           False
#                           2019-20            True           False
#                           2020-21            True           False
#                           2021-22            True           False
# ENV06 Scotland            2010-11            True           False
#
#                                    Denominator_diff  Record_Changed  \
# Code  LocalAuthority      Year
# ENV06 Argyll & Bute       2010-11             False            True
#       Clackmannanshire    2017-18             False            True
#       Dumfries & Galloway 2010-11             False            True
#                           2019-20             False            True
#       Dundee City         2017-18             False            True
#       East Ayrshire       2022-23             False            True
#       Eilean Siar         2019-20             False            True
#       Fife                2019-20             False            True
#       Glasgow City        2012-13             False            True
#       Highland            2011-12             False            True
#                           2015-16             False            True
#       Inverclyde          2010-11             False            True
#                           2013-14             False            True
#       North Ayrshire      2010-11             False            True
#                           2014-15             False            True
#       North Lanarkshire   2010-11             False            True
#       Orkney Islands      2012-13             False            True
#                           2020-21             False            True
#       Perth & Kinross     2014-15             False            True
#       Shetland Islands    2010-11             False            True
#                           2012-13             False            True
#                           2018-19             False            True
#       South Ayrshire      2015-16             False            True
#                           2017-18             False            True
#       Stirling            2010-11             False            True
#                           2011-12             False            True
#       West Dunbartonshire 2018-19             False            True
# CHN24 Scotland            2014-15             False            True
#                           2015-16             False            True
#                           2016-17             False            True
#                           2017-18             False            True
#                           2018-19             False            True
#                           2019-20             False            True
#                           2020-21             False            True
#                           2021-22             False            True
# ENV06 Scotland            2010-11             False            True
#
#                                   Cols_Changed
# Code  LocalAuthority      Year
# ENV06 Argyll & Bute       2010-11    Indicator
#       Clackmannanshire    2017-18    Indicator
#       Dumfries & Galloway 2010-11    Indicator
#                           2019-20    Indicator
#       Dundee City         2017-18    Indicator
#       East Ayrshire       2022-23    Indicator
#       Eilean Siar         2019-20    Indicator
#       Fife                2019-20    Indicator
#       Glasgow City        2012-13    Indicator
#       Highland            2011-12    Indicator
#                           2015-16    Indicator
#       Inverclyde          2010-11    Indicator
#                           2013-14    Indicator
#       North Ayrshire      2010-11    Indicator
#                           2014-15    Indicator
#       North Lanarkshire   2010-11    Indicator
#       Orkney Islands      2012-13    Indicator
#                           2020-21    Indicator
#       Perth & Kinross     2014-15    Indicator
#       Shetland Islands    2010-11    Indicator
#                           2012-13    Indicator
#                           2018-19    Indicator
#       South Ayrshire      2015-16    Indicator
#                           2017-18    Indicator
#       Stirling            2010-11    Indicator
#                           2011-12    Indicator
#       West Dunbartonshire 2018-19    Indicator
# CHN24 Scotland            2014-15    Indicator
#                           2015-16    Indicator
#                           2016-17    Indicator
#                           2017-18    Indicator
#                           2018-19    Indicator
#                           2019-20    Indicator
#                           2020-21    Indicator
#                           2021-22    Indicator
# ENV06 Scotland            2010-11    Indicator

# %%
from google.colab import files
diffs. to_excel('diffs.xlsx')
files.download('diffs.xlsx')

# %% [markdown]
# #Expenditure Table Differences

# %%
exp_new = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
new_exp = get_data(exp_new)
exp_old = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/Expenditure_Table_22Nov.csv"
old_exp = get_data(exp_old)

# %%
new_exp.dtypes
# Out:
# LocalAuthority           object
# Year                     object
# ServiceAreaBreakdown     object
# ExpenditureCash         float64
# dtype: object

# %%
df1 = old_exp
df2 = new_exp

# %%
df2[~df2.astype(str).apply(tuple, 1).isin(df1.astype(str).apply(tuple, 1))]
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash]
# Index: []

# %%
out = pd.merge(df1, df2, on=['LocalAuthority', 'Year', 'ServiceAreaBreakdown'], how='outer',
               suffixes=('_old', '_new')).set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

out.columns = pd.MultiIndex.from_tuples(out.columns.str.split('_').map(tuple)).swaplevel()
#diff_out = out['df1'].compare(out['df2'], keep_equal=True, keep_shape=False).pipe(lambda df_: df_.set_index(df1.loc[df_.index, "IndicatorCode"])).reset_index()

# %%
out
# Out:
#                                                                                    old  \
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
#                                                                                    new
#                                                                        ExpenditureCash
# LocalAuthority Year    ServiceAreaBreakdown
# Aberdeen City  2010-11 Care Homes for Older People                             32279.0
#                        Homecare                                                13516.0
#                        Other Spend On Over 18s                                 65551.0
#                        Community Parks & Open Spaces Gross Expenditure          6198.0
#                        Libraries                                                5867.0
# ...                                                                                ...
# West Lothian   2022-23 Residential                                              9264.0
#                        Planning                                                 3011.0
#                        Roads                                                   14668.0
#                        Support Services                                        16801.0
#                        Total General Fund                                     584113.0
#
# [8735 rows x 2 columns]

# %%
out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
# Empty DataFrame
# Columns: [LocalAuthority, Year, ServiceAreaBreakdown, ExpenditureCash, _merge]
# Index: []

# %% [markdown]
# #Identify the size difference between the two dataframes.

# %%
def getColChangedName(row):
    colsChanged = []
    for c in df1.columns.values:
        if row[c+"_diff"] == True:
            colsChanged.append(c)
    return ", ".join(colsChanged)


df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])

diffs = df1.merge(df2, left_index=True, right_index=True, suffixes=('_old', '_new'))

diff_cols = [c+"_diff" for c in df1.columns.values]

for c in df1.columns.values:
    diffs[c+"_diff"] = diffs[c+"_old"] != diffs[c+"_new"]

diffs["Record_Changed"] = diffs[diff_cols].sum(axis=1)/len(diff_cols) > 0


diffs = diffs[diffs["Record_Changed"] == 1]
diffs["Cols_Changed"] = diffs.apply(lambda row: getColChangedName(row), axis=1)

diffs
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dc0f4cf5ffed> in <cell line: 9>()
#       7
#       8
# ----> 9 df1 = df1.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      10 df2 = df2.set_index(['LocalAuthority', 'Year','ServiceAreaBreakdown'])
#      11
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#
# KeyError: "None of ['LocalAuthority', 'Year', 'ServiceAreaBreakdown'] are in the columns"

# %%
df1 = old_df
df2 = new_df

out_diff = dataframe_difference(df1, df2)
out_diff
# Out:
#         Code       LocalAuthority     Year Indicator Numerator Denominator  \
# 27530  ENV06        Argyll & Bute  2010-11      0.42       nan         nan
# 27550  ENV06     Clackmannanshire  2017-18      0.60       nan         nan
# 27556  ENV06  Dumfries & Galloway  2010-11      0.38       nan         nan
# 27565  ENV06  Dumfries & Galloway  2019-20      0.30       nan         nan
# 27576  ENV06          Dundee City  2017-18      0.36       nan         nan
# ...      ...                  ...      ...       ...       ...         ...
# 36193  SW04b             Scotland  2023-24      0.61       nan         nan
# 36194  SW04c             Scotland  2023-24      0.64       nan         nan
# 36195  SW04d             Scotland  2023-24      0.53       nan         nan
# 36196  SW04e             Scotland  2023-24      0.31       nan         nan
# 36197   SW07             Scotland  2023-24      0.77       nan         nan
#
#            _merge
# 27530   left_only
# 27550   left_only
# 27556   left_only
# 27565   left_only
# 27576   left_only
# ...           ...
# 36193  right_only
# 36194  right_only
# 36195  right_only
# 36196  right_only
# 36197  right_only
#
# [270 rows x 7 columns]

# %%
old_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35959   SW07       Scotland  2018-19      0.82       nan         nan
# 35960   SW07       Scotland  2019-20      0.82       nan         nan
# 35961   SW07       Scotland  2020-21      0.82       nan         nan
# 35962   SW07       Scotland  2021-22      0.76       nan         nan
# 35963   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35964 rows x 6 columns]

# %%
new_df
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 36157   SW07       Scotland  2019-20      0.82       nan         nan
# 36158   SW07       Scotland  2020-21      0.82       nan         nan
# 36159   SW07       Scotland  2021-22      0.76       nan         nan
# 36160   SW07       Scotland  2022-23      0.75       nan         nan
# 36161   SW07       Scotland  2023-24      0.77       nan         nan
#
# [36162 rows x 6 columns]

# %% [markdown]
# #Actual code starts here
#
# ##1. first find new year's data that is added for this year

# %%
#find rows with added data from new year
temp = new_df.rename({'Year': 'Year_new'}, axis=1)
merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Code','Year_new'], right_on=['LocalAuthority','Code','Year'])
#merged = temp.merge(old_df, how='left', left_on=['LocalAuthority','Year_new'], right_on=['LocalAuthority','Year'],indicator='Match')
new_year_df = np.where(merged['Year'].isnull())[0]
new_year_df
# Out:
# array([12894, 12903, 12912, 12921, 12930, 12939, 12948, 12957, 12966,
#        12975, 12984, 12993, 13002, 13011, 13020, 13029, 13038, 13047,
#        13056, 13065, 13074, 13083, 13092, 13101, 13110, 13119, 13128,
#        13137, 13146, 13155, 13164, 13173, 33038, 33044, 33050, 33056,
#        33062, 33068, 33074, 33080, 33086, 33092, 33098, 33104, 33110,
#        33116, 33122, 33128, 33134, 33140, 33146, 33152, 33158, 33164,
#        33170, 33176, 33182, 33188, 33194, 33200, 33206, 33212, 33218,
#        33224, 33230, 33236, 33242, 33248, 33254, 33260, 33266, 33272,
#        33278, 33284, 33290, 33296, 33302, 33308, 33314, 33320, 33326,
#        33332, 33338, 33344, 33350, 33356, 33362, 33368, 33374, 33380,
#        33386, 33392, 33398, 33404, 33410, 33416, 33422, 33428, 33434,
#        33440, 33446, 33452, 33458, 33464, 33470, 33476, 33482, 33488,
#        33494, 33500, 33506, 33512, 33518, 33524, 33530, 33536, 33542,
#        33548, 33554, 33560, 33566, 33572, 33578, 33584, 33590, 33596,
#        33602, 33608, 33614, 33620, 33626, 33632, 33638, 33644, 33650,
#        33656, 33662, 33668, 33674, 33680, 33686, 33692, 33698, 33704,
#        33710, 33716, 33722, 33728, 33734, 33740, 33746, 33752, 33758,
#        33764, 33770, 33776, 33782, 33788, 33794, 33800, 34645, 34658,
#        34671, 34684, 34697, 34710, 34723, 34736, 34749, 34762, 34775,
#        34788, 34801, 34814, 34827, 34840, 34853, 34866, 34879, 34892,
#        34905, 34918, 34931, 34944, 34957, 34970, 34983, 34996, 35009,
#        35022, 35035, 35048, 35466, 36104, 36110, 36116, 36122, 36161])

# %% [markdown]
# # create a new data frame with just the new year's data

# %%
#new year added data
new_Data = pd.concat([old_df,new_df]).drop_duplicates(subset=["Code", "LocalAuthority", 'Year'], keep=False)

# %%
new_Data
# Out:
#          Code    LocalAuthority     Year Indicator  Numerator Denominator
# 13915  CLIM03     Aberdeen City  2022-23     16.65    3786.36   227430.00
# 13921  CLIM03     Aberdeenshire  2022-23     41.28   10842.57   262690.00
# 13927  CLIM03             Angus  2022-23     23.63    2743.39   116120.00
# 13933  CLIM03     Argyll & Bute  2022-23     36.69    3163.19    86220.00
# 13939  CLIM03  Clackmannanshire  2022-23     18.66     961.64    51540.00
# ...       ...               ...      ...       ...        ...         ...
# 24226  ENV03c      West Lothian  2023-24      0.94        nan         nan
# 35303  CLIM03          Scotland  2022-23     27.67  151611.40  5479900.00
# 35309  CLIM04          Scotland  2022-23     43.46  238134.79  5479900.00
# 35315  CLIM05          Scotland  2022-23     57.23  313592.29  5479900.00
# 35622  ENV03c          Scotland  2023-24      0.92        nan         nan
#
# [131 rows x 6 columns]

# %%
#new year added data
new_Data = new_df.loc[new_year_df]
new_Data = new_Data.rename(columns={"Indicator": "New_Indicator", "Numerator": "New_Numerator", "Denominator": "New_Denominator"})
new_Data = new_Data.drop_duplicates()
new_Data
# Out:
#         Code    LocalAuthority     Year New_Indicator New_Numerator  \
# 12894  CHN24     Aberdeen City  2022-23          0.22           nan
# 12903  CHN24     Aberdeenshire  2022-23          0.17           nan
# 12912  CHN24             Angus  2022-23          0.25           nan
# 12921  CHN24     Argyll & Bute  2022-23          0.23           nan
# 12930  CHN24  Clackmannanshire  2022-23          0.29           nan
# ...      ...               ...      ...           ...           ...
# 36104  SW04b          Scotland  2023-24          0.61           nan
# 36110  SW04c          Scotland  2023-24          0.64           nan
# 36116  SW04d          Scotland  2023-24          0.53           nan
# 36122  SW04e          Scotland  2023-24          0.31           nan
# 36161   SW07          Scotland  2023-24          0.77           nan
#
#       New_Denominator
# 12894             nan
# 12903             nan
# 12912             nan
# 12921             nan
# 12930             nan
# ...               ...
# 36104             nan
# 36110             nan
# 36116             nan
# 36122             nan
# 36161             nan
#
# [198 rows x 6 columns]

# %%
from google.colab import files
new_Data. to_excel('newyear_Data.xlsx')
files.download('newyear_Data.xlsx')

# %% [markdown]
# # Create a dataframe with just changes/updates to old data

# %%
#make df with only changes
new_update= new_df.drop(new_df.index[new_year_df], inplace=False).reset_index(drop=True)
new_update
# Out:
#         Code LocalAuthority     Year Indicator Numerator Denominator
# 0      C&L01  Aberdeen City  2010-11      0.33    637.00  1922292.00
# 1      C&L01  Aberdeen City  2011-12      0.76   1554.00  2045051.00
# 2      C&L01  Aberdeen City  2012-13      3.64   7883.00  2163756.00
# 3      C&L01  Aberdeen City  2013-14      3.48   7726.00  2222588.00
# 4      C&L01  Aberdeen City  2014-15      3.02   7517.00  2487138.00
# ...      ...            ...      ...       ...       ...         ...
# 35959   SW07       Scotland  2018-19      0.82       nan         nan
# 35960   SW07       Scotland  2019-20      0.82       nan         nan
# 35961   SW07       Scotland  2020-21      0.82       nan         nan
# 35962   SW07       Scotland  2021-22      0.76       nan         nan
# 35963   SW07       Scotland  2022-23      0.75       nan         nan
#
# [35964 rows x 6 columns]

# %%
np.array_equal(old_df,new_df)
# Out:
# False

# %%
old_df.values==new_update.values
# Out:
# array([[ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        ...,
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True],
#        [ True,  True,  True,  True,  True,  True]])

# %%
#compare the old df to find the changes
comparison_values = old_df.values == new_update.values
rows,cols=np.where(comparison_values==False)
rows
# Out:
# array([27530, 27550, 27556, 27565, 27576, 27594, 27656, 27682, 27688,
#        27700, 27704, 27712, 27715, 27751, 27755, 27764, 27779, 27787,
#        27794, 27829, 27831, 27837, 27847, 27849, 27868, 27869, 27889,
#        35266, 35267, 35268, 35269, 35270, 35271, 35272, 35273, 35725])

# %% [markdown]
# #Add new columns with the changes (keeping the old values)

# %%
change_df = pd.DataFrame()
change_df = old_df.loc[rows]
AddNew_df = new_update.loc[rows]
change_df.insert(loc = 4, column = "New_Indicator", value = AddNew_df["Indicator"].values)
change_df.insert(loc = 6, column = "New_Numerator", value = AddNew_df["Numerator"].values)
change_df.insert(loc = 8, column ="New_Denominator", value = AddNew_df["Denominator"].values)
change_df = change_df.drop_duplicates()
change_df
# Out:
#         Code       LocalAuthority     Year Indicator New_Indicator Numerator  \
# 27530  ENV06        Argyll & Bute  2010-11      0.42          0.41       nan
# 27550  ENV06     Clackmannanshire  2017-18      0.60          0.59       nan
# 27556  ENV06  Dumfries & Galloway  2010-11      0.38          0.39       nan
# 27565  ENV06  Dumfries & Galloway  2019-20      0.30          0.29       nan
# 27576  ENV06          Dundee City  2017-18      0.36          0.35       nan
# 27594  ENV06        East Ayrshire  2022-23      0.49          0.48       nan
# 27656  ENV06          Eilean Siar  2019-20      0.21          0.20       nan
# 27682  ENV06                 Fife  2019-20      0.44          0.45       nan
# 27688  ENV06         Glasgow City  2012-13      0.30          0.29       nan
# 27700  ENV06             Highland  2011-12      0.44          0.45       nan
# 27704  ENV06             Highland  2015-16      0.44          0.45       nan
# 27712  ENV06           Inverclyde  2010-11      0.31          0.32       nan
# 27715  ENV06           Inverclyde  2013-14      0.55          0.56       nan
# 27751  ENV06       North Ayrshire  2010-11      0.44          0.43       nan
# 27755  ENV06       North Ayrshire  2014-15      0.57          0.56       nan
# 27764  ENV06    North Lanarkshire  2010-11      0.44          0.43       nan
# 27779  ENV06       Orkney Islands  2012-13      0.22          0.23       nan
# 27787  ENV06       Orkney Islands  2020-21      0.26          0.23       nan
# 27794  ENV06      Perth & Kinross  2014-15      0.57          0.56       nan
# 27829  ENV06     Shetland Islands  2010-11      0.18          0.20       nan
# 27831  ENV06     Shetland Islands  2012-13      0.13          0.14       nan
# 27837  ENV06     Shetland Islands  2018-19      0.11          0.10       nan
# 27847  ENV06       South Ayrshire  2015-16      0.51          0.52       nan
# 27849  ENV06       South Ayrshire  2017-18      0.55          0.53       nan
# 27868  ENV06             Stirling  2010-11      0.48          0.47       nan
# 27869  ENV06             Stirling  2011-12      0.53          0.54       nan
# 27889  ENV06  West Dunbartonshire  2018-19      0.44          0.43       nan
# 35266  CHN24             Scotland  2014-15      0.20          0.19       nan
# 35267  CHN24             Scotland  2015-16      0.21          0.20       nan
# 35268  CHN24             Scotland  2016-17      0.22          0.20       nan
# 35269  CHN24             Scotland  2017-18      0.22          0.21       nan
# 35270  CHN24             Scotland  2018-19      0.21          0.20       nan
# 35271  CHN24             Scotland  2019-20      0.23          0.22       nan
# 35272  CHN24             Scotland  2020-21      0.21          0.20       nan
# 35273  CHN24             Scotland  2021-22      0.23          0.21       nan
# 35725  ENV06             Scotland  2010-11      0.39          0.38       nan
#
#       New_Numerator Denominator New_Denominator
# 27530           nan         nan             nan
# 27550           nan         nan             nan
# 27556           nan         nan             nan
# 27565           nan         nan             nan
# 27576           nan         nan             nan
# 27594           nan         nan             nan
# 27656           nan         nan             nan
# 27682           nan         nan             nan
# 27688           nan         nan             nan
# 27700           nan         nan             nan
# 27704           nan         nan             nan
# 27712           nan         nan             nan
# 27715           nan         nan             nan
# 27751           nan         nan             nan
# 27755           nan         nan             nan
# 27764           nan         nan             nan
# 27779           nan         nan             nan
# 27787           nan         nan             nan
# 27794           nan         nan             nan
# 27829           nan         nan             nan
# 27831           nan         nan             nan
# 27837           nan         nan             nan
# 27847           nan         nan             nan
# 27849           nan         nan             nan
# 27868           nan         nan             nan
# 27869           nan         nan             nan
# 27889           nan         nan             nan
# 35266           nan         nan             nan
# 35267           nan         nan             nan
# 35268           nan         nan             nan
# 35269           nan         nan             nan
# 35270           nan         nan             nan
# 35271           nan         nan             nan
# 35272           nan         nan             nan
# 35273           nan         nan             nan
# 35725           nan         nan             nan

# %%
from google.colab import files
change_df. to_excel('Data_changes.xlsx')
files.download('Data_changes.xlsx')

# %% [markdown]
# #Add the new year's data in the end in the new value columns

# %%
#Add all changes including new data for the new year

All_changes = pd.concat([change_df, new_Data],  join="outer", axis=0).reset_index()
#All_changes = pd.concat([new_Data, change_df], ignore_index=True)
All_changes = All_changes.sort_values(by=['Year','LocalAuthority'], ascending=[False, True])
All_changes
# Out:
#      index   Code     LocalAuthority     Year Indicator New_Indicator  \
# 68   33038  SW04b      Aberdeen City  2023-24       NaN          0.63
# 100  33230  SW04c      Aberdeen City  2023-24       NaN          0.68
# 132  33422  SW04d      Aberdeen City  2023-24       NaN          0.48
# 164  33614  SW04e      Aberdeen City  2023-24       NaN          0.37
# 196  34645   SW07      Aberdeen City  2023-24       NaN          0.71
# ..     ...    ...                ...      ...       ...           ...
# 13   27751  ENV06     North Ayrshire  2010-11      0.44          0.43
# 15   27764  ENV06  North Lanarkshire  2010-11      0.44          0.43
# 35   35725  ENV06           Scotland  2010-11      0.39          0.38
# 19   27829  ENV06   Shetland Islands  2010-11      0.18          0.20
# 24   27868  ENV06           Stirling  2010-11      0.48          0.47
#
#     Numerator New_Numerator Denominator New_Denominator
# 68        NaN           nan         NaN             nan
# 100       NaN           nan         NaN             nan
# 132       NaN           nan         NaN             nan
# 164       NaN           nan         NaN             nan
# 196       NaN           nan         NaN             nan
# ..        ...           ...         ...             ...
# 13        nan           nan         nan             nan
# 15        nan           nan         nan             nan
# 35        nan           nan         nan             nan
# 19        nan           nan         nan             nan
# 24        nan           nan         nan             nan
#
# [234 rows x 10 columns]

# %%
from google.colab import files
change_df. to_excel('All_changes.xlsx')
files.download('All_changes.xlsx')

# %% [markdown]
# #Highlight changes in the new value columns

# %%
def set_colormap(x):
    c = f'background-color: yellow'
    # DataFrame of styles
    df1 = pd.DataFrame('', index=x.index, columns=x.columns)
    #set new columns by condition
    columns = len(x.columns)
    for i in range (4,columns-1,2):
        col1 = x.columns[i]
        col2 = x.columns[i+1]
        m = x[col1]!=x[col2]
        # set columns by condition
        df1.loc[m, col2] = c
    return df1

All_changes = All_changes.style.apply(set_colormap, axis=None)

# %% [markdown]
# #Write to CSV.

# %%
from google.colab import files
All_changes. to_excel('Final_changes.xlsx')
files.download('Final_changes.xlsx')

# %% [markdown]
# #Stops here!!!!!!!!!!!!!!!!

# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Work_in_progress/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

url = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/test_new.csv"
new_df = get_data(url)
url = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/test_old.csv"
old_df = get_data(url)

# %%
old_df.equals(new_df)
# Out:
# False

# %%
comparison_values = old_df.values == new_df.values
print(comparison_values)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
import numpy as np
rows,cols=np.where(comparison_values==False)

# %%
out_df = old_df

# %%
for item in zip(rows,cols):
    if old_df.iloc[item] != new_df.iloc[item]:
       out_df.iloc[item[0], item[1]] = '{} --> {}'.format(old_df.iloc[item[0], item[1]],new_df.iloc[item[0], item[1]])

# %%
out_df = out_df.dropna(how='all', axis=0)
out_df
# Out:
#       Code LocalAuthority     Year LA_IndicatorReal LA_Numerator_real  \
# 0    C&L01  Aberdeen City  2010-11         0.406679        785.018799
# 1    C&L01  Aberdeen City  2011-12         0.922524       1886.603428
# 2    C&L01  Aberdeen City  2012-13         4.335545       9381.043169
# 3    C&L01  Aberdeen City  2013-14         4.044078       8988.323761
# 4    C&L01  Aberdeen City  2014-15         3.476122       8645.573117
# ..     ...            ...      ...              ...               ...
# 379  C&L01   West Lothian  2017-18         1.843244        4510.75788
# 380  C&L01   West Lothian  2018-19          2.39443       6097.571345
# 381  C&L01   West Lothian  2019-20         2.007365       5049.269872
# 382  C&L01   West Lothian  2020-21        22.000649       4619.323346
# 383  C&L01   West Lothian  2021-22         2.075107       2983.564522
#
#     LA_Den_Real  Scotland_Indicator_Real  Scotland_Num_Real  \
# 0       1922292                 4.374884        198956.0517
# ...

# %%
out_df.to_csv(r'C:\Users\santhanam.jayanthi\Desktop\out_df.csv',index=False, header=True)

# %%
out1_df = old_df
out1_df = out1_df.rename(columns={'LA_IndicatorReal': 'LA_IndicatorRealOldValue', 'LA_Numerator_real': 'LA_Numerator_realOldValue','LA_Den_Real': 'LA_Den_RealOldValue', 'Scotland_Indicator_Real':'Scotland_Indicator_Real_OldValue','Scotland_Num_Real':'Scotland_Num_Real_OldValue','Scotland_Den_Real': 'Scotland_Den_RealOldValue',	'FG_Avg_Indicator_Real':'FG_Avg_Indicator_Real_OldValue',	'FG_Avg_Num_Real':'FG_Avg_Num_Real_OldValue',	'FG_Avg_Den_Real':'FG_Avg_Den_Real_OldValue'})

# %%
out1_df
# Out:
#       Code LocalAuthority     Year LA_IndicatorRealOldValue  \
# 0    C&L01  Aberdeen City  2010-11                 0.406679
# 1    C&L01  Aberdeen City  2011-12                 0.922524
# 2    C&L01  Aberdeen City  2012-13                 4.335545
# 3    C&L01  Aberdeen City  2013-14                 4.044078
# 4    C&L01  Aberdeen City  2014-15                 3.476122
# ..     ...            ...      ...                      ...
# 379  C&L01   West Lothian  2017-18                 1.843244
# 380  C&L01   West Lothian  2018-19                  2.39443
# 381  C&L01   West Lothian  2019-20                 2.007365
# 382  C&L01   West Lothian  2020-21                22.000649
# 383  C&L01   West Lothian  2021-22                 2.075107
#
#     LA_Numerator_realOldValue LA_Den_RealOldValue  \
# 0                  785.018799             1922292
# 1                 1886.603428             2045051
# 2                 9381.043169             2163756
# ...

# %%
for item in zip(rows,cols):
    if old_df.iloc[item] != new_df.iloc[item]:
       out1_df.iloc[item[0], item[1]] = '{} --> {}'.format(old_df.iloc[item[0], item[1]],new_df.iloc[item[0], item[1]])

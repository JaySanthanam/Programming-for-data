# %% [markdown]
# <a href="https://colab.research.google.com/github/JaySanthanam/Programming-for-data/blob/main/Projects/Work_in_progress/Automate_differences.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Test code for automated output file

# %%
import pandas as pd
import numpy as np

def get_data(url): # this function gets data stored as csv file from a given url
  df = pd.read_csv(url)
  return df

url = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/test_new.csv"
new_df = get_data(url)
url = "https://raw.githubusercontent.com/JaySanthanam/Programming-for-data/main/Datasets/test_old.csv"
old_df = get_data(url)

# %%
old_df.equals(new_df)
# Out:
# False

# %%
comparison_values = old_df.values == new_df.values
print(comparison_values)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
import numpy as np
rows,cols=np.where(comparison_values==False)

# %%
out_df = pd.DataFrame(columns=['IndicatorCode','LocalAuthority','Year','LA_IndicatorReal','LA_Numerator_real', 'LA_Den_Real',  'Scotland_Indicator_Real',  'Scotland_Num_Real',  'Scotland_Den_Real', 'FG_Avg_Indicator_Real',  'FG_Avg_Num_Real',  'FG_Avg_Den_Real'], index=old_df.index)

# %%
out_df
# Out:
#     IndicatorCode LocalAuthority Year LA_IndicatorReal LA_Numerator_real  \
# 0             NaN            NaN  NaN              NaN               NaN
# 1             NaN            NaN  NaN              NaN               NaN
# 2             NaN            NaN  NaN              NaN               NaN
# 3             NaN            NaN  NaN              NaN               NaN
# 4             NaN            NaN  NaN              NaN               NaN
# ..            ...            ...  ...              ...               ...
# 379           NaN            NaN  NaN              NaN               NaN
# 380           NaN            NaN  NaN              NaN               NaN
# 381           NaN            NaN  NaN              NaN               NaN
# 382           NaN            NaN  NaN              NaN               NaN
# 383           NaN            NaN  NaN              NaN               NaN
#
#     LA_Den_Real Scotland_Indicator_Real Scotland_Num_Real Scotland_Den_Real  \
# 0           NaN                     NaN               NaN               NaN
# 1           NaN                     NaN               NaN               NaN
# 2           NaN                     NaN               NaN               NaN
# 3           NaN                     NaN               NaN               NaN
# 4           NaN                     NaN               NaN               NaN
# ..          ...                     ...               ...               ...
# 379         NaN                     NaN               NaN               NaN
# 380         NaN                     NaN               NaN               NaN
# 381         NaN                     NaN               NaN               NaN
# 382         NaN                     NaN               NaN               NaN
# 383         NaN                     NaN               NaN               NaN
#
#     FG_Avg_Indicator_Real FG_Avg_Num_Real FG_Avg_Den_Real
# 0                     NaN             NaN             NaN
# 1                     NaN             NaN             NaN
# 2                     NaN             NaN             NaN
# 3                     NaN             NaN             NaN
# 4                     NaN             NaN             NaN
# ..                    ...             ...             ...
# 379                   NaN             NaN             NaN
# 380                   NaN             NaN             NaN
# 381                   NaN             NaN             NaN
# 382                   NaN             NaN             NaN
# 383                   NaN             NaN             NaN
#
# [384 rows x 12 columns]

# %%
for item in zip(rows,cols):
    if old_df.iloc[item] != new_df.iloc[item]:
       out_df.iloc[item[0], item[1]] = '{} --> {}'.format(old_df.iloc[item[0], item[1]],new_df.iloc[item[0], item[1]])

# %%
out_df = out_df.dropna(how='all', axis=0)
out_df
# Out:
#     IndicatorCode LocalAuthority Year LA_IndicatorReal LA_Numerator_real  \
# 0           C&L01            NaN  NaN              NaN               NaN
# 1           C&L01            NaN  NaN              NaN               NaN
# 2           C&L01            NaN  NaN              NaN               NaN
# 3           C&L01            NaN  NaN              NaN               NaN
# 4           C&L01            NaN  NaN              NaN               NaN
# ..            ...            ...  ...              ...               ...
# 379         C&L01            NaN  NaN              NaN               NaN
# 380         C&L01            NaN  NaN              NaN               NaN
# 381         C&L01            NaN  NaN              NaN               NaN
# 382         C&L01            NaN  NaN              NaN               NaN
# 383         C&L01            NaN  NaN              NaN               NaN
#
#     LA_Den_Real Scotland_Indicator_Real Scotland_Num_Real  \
# 0           NaN                     NaN               NaN
# 1           NaN                     NaN               NaN
# 2           NaN                     NaN               NaN
# 3           NaN                     NaN               NaN
# 4           NaN                     NaN               NaN
# ..          ...                     ...               ...
# 379         NaN                     NaN               NaN
# 380         NaN                     NaN               NaN
# 381         NaN                     NaN               NaN
# 382         NaN                     NaN               NaN
# 383         NaN                     NaN               NaN
#
#          Scotland_Den_Real FG_Avg_Indicator_Real FG_Avg_Num_Real  \
# 0    45459818 --> 45458000                   NaN             NaN
# 1                      NaN                   NaN             NaN
# 2                      NaN                   NaN             NaN
# 3                      NaN                   NaN             NaN
# 4                      NaN                   NaN             NaN
# ..                     ...                   ...             ...
# 379                    NaN                   NaN             NaN
# 380                    NaN                   NaN             NaN
# 381                    NaN                   NaN             NaN
# 382                    NaN                   NaN             NaN
# 383                    NaN                   NaN             NaN
#
#     FG_Avg_Den_Real
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 379             NaN
# 380             NaN
# 381             NaN
# 382             NaN
# 383             NaN
#
# [384 rows x 12 columns]
